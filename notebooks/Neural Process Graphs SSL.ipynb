# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Environment" data-toc-modified-id="Environment-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Environment</a></span></li><li><span><a href="#Vanilla-Sup" data-toc-modified-id="Vanilla-Sup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Vanilla Sup</a></span></li></ul></div>

# %% [markdown]
# # Tutorial 7 : Neural Process Graphs
#
# Last Update : 28 July 2019
#
# **Aim**:

# %%
N_THREADS = 8
# Nota Bene : notebooks don't deallocate GPU memory
IS_FORCE_CPU = True # can also be set in the trainer

# %% [markdown]
# ## Environment

# %%
cd ..
# Out:
# /private/home/yannd/projects/Semi-Supervised-Neural-Processes

# %%
# %autosave 600
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# CENTER PLOTS
from IPython.core.display import HTML
display(HTML(""" <style> .output_png {display: table-cell; text-align: center; margin:auto; }
.prompt display:none;}  </style>"""))

import os
if IS_FORCE_CPU:
    os.environ['CUDA_VISIBLE_DEVICES'] = ""
    
import sys
sys.path.append("notebooks")

import numpy as np
import matplotlib.pyplot as plt
import torch
torch.set_num_threads(N_THREADS)
# Out:
# Autosaving every 600 seconds
#  <style> .output_png {display: table-cell; text-align: center; margin:auto; }
# .prompt display:none;}  </style>

# %% [markdown]
# # Dataset
#
# Cora, Citeseer, Pubmed
# PROTEINS, enzymes

# %%
from torch_geometric.datasets import TUDataset, Planetoid, PPI, QM7b, ModelNet
from sklearn.preprocessing import StandardScaler
from utils.data.helpers import make_ssl_dataset_
from copy import deepcopy
# Out:
# -------------------------------
# ImportErrorTraceback (most recent call last)
# <ipython-input-4-ed0d53c216ae> in <module>
#       1 from torch_geometric.datasets import TUDataset, Planetoid, PPI, QM7b, ModelNet
#       2 from sklearn.preprocessing import StandardScaler
# ----> 3 from utils.data.helpers import make_ssl_dataset_
#       4 from copy import deepcopy
#
# ImportError: cannot import name 'make_ssl_dataset_' from 'utils.data.helpers' (/private/home/yannd/projects/Semi-Supervised-Neural-Processes/utils/data/helpers.py)

# %%
from random import shuffle

datasets=dict(enzymes = TUDataset(root='data/ENZYMES', name='ENZYMES', use_node_attr=True, ),
             proteins = TUDataset(root='data/PROTEINS_full', name='PROTEINS_full', use_node_attr=True),
             synthie = TUDataset(root='data/Synthie', name='Synthie', use_node_attr=True))

data_specific_kwargs = {k:dict(y_dim=d.num_node_features,
                               t_dim=d.num_classes
                              ) 
                        for k,d in datasets.items()}

def train_test_split(d, transform=lambda x : StandardScaler().fit_transform(x)):
    if transform is not None:
        d.data.x = torch.from_numpy(transform(d.data.x.numpy()))
    d = d.shuffle()
    return d[:-len(d) // 10], d[-len(d) // 10:]

from skssl.utils.helpers import cont_tuple_to_tuple_cont

def ssl_graph(train_test, label_perc=0.1, is_add_test=True, is_augment=True):
    train, test = train_test
    make_ssl_dataset_(train, label_perc, is_graph=True)
    list_train, list_test = list(train), list(test)
    
    if is_add_test:
        test = deepcopy(test)
        test.data.y = torch.ones_like(test.data.y) * -1
        list_train += list(test)
        
    if is_augment:
        indcs_labels = (train.data.y != -1)
        factor = int((1 - label_perc)/label_perc)-1
        labeled_data = [d for d,i in zip(list_train, indcs_labels) if i]
        list_train += labeled_data * factor
        
    return list_train, list_test

# %%
X_DIM = 2  # 2D spatial input 
#Y_DIM = data.shape[0]
N_TARGETS = None#data.n_classes

label_percentages = [0.01, 0.05, 0.1, 0.3, 0.5, 1]

# %% [markdown]
# # Model

# %%
from skssl.transformers import GraphConvNeuralProcess, GraphNeuralProcessSSLLoss
from skssl.predefined import GCN, UnetGCN, GraphUNet, MLP
from skssl.transformers.neuralproc.datasplit import precomputed_cntxt_trgt_split
from functools import partial
from torch_geometric.nn import GCNConv
import torch.nn as nn

models = {}


m_clf = lambda y_dim, t_dim : partial(GraphConvNeuralProcess,y_dim=y_dim,
                         r_dim=32,
                                Classifier=partial(MLP, input_size=128+y_dim*3, output_size=t_dim, 
                                        dropout=0., hidden_size=64, n_hidden_layers=3, is_res=True),
                                      is_clf_features=True,
                          TmpSelfAttn=partial(UnetGCN, 
                                              is_sum_res=True,
                                              Conv=partial(GCNConv, improved=True), 
                                              max_nchannels=128, n_layers=5,
                                             _is_summary=True))

models["ssl_classifier_gcnp_unetgcn"] = m_clf

m_trnsf = lambda y_dim, t_dim : partial(GraphConvNeuralProcess,y_dim=y_dim,
                         r_dim=32,
                                Classifier=None,
                          TmpSelfAttn=partial(UnetGCN, 
                                              is_sum_res=True,
                                              Conv=partial(GCNConv, improved=True), 
                                              max_nchannels=128, n_layers=5,_is_summary=True))

models["transformer_gcnp_unetgcn"] = m_trnsf

# %%
UnetGCN??

# %%
GraphConvNeuralProcess??

# %%
from utils.helpers import count_parameters
for k,v in models.items():
    print(k, "- N Param:", count_parameters(v(y_dim=3, t_dim=6)()))
# Out:
# ssl_classifier_gcnp_unetgcn - N Param: 59599
# transformer_gcnp_unetgcn - N Param: 42057

# %%
from skssl.transformers.neuralproc.datasplit import GridCntxtTrgtGetter, RandomMasker, no_masker, half_masker
from utils.data.tsdata import get_timeseries_dataset, SparseMultiTimeSeriesDataset

get_cntxt_trgt_test = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.50),
                                         target_masker=no_masker,
                                         is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

get_cntxt_trgt_feat = GridCntxtTrgtGetter(context_masker=no_masker,
                                     target_masker=no_masker,
                                     is_add_cntxts_to_trgts=False)  # don't context points to tagrtes

get_cntxt_trgt = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.99),
                                 target_masker=RandomMasker(min_nnz=0.50, max_nnz=0.99),
                                 is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

import torch
import skorch
from torch_geometric.data import Batch

def cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=False):
    def mycollate(data_list):
        
        if is_repeat_batch:
            data_list = data_list + data_list
            
        data = Batch.from_data_list(data_list, [])
        edge_attr = torch.ones_like(data.edge_index[0], dtype=torch.float) if data.edge_attr is None else data.edge_attr
        
        X, mask_context, mask_target = get_cntxt_trgt(data.x.t().unsqueeze(0), None, is_grided=True, 
                                                      stratify=data.batch)
        data.x = X.squeeze(0).t()
            
        
        # Can't pass a Dataset directly, since it expects tensors. 
        # Use dict of tensors instead. Also, use torch.sparse for 
        # adjacency matrix to pass skorch's same-dimension check
        return {
            "X":{'x': data.x,
            'adj': torch.sparse.FloatTensor(data.edge_index, 
                                            edge_attr, 
                                            size=[data.num_nodes, data.num_nodes], 
                                            device=data.x.device),
            'batch': data.batch},
            'mask_context':mask_context.squeeze(0),
            'mask_target':mask_target.squeeze(0),
            
        }, data.y
    
    return mycollate
        
class SkorchDataset(skorch.dataset.Dataset):
    def __init__(self, X, y):
        # We need to specify `length` to avoid checks
        super(SkorchDataset, self).__init__(X, y, length=len(X))
    
    def transform(self, X, y):
        return X   # Ignore y, since it is included in X

# %%
def load_pretrained_(models, data_name, datasets, data_specific_kwargs):

    # ALREADY INITALIZE TO BE ABLE TO LOAD
    models["ssl_classifier_gcnp_unetgcn"] = m_clf(**data_specific_kwargs[data_name])()
    models["transformer_gcnp_unetgcn"] = m_trnsf(**data_specific_kwargs[data_name])()

    # load all transformers
    loaded_models = {}
    for k, m in models.items():
        if "transformer" not in k:
            continue

        out = train_models_({data_name:datasets[data_name]}, {k :m },
                            chckpnt_dirname=chckpnt_dirname,
                            is_retrain=False,
                           seed=None)

        pretrained_model = out[list(out.keys())[0]].module_
        model_dict = models[k.replace("transformer", "ssl_classifier")].state_dict()
        model_dict.update(pretrained_model.state_dict())
        models[k.replace("transformer", "ssl_classifier")].load_state_dict(model_dict)

# %% [markdown]
# # Training

# %%
import random

N_EPOCHS = 200 
BATCH_SIZE = 16
IS_RETRAIN = False # if false load precomputed
chckpnt_dirname="results/notebooks/neural_process_graph/"

from ntbks_helpers import train_models_
from skorch.callbacks import EarlyStopping

# %%
data_trainers = {}
data_keys = datasets.keys()

for label_perc in label_percentages[::-1]:
    for run in range(10):
        for name_mod in models.keys():
            if "transformer" in name_mod:
                continue
                
            for data_name in data_keys:

                datasets_new = {k:ssl_graph(train_test_split(d), label_perc=label_perc, is_add_test=True, is_augment=True) 
                                for k,d in datasets.items()}

                (data_train, data_test) = datasets_new[data_name]

                data_train = SkorchDataset(data_train, None)
                data_test = SkorchDataset(data_test, None)
                data_test.y = torch.cat([x.y for x in data_test.X])
                data_train.y = torch.cat([x.y for x in data_train.X])

                load_pretrained_(models, data_name, datasets, data_specific_kwargs)

                from skssl.utils.helpers import HyperparameterInterpolator
                n_steps_per_epoch = len(data_train) // BATCH_SIZE
                get_lambda_clf = HyperparameterInterpolator(1, 50, N_EPOCHS * n_steps_per_epoch, mode="linear")

                data_trainers.update(train_models_({data_name: (data_train, data_test)}, 
                                      {k+"_finetune_lab{}%_run{}".format(label_perc, run) :m for k,m in models.items() if "ssl_classifier" in k}, 
                                      criterion=partial(GraphNeuralProcessSSLLoss, 
                                                        n_max_elements=-1, # auto
                                                        label_perc=(data_train.y!=-1).float().mean() ,
                                                        get_lambda_sup=lambda: get_lambda_clf(True),
                                                        is_ssl_only=False,
                                                        ),
                                        patience=15,
                                      chckpnt_dirname=chckpnt_dirname,
                                      max_epochs=N_EPOCHS,
                                                   seed=random.randint(0,10000),
                                      batch_size=BATCH_SIZE,
                                      is_retrain=IS_RETRAIN,
                                                   dataset=SkorchDataset,
                                                   is_monitor_acc=True,
                                      callbacks=[],
                                      #callbacks=[Freezer(lambda x: not x.startswith('classifier'))],
                                      iterator_train__collate_fn=cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=True),  
                                      iterator_valid__collate_fn=cntxt_trgt_collate(get_cntxt_trgt_feat),
                                                   mode="classifier",
                                                  ))
# Out:
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 45 val_loss: 1.2858003377914429
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 7 val_loss: 0.5431659817695618
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 27 val_loss: 0.8947901725769043
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 35 val_loss: 1.3219211101531982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 4 val_loss: 0.548983633518219
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 16 val_loss: 0.9077684283256531
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 45 val_loss: 1.3730242252349854
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 8 val_loss: 0.5437370538711548
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 27 val_loss: 0.9021309018135071
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 35 val_loss: 1.302344799041748
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 8 val_loss: 0.5479198098182678
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 27 val_loss: 0.8938373327255249
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 35 val_loss: 1.3134015798568726
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 1 val_loss: 0.6016703248023987
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 27 val_loss: 0.8845755457878113
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 45 val_loss: 1.3031649589538574
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 7 val_loss: 0.5434341430664062
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 27 val_loss: 0.8981335759162903
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 45 val_loss: 1.2180068492889404
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 1 val_loss: 0.6003772616386414
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 27 val_loss: 0.8906818628311157
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 65 val_loss: 1.276801347732544
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 8 val_loss: 0.539327085018158
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 27 val_loss: 0.8912492990493774
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 30 val_loss: 1.3993544578552246
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 7 val_loss: 0.5523544549942017
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 53 val_loss: 0.7389787435531616
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 35 val_loss: 1.308423638343811
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 7 val_loss: 0.5469298958778381
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 22 val_loss: 0.9014230966567993
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 35 val_loss: 1.6084825992584229
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 7 val_loss: 0.5368859171867371
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 16 val_loss: 0.977568507194519
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 24 val_loss: 1.6144300699234009
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 4 val_loss: 0.5364064574241638
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 16 val_loss: 0.9867525100708008
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 11 val_loss: 1.565070390701294
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 2 val_loss: 0.5400756001472473
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 12 val_loss: 1.0308434963226318
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 11 val_loss: 1.6694332361221313
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 5 val_loss: 0.5372689962387085
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 16 val_loss: 0.9789174199104309
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 24 val_loss: 1.6322911977767944
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 2 val_loss: 0.5405126810073853
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 16 val_loss: 0.9704945683479309
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 22 val_loss: 1.62800931930542
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 2 val_loss: 0.5393995642662048
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 16 val_loss: 0.9710229635238647
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 42 val_loss: 1.5398651361465454
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 4 val_loss: 0.5265993475914001
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 12 val_loss: 1.035929560661316
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 21 val_loss: 1.6602433919906616
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 5 val_loss: 0.5288232564926147
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 16 val_loss: 0.9686108827590942
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 11 val_loss: 1.6536604166030884
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 7 val_loss: 0.5235149264335632
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 20 val_loss: 0.9710159301757812
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 24 val_loss: 1.5892568826675415
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 2 val_loss: 0.5323352217674255
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 16 val_loss: 0.9801570177078247
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 5 val_loss: 1.8553229570388794
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 2 val_loss: 0.4943455755710602
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 13 val_loss: 0.9891241788864136
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 9 val_loss: 1.8083574771881104
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 3 val_loss: 0.48920780420303345
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 12 val_loss: 0.9735854268074036
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 6 val_loss: 1.8204602003097534
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 3 val_loss: 0.49663904309272766
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 47 val_loss: 0.8154346346855164
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 11 val_loss: 1.7522765398025513
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 2 val_loss: 0.4951602518558502
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 27 val_loss: 0.9452120661735535
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 7 val_loss: 1.8469455242156982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 3 val_loss: 0.5039848685264587
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 12 val_loss: 0.9815541505813599
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 11 val_loss: 1.7652459144592285
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 2 val_loss: 0.5005922913551331
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 27 val_loss: 0.9377015829086304
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 best epoch: 9 val_loss: 1.7956082820892334
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 best epoch: 3 val_loss: 0.48750320076942444
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 best epoch: 27 val_loss: 0.9367762804031372
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 best epoch: 11 val_loss: 1.814871072769165
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 best epoch: 2 val_loss: 0.5015658736228943
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 best epoch: 37 val_loss: 0.9069669842720032
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 best epoch: 12 val_loss: 1.8617689609527588
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 best epoch: 2 val_loss: 0.4965931475162506
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 best epoch: 27 val_loss: 0.9451090693473816
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 best epoch: 7 val_loss: 1.7874667644500732
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 best epoch: 2 val_loss: 0.49412307143211365
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 best epoch: 12 val_loss: 0.9829586148262024
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 best epoch: 1 val_loss: 2.7048797607421875
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 best epoch: 1 val_loss: 1.2248475551605225
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 best epoch: 6 val_loss: 1.1138055324554443
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 best epoch: 1 val_loss: 2.70407772064209
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 best epoch: 4 val_loss: 1.1978684663772583
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 best epoch: 5 val_loss: 1.1754133701324463
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 best epoch: 1 val_loss: 2.70713472366333
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 best epoch: 1 val_loss: 1.1962950229644775
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 best epoch: 6 val_loss: 1.097802996635437
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 best epoch: 1 val_loss: 2.7040555477142334
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 best epoch: 4 val_loss: 1.0215293169021606
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 best epoch: 6 val_loss: 1.120909571647644
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 best epoch: 1 val_loss: 2.7074506282806396
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 best epoch: 1 val_loss: 1.2088603973388672
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 best epoch: 6 val_loss: 1.115639328956604
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 best epoch: 1 val_loss: 2.7027437686920166
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 best epoch: 2 val_loss: 1.1535379886627197
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 best epoch: 6 val_loss: 1.1044161319732666
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 best epoch: 1 val_loss: 2.708676338195801
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 best epoch: 2 val_loss: 1.1098099946975708
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 best epoch: 6 val_loss: 1.1321070194244385
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 best epoch: 1 val_loss: 2.7034807205200195
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 best epoch: 1 val_loss: 1.2007887363433838
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 best epoch: 6 val_loss: 1.0996387004852295
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 best epoch: 1 val_loss: 2.708895444869995
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 best epoch: 6 val_loss: 0.8658742308616638
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 best epoch: 6 val_loss: 1.1101226806640625
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 best epoch: 1 val_loss: 2.7041115760803223
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 best epoch: 2 val_loss: 1.1585949659347534
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 best epoch: 5 val_loss: 1.1772054433822632
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 best epoch: 1 val_loss: 3.121708631515503
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 best epoch: 1 val_loss: 1.2755740880966187
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 best epoch: 5 val_loss: 1.084579586982727
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 best epoch: 1 val_loss: 3.122159004211426
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 best epoch: 1 val_loss: 1.2980079650878906
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 best epoch: 5 val_loss: 1.086868405342102
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 best epoch: 1 val_loss: 3.1235008239746094
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 best epoch: 1 val_loss: 1.277952790260315
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 best epoch: 5 val_loss: 1.077040672302246
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 best epoch: 1 val_loss: 3.126474618911743
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 best epoch: 1 val_loss: 1.3256776332855225
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 best epoch: 5 val_loss: 1.083446741104126
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 best epoch: 1 val_loss: 3.1225013732910156
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 best epoch: 2 val_loss: 1.0275222063064575
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 best epoch: 5 val_loss: 1.0908321142196655
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 best epoch: 1 val_loss: 3.1247103214263916
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 best epoch: 2 val_loss: 1.1820677518844604
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 best epoch: 5 val_loss: 1.086256742477417
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 best epoch: 1 val_loss: 3.122833013534546
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 best epoch: 1 val_loss: 1.2469661235809326
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 best epoch: 5 val_loss: 1.1082589626312256
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 best epoch: 1 val_loss: 3.124898672103882
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 best epoch: 1 val_loss: 1.3326984643936157
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 best epoch: 5 val_loss: 1.0711352825164795
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 best epoch: 1 val_loss: 3.123504877090454
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 best epoch: 1 val_loss: 1.3177815675735474
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 best epoch: 5 val_loss: 1.0809091329574585
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 best epoch: 1 val_loss: 3.1260411739349365
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 best epoch: 1 val_loss: 1.3405306339263916
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 best epoch: 5 val_loss: 1.0834201574325562
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 best epoch: 1 val_loss: 5.989979267120361
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 best epoch: 1 val_loss: 6.519623279571533
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 best epoch: 1 val_loss: 1.3872302770614624
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 5.956545829772949
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 6.521864891052246
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 1.3872177600860596
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 5.952715873718262
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 6.476783275604248
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 1.3872379064559937
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 5.973859786987305
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 6.626062870025635
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 1.3880759477615356
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 5.95278787612915
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 6.636899471282959
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 1.387303113937378
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 5.966891288757324
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 6.324332237243652
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 1.3872627019882202
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 5.954939365386963
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 10.4124174118042
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 1.387237310409546
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 5.959175109863281
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 6.769335746765137
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 1.3880339860916138
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 5.9524760246276855
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 6.628399848937988
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 1.3881711959838867
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 5.956018924713135
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 4 val_loss: 7.18483829498291
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 1.3872971534729004

# %% [markdown]
# ## Vanilla Sup

# %%
data_keys = datasets.keys()

for label_perc in label_percentages[::-1]:
    for run in range(10):
        for name_mod in models.keys():
            if "transformer" in name_mod:
                continue
                
            for data_name in data_keys:

                datasets_new = {k:ssl_graph(train_test_split(d), label_perc=label_perc, is_add_test=True, is_augment=True) 
                                for k,d in datasets.items()}

                (data_train, data_test) = datasets_new[data_name]

                data_train = SkorchDataset(data_train, None)
                data_test = SkorchDataset(data_test, None)
                data_test.y = torch.cat([x.y for x in data_test.X])
                data_train.y = torch.cat([x.y for x in data_train.X])

                load_pretrained_(models, data_name, datasets, data_specific_kwargs)

                from skssl.utils.helpers import HyperparameterInterpolator
                n_steps_per_epoch = len(data_train) // BATCH_SIZE
                get_lambda_clf = HyperparameterInterpolator(1, 50, N_EPOCHS * n_steps_per_epoch, mode="linear")

                data_trainers.update(train_models_({data_name: (data_train, data_test)}, 
                                      {k+"_finetune_sup_vanilla_lab{}%_run{}".format(label_perc, run) :m for k,m in models.items() if "ssl_classifier" in k}, 
                                      criterion=partial(GraphNeuralProcessSSLLoss, 
                                                        n_max_elements=None, # auto
                                                        label_perc=None,
                                                        get_lambda_unsup=lambda: 0,
                                                        get_lambda_sup=lambda: 1,
                                                        is_ssl_only=True,
                                                        ),
                                        patience=15,
                                      chckpnt_dirname=chckpnt_dirname,
                                      max_epochs=N_EPOCHS,
                                                   seed=random.randint(0,10000),
                                      batch_size=BATCH_SIZE,
                                      is_retrain=IS_RETRAIN,
                                                   dataset=SkorchDataset,
                                                   is_monitor_acc=True,
                                      callbacks=[],
                                      #callbacks=[Freezer(lambda x: not x.startswith('classifier'))],
                                      iterator_train__collate_fn=cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=True),  
                                      iterator_valid__collate_fn=cntxt_trgt_collate(get_cntxt_trgt_feat),
                                                   mode="classifier",
                                                  ))
# Out:
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 best epoch: 32 val_loss: 1.1423413753509521
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 best epoch: 12 val_loss: 0.4449959695339203
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run0 best epoch: 3 val_loss: 1.3055026531219482
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 best epoch: 17 val_loss: 1.392900824546814
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 best epoch: 2 val_loss: 0.5378443002700806
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run1 best epoch: 34 val_loss: 0.8772810101509094
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 best epoch: 50 val_loss: 1.1408284902572632
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 best epoch: 5 val_loss: 0.49144110083580017
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run2 best epoch: 3 val_loss: 1.2667125463485718
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 best epoch: 54 val_loss: 1.1325775384902954
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 best epoch: 17 val_loss: 0.6552481055259705
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run3 best epoch: 4 val_loss: 1.2591986656188965
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 best epoch: 40 val_loss: 1.2762683629989624
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 best epoch: 3 val_loss: 0.5585976243019104
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run4 best epoch: 23 val_loss: 0.8910670280456543
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 best epoch: 31 val_loss: 1.2383499145507812
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 best epoch: 1 val_loss: 0.5660030245780945
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run5 best epoch: 4 val_loss: 1.1739091873168945
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 best epoch: 30 val_loss: 1.14400315284729
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 best epoch: 21 val_loss: 0.3840336501598358
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run6 best epoch: 18 val_loss: 0.9069331288337708
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 best epoch: 16 val_loss: 1.348412275314331
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 best epoch: 7 val_loss: 0.5262420773506165
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run7 best epoch: 14 val_loss: 0.9938443899154663
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 best epoch: 50 val_loss: 1.26901376247406
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 best epoch: 15 val_loss: 0.4917772710323334
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run8 best epoch: 6 val_loss: 1.123498797416687
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 best epoch: 33 val_loss: 1.2742878198623657
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 best epoch: 1 val_loss: 0.5365533232688904
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab1%_run9 best epoch: 49 val_loss: 0.6676395535469055
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 best epoch: 36 val_loss: 1.407585620880127
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 best epoch: 4 val_loss: 0.49628812074661255
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run0 best epoch: 14 val_loss: 0.9900690317153931
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 best epoch: 34 val_loss: 1.2269314527511597
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 best epoch: 4 val_loss: 0.5743699669837952
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run1 best epoch: 18 val_loss: 1.0009845495224
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 best epoch: 20 val_loss: 1.369966745376587
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 best epoch: 3 val_loss: 0.4973214566707611
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run2 best epoch: 5 val_loss: 1.2430849075317383
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 best epoch: 25 val_loss: 1.46372389793396
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 best epoch: 6 val_loss: 0.4561343193054199
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run3 best epoch: 24 val_loss: 0.9602629542350769
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 best epoch: 61 val_loss: 1.1693006753921509
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 best epoch: 2 val_loss: 0.5288137197494507
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run4 best epoch: 13 val_loss: 1.050696849822998
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 best epoch: 6 val_loss: 1.5566190481185913
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 best epoch: 1 val_loss: 0.6618315577507019
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run5 best epoch: 20 val_loss: 0.9539737701416016
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 best epoch: 38 val_loss: 1.3015061616897583
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 best epoch: 1 val_loss: 0.5303784012794495
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run6 best epoch: 8 val_loss: 1.1760090589523315
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 best epoch: 26 val_loss: 1.4823017120361328
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 best epoch: 4 val_loss: 0.49377569556236267
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run7 best epoch: 13 val_loss: 1.0220853090286255
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 best epoch: 15 val_loss: 1.6426459550857544
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 best epoch: 4 val_loss: 0.5283929109573364
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run8 best epoch: 3 val_loss: 1.265734076499939
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 best epoch: 13 val_loss: 1.605674386024475
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 best epoch: 10 val_loss: 0.4653606116771698
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.5%_run9 best epoch: 17 val_loss: 1.1109424829483032
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 best epoch: 44 val_loss: 1.4231905937194824
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 best epoch: 1 val_loss: 0.6437962651252747
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run0 best epoch: 37 val_loss: 0.8845527768135071
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 best epoch: 62 val_loss: 1.2212773561477661
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 best epoch: 1 val_loss: 0.652508556842804
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run1 best epoch: 16 val_loss: 1.148429036140442
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 best epoch: 13 val_loss: 1.651789903640747
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 best epoch: 2 val_loss: 0.4733107089996338
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run2 best epoch: 10 val_loss: 1.0467607975006104
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 best epoch: 8 val_loss: 1.733794093132019
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 best epoch: 1 val_loss: 0.5564025640487671
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run3 best epoch: 14 val_loss: 1.0067756175994873
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 best epoch: 1 val_loss: 1.6838047504425049
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 best epoch: 3 val_loss: 0.5742906928062439
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run4 best epoch: 22 val_loss: 0.8982422947883606
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 best epoch: 17 val_loss: 1.5002291202545166
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 best epoch: 1 val_loss: 0.6854615807533264
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run5 best epoch: 13 val_loss: 1.0528881549835205
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 best epoch: 38 val_loss: 1.4174638986587524
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 best epoch: 1 val_loss: 0.5300217270851135
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run6 best epoch: 8 val_loss: 1.3205368518829346
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 best epoch: 14 val_loss: 1.395005464553833
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 best epoch: 1 val_loss: 0.5461642146110535
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run7 best epoch: 5 val_loss: 1.1968590021133423
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 best epoch: 7 val_loss: 1.6229026317596436
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 best epoch: 3 val_loss: 0.5123879313468933
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run8 best epoch: 19 val_loss: 1.0410022735595703
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 best epoch: 1 val_loss: 1.724959135055542
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 best epoch: 2 val_loss: 0.533263623714447
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.3%_run9 best epoch: 15 val_loss: 1.0071344375610352
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 best epoch: 2 val_loss: 1.6630699634552002
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 best epoch: 1 val_loss: 0.9985078573226929
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run0 best epoch: 9 val_loss: 1.2066850662231445
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 best epoch: 2 val_loss: 1.6978832483291626
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 best epoch: 1 val_loss: 0.6718690991401672
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run1 best epoch: 4 val_loss: 1.0952308177947998
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 best epoch: 1 val_loss: 1.9070725440979004
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 best epoch: 1 val_loss: 0.6571431159973145
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run2 best epoch: 8 val_loss: 1.0715452432632446
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 best epoch: 1 val_loss: 1.8423789739608765
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 best epoch: 1 val_loss: 1.014042615890503
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run3 best epoch: 16 val_loss: 0.9671043157577515
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 best epoch: 2 val_loss: 1.7785660028457642
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 best epoch: 1 val_loss: 0.7147096991539001
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run4 best epoch: 4 val_loss: 1.1318795680999756
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 best epoch: 1 val_loss: 2.011681079864502
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 best epoch: 1 val_loss: 0.5932081937789917
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run5 best epoch: 7 val_loss: 0.9997231364250183
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 best epoch: 2 val_loss: 1.7684637308120728
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 best epoch: 1 val_loss: 1.2198740243911743
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run6 best epoch: 4 val_loss: 1.115669846534729
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 best epoch: 1 val_loss: 2.2086453437805176
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 best epoch: 1 val_loss: 1.1852988004684448
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run7 best epoch: 4 val_loss: 1.2194280624389648
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 best epoch: 1 val_loss: 1.892700433731079
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 best epoch: 1 val_loss: 0.7187243103981018
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run8 best epoch: 12 val_loss: 1.0852092504501343
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 best epoch: 1 val_loss: 1.9386570453643799
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 best epoch: 3 val_loss: 0.6967845559120178
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.1%_run9 best epoch: 8 val_loss: 1.1283979415893555
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 best epoch: 1 val_loss: 2.9132587909698486
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 best epoch: 1 val_loss: 1.2595819234848022
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run0 best epoch: 2 val_loss: 1.3603270053863525
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 best epoch: 1 val_loss: 1.9186393022537231
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 best epoch: 1 val_loss: 1.2609567642211914
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run1 best epoch: 3 val_loss: 1.1634318828582764
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 best epoch: 1 val_loss: 2.003441572189331
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 best epoch: 1 val_loss: 0.9179638624191284
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run2 best epoch: 4 val_loss: 1.2075313329696655
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 best epoch: 1 val_loss: 2.0729031562805176
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 best epoch: 1 val_loss: 1.4464741945266724
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run3 best epoch: 9 val_loss: 1.1379504203796387
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 best epoch: 1 val_loss: 2.274831533432007
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 best epoch: 1 val_loss: 1.1040561199188232
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run4 best epoch: 4 val_loss: 1.3255535364151
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 best epoch: 1 val_loss: 2.214184522628784
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 best epoch: 1 val_loss: 1.0896916389465332
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run5 best epoch: 5 val_loss: 1.3219839334487915
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 best epoch: 1 val_loss: 2.134708881378174
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 best epoch: 1 val_loss: 2.5149290561676025
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run6 best epoch: 1 val_loss: 1.395849585533142
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 best epoch: 1 val_loss: 1.9282875061035156
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 best epoch: 1 val_loss: 1.6876376867294312
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run7 best epoch: 4 val_loss: 1.2398830652236938
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 best epoch: 1 val_loss: 2.2729971408843994
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 best epoch: 1 val_loss: 0.7022567391395569
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run8 best epoch: 2 val_loss: 1.3653978109359741
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 best epoch: 1 val_loss: 1.9566420316696167
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 best epoch: 1 val_loss: 1.1862398386001587
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.05%_run9 best epoch: 4 val_loss: 1.2093501091003418
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 best epoch: 1 val_loss: 3.443237781524658
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 best epoch: 2 val_loss: 2.8427574634552
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run0 best epoch: 1 val_loss: 1.3168781995773315
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 best epoch: 1 val_loss: 6.4095330238342285
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 best epoch: 1 val_loss: 5.884932041168213
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run1 best epoch: 1 val_loss: 1.4580438137054443
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 best epoch: 1 val_loss: 2.845567226409912
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 best epoch: 1 val_loss: 2.275277614593506
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run2 best epoch: 1 val_loss: 1.43010675907135
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 best epoch: 1 val_loss: 3.0327670574188232
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 best epoch: 1 val_loss: 5.512417793273926
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run3 best epoch: 1 val_loss: 1.3863087892532349
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 best epoch: 1 val_loss: 3.9217116832733154
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 best epoch: 1 val_loss: 4.17077112197876
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run4 best epoch: 1 val_loss: 1.4445693492889404
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 best epoch: 1 val_loss: 5.7581868171691895
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 best epoch: 1 val_loss: 2.514145612716675
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run5 best epoch: 2 val_loss: 1.3338263034820557
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 best epoch: 1 val_loss: 3.9681525230407715
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 best epoch: 1 val_loss: 9.481353759765625
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run6 best epoch: 1 val_loss: 1.3982361555099487
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 best epoch: 1 val_loss: 3.2421486377716064
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 best epoch: 1 val_loss: 3.6567234992980957
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run7 best epoch: 1 val_loss: 1.427252173423767
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 best epoch: 1 val_loss: 4.730015277862549
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 best epoch: 1 val_loss: 2.326939105987549
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run8 best epoch: 1 val_loss: 1.5232813358306885
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 best epoch: 1 val_loss: 4.420928478240967
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 best epoch: 1 val_loss: 4.357398509979248
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla_lab0.01%_run9 best epoch: 1 val_loss: 1.4754126071929932

# %%
import pandas as pd

out = pd.Series({k:v.history[-1]["valid_acc"] for k,v in data_trainers.items()}).reset_index(name="accuracy")
splitted = out["index"].str.split("/", expand = True)
out["data"] = splitted[0]
out["models"] = splitted[1]

splitted2 = out["models"].str.split("_run", expand = True)
out["models"] = splitted2[0]
out["run"] = splitted2[1]

splitted3 = out["models"].str.split("_lab", expand = True)
out["models"] = splitted3[0]
out["lab"] = splitted3[1]


out.drop(columns =["index"], inplace = True) 

out = out.groupby(["lab", "models"]).agg(["mean", "std"])

out=out.reset_index()
out.lab = out.lab.map(lambda x : float(x[:-1])*100)

out.replace({"ssl_classifier_gcnp_unetgcn_finetune": "Joint UnetGNP",
            "ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla": "Joint UnetGNP Minimal"},
                                 inplace = True)



out=out.rename(columns={"models":"Models", "data":"Dataset",
                       "lab":"Label Percentage (%)"})

out.to_csv("results/tables/table_graph_minimal.csv")

# %%
ls results/tables/
# Out:
# table_ablation_har.csv   table_graph_proteins.csv
# table_graph_enzymes.csv  table_graph_synthie.csv

# %%
import pandas as pd

out = pd.Series({k:v.history[-1]["valid_acc"] for k,v in data_trainers.items()}).reset_index(name="accuracy")
splitted = out["index"].str.split("/", expand = True)
out["data"] = splitted[0]
out["models"] = splitted[1]

splitted2 = out["models"].str.split("_run", expand = True)
out["models"] = splitted2[0]
out["run"] = splitted2[1]

splitted3 = out["models"].str.split("_lab", expand = True)
out["models"] = splitted3[0]
out["lab"] = splitted3[1]


out.drop(columns =["index"], inplace = True) 

out.groupby(["data", "models"]).describe()
# Out:
#                                                                 accuracy  \
#                                                                    count
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%     10.0
#                                                           0.05%     10.0
#                                                           0.1%      10.0
#                                                           0.3%      10.0
#                                                           0.5%      10.0
#                                                           1%        10.0
#
#                                                                            \
#                                                                      mean
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.186667
#                                                           0.05%  0.360000
#                                                           0.1%   0.406667
#                                                           0.3%   0.465000
#                                                           0.5%   0.526667
#                                                           1%     0.668333
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.278333
#                                                           0.05%  0.356667
#                                                           0.1%   0.433333
#                                                           0.3%   0.530000
#                                                           0.5%   0.545000
#                                                           1%     0.636667
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.621429
#                                                           0.05%  0.756250
#                                                           0.1%   0.750000
#                                                           0.3%   0.759821
#                                                           0.5%   0.758036
#                                                           1%     0.756250
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.626786
#                                                           0.05%  0.700893
#                                                           0.1%   0.725893
#                                                           0.3%   0.759821
#                                                           0.5%   0.788393
#                                                           1%     0.768750
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.535000
#                                                           0.05%  0.595000
#                                                           0.1%   0.555000
#                                                           0.3%   0.640000
#                                                           0.5%   0.587500
#                                                           1%     0.642500
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.405000
#                                                           0.05%  0.482500
#                                                           0.1%   0.535000
#                                                           0.3%   0.557500
#                                                           0.5%   0.527500
#                                                           1%     0.560000
#
#                                                                            \
#                                                                       std
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.028109
#                                                           0.05%  0.022498
#                                                           0.1%   0.032584
#                                                           0.3%   0.031866
#                                                           0.5%   0.031623
#                                                           1%     0.051190
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.031476
#                                                           0.05%  0.053403
#                                                           0.1%   0.036851
#                                                           0.3%   0.058689
#                                                           0.5%   0.077798
#                                                           1%     0.053748
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.032384
#                                                           0.05%  0.011942
#                                                           0.1%   0.014580
#                                                           0.3%   0.010689
#                                                           0.5%   0.006588
#                                                           1%     0.004313
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.095033
#                                                           0.05%  0.032124
#                                                           0.1%   0.040818
#                                                           0.3%   0.035826
#                                                           0.5%   0.026302
#                                                           1%     0.047517
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.033747
#                                                           0.05%  0.010541
#                                                           0.1%   0.034960
#                                                           0.3%   0.039441
#                                                           0.5%   0.029463
#                                                           1%     0.040910
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.066458
#                                                           0.05%  0.085837
#                                                           0.1%   0.075645
#                                                           0.3%   0.069771
#                                                           0.5%   0.066091
#                                                           1%     0.092946
#
#                                                                            \
#                                                                       min
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.166667
#                                                           0.05%  0.316667
#                                                           0.1%   0.350000
#                                                           0.3%   0.416667
#                                                           0.5%   0.483333
#                                                           1%     0.600000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.233333
#                                                           0.05%  0.283333
#                                                           0.1%   0.383333
#                                                           0.3%   0.416667
#                                                           0.5%   0.450000
#                                                           1%     0.533333
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.580357
#                                                           0.05%  0.741071
#                                                           0.1%   0.723214
#                                                           0.3%   0.741071
#                                                           0.5%   0.750000
#                                                           1%     0.750000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.482143
#                                                           0.05%  0.651786
#                                                           0.1%   0.642857
#                                                           0.3%   0.714286
#                                                           0.5%   0.741071
#                                                           1%     0.678571
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.475000
#                                                           0.05%  0.575000
#                                                           0.1%   0.500000
#                                                           0.3%   0.600000
#                                                           0.5%   0.550000
#                                                           1%     0.600000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.275000
#                                                           0.05%  0.300000
#                                                           0.1%   0.400000
#                                                           0.3%   0.450000
#                                                           0.5%   0.450000
#                                                           1%     0.450000
#
#                                                                            \
#                                                                       25%
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.166667
#                                                           0.05%  0.350000
#                                                           0.1%   0.400000
#                                                           0.3%   0.437500
#                                                           0.5%   0.504167
#                                                           1%     0.620833
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.254167
#                                                           0.05%  0.333333
#                                                           0.1%   0.400000
#                                                           0.3%   0.520833
#                                                           0.5%   0.487500
#                                                           1%     0.637500
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.607143
#                                                           0.05%  0.750000
#                                                           0.1%   0.743304
#                                                           0.3%   0.752232
#                                                           0.5%   0.752232
#                                                           1%     0.752232
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.542411
#                                                           0.05%  0.680804
#                                                           0.1%   0.716518
#                                                           0.3%   0.734375
#                                                           0.5%   0.770089
#                                                           1%     0.743304
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.525000
#                                                           0.05%  0.600000
#                                                           0.1%   0.525000
#                                                           0.3%   0.606250
#                                                           0.5%   0.575000
#                                                           1%     0.625000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.381250
#                                                           0.05%  0.437500
#                                                           0.1%   0.487500
#                                                           0.3%   0.506250
#                                                           0.5%   0.462500
#                                                           1%     0.487500
#
#                                                                            \
#                                                                       50%
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.175000
#                                                           0.05%  0.358333
#                                                           0.1%   0.408333
#                                                           0.3%   0.466667
#                                                           0.5%   0.533333
#                                                           1%     0.666667
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.283333
#                                                           0.05%  0.350000
#                                                           0.1%   0.433333
#                                                           0.3%   0.533333
#                                                           0.5%   0.541667
#                                                           1%     0.650000
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.616071
#                                                           0.05%  0.754464
#                                                           0.1%   0.750000
#                                                           0.3%   0.758929
#                                                           0.5%   0.758929
#                                                           1%     0.758929
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.656250
#                                                           0.05%  0.705357
#                                                           0.1%   0.727679
#                                                           0.3%   0.750000
#                                                           0.5%   0.794643
#                                                           1%     0.772321
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.537500
#                                                           0.05%  0.600000
#                                                           0.1%   0.562500
#                                                           0.3%   0.625000
#                                                           0.5%   0.575000
#                                                           1%     0.625000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.400000
#                                                           0.05%  0.487500
#                                                           0.1%   0.525000
#                                                           0.3%   0.550000
#                                                           0.5%   0.525000
#                                                           1%     0.537500
#
#                                                                            \
#                                                                       75%
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.195833
#                                                           0.05%  0.366667
#                                                           0.1%   0.416667
#                                                           0.3%   0.483333
#                                                           0.5%   0.545833
#                                                           1%     0.712500
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.300000
#                                                           0.05%  0.366667
#                                                           0.1%   0.466667
#                                                           0.3%   0.545833
#                                                           0.5%   0.591667
#                                                           1%     0.662500
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.616071
#                                                           0.05%  0.765625
#                                                           0.1%   0.750000
#                                                           0.3%   0.767857
#                                                           0.5%   0.758929
#                                                           1%     0.758929
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.712054
#                                                           0.05%  0.720982
#                                                           0.1%   0.754464
#                                                           0.3%   0.794643
#                                                           0.5%   0.812500
#                                                           1%     0.776786
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.550000
#                                                           0.05%  0.600000
#                                                           0.1%   0.575000
#                                                           0.3%   0.668750
#                                                           0.5%   0.618750
#                                                           1%     0.650000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.456250
#                                                           0.05%  0.525000
#                                                           0.1%   0.587500
#                                                           0.3%   0.593750
#                                                           0.5%   0.587500
#                                                           1%     0.612500
#
#
#                                                                       max
# data     models                                           lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.250000
#                                                           0.05%  0.400000
#                                                           0.1%   0.466667
#                                                           0.3%   0.516667
#                                                           0.5%   0.583333
#                                                           1%     0.733333
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.316667
#                                                           0.05%  0.466667
#                                                           0.1%   0.483333
#                                                           0.3%   0.633333
#                                                           0.5%   0.683333
#                                                           1%     0.700000
# proteins ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.687500
#                                                           0.05%  0.776786
#                                                           0.1%   0.776786
#                                                           0.3%   0.776786
#                                                           0.5%   0.767857
#                                                           1%     0.758929
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.723214
#                                                           0.05%  0.758929
#                                                           0.1%   0.776786
#                                                           0.3%   0.812500
#                                                           0.5%   0.812500
#                                                           1%     0.848214
# synthie  ssl_classifier_gcnp_unetgcn_finetune             0.01%  0.600000
#                                                           0.05%  0.600000
#                                                           0.1%   0.600000
#                                                           0.3%   0.700000
#                                                           0.5%   0.625000
#                                                           1%     0.750000
#          ssl_classifier_gcnp_unetgcn_finetune_sup_vanilla 0.01%  0.500000
#                                                           0.05%  0.600000
#                                                           0.1%   0.650000
#                                                           0.3%   0.675000
#                                                           0.5%   0.625000
#                                                           1%     0.750000

# %%
for k,t in data_trainers.items(): 
    for e, h in enumerate(t.history[::-1]):
        if h["valid_acc_best"]:
            print(k, "epoch:", len(t.history)-e, 
                  "val_loss:", h["valid_loss"], 
                 "valid_acc", h["valid_acc"])
            break

# %%
#add param / time / memory

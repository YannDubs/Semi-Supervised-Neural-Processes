# %% [markdown]
# # Tutorial 7 : Neural Process Graphs
#
# Last Update : 28 July 2019
#
# **Aim**:

# %%
N_THREADS = 12
# Nota Bene : notebooks don't deallocate GPU memory
IS_FORCE_CPU = True # can also be set in the trainer

# %% [markdown]
# ## Environment

# %%
cd ..
# Out:
# /conv

# %%
# %autosave 600
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# CENTER PLOTS
from IPython.core.display import HTML
display(HTML(""" <style> .output_png {display: table-cell; text-align: center; margin:auto; }
.prompt display:none;}  </style>"""))

import os
if IS_FORCE_CPU:
    os.environ['CUDA_VISIBLE_DEVICES'] = ""
    
import sys
sys.path.append("notebooks")

import numpy as np
import matplotlib.pyplot as plt
import torch
torch.set_num_threads(N_THREADS)
# Out:
# Autosaving every 600 seconds
#  <style> .output_png {display: table-cell; text-align: center; margin:auto; }
# .prompt display:none;}  </style>

# %% [markdown]
# # Dataset
#
# Cora, Citeseer, Pubmed
# PROTEINS, enzymes

# %%
from torch_geometric.datasets import TUDataset, Planetoid, PPI, QM7b, ModelNet
from sklearn.preprocessing import StandardScaler

from torch_geometric.datasets import TUDataset, Planetoid, PPI, QM7b, ModelNet
from sklearn.preprocessing import StandardScaler
from utils.data.helpers import make_ssl_dataset_
from copy import deepcopy

# %%
from random import shuffle

datasets=dict(enzymes = TUDataset(root='data/ENZYMES', name='ENZYMES', use_node_attr=True, ),
             proteins = TUDataset(root='data/PROTEINS_full', name='PROTEINS_full', use_node_attr=True),
             synthie = TUDataset(root='data/Synthie', name='Synthie', use_node_attr=True))

data_specific_kwargs = {k:dict(y_dim=d.num_node_features,
                               t_dim=d.num_classes
                              ) 
                        for k,d in datasets.items()}

def train_test_split(d, transform=lambda x : StandardScaler().fit_transform(x)):
    if transform is not None:
        d.data.x = torch.from_numpy(transform(d.data.x.numpy()))
    d = d.shuffle()
    return d[:-len(d) // 10], d[-len(d) // 10:]

from skssl.utils.helpers import cont_tuple_to_tuple_cont

def ssl_graph(train_test, label_perc=0.1, is_add_test=True, is_augment=True):
    train, test = train_test
    make_ssl_dataset_(train, label_perc, is_graph=True)
    list_train, list_test = list(train), list(test)
    
    if is_add_test:
        test = deepcopy(test)
        test.data.y = torch.ones_like(test.data.y) * -1
        list_train += list(test)
        
    if is_augment:
        indcs_labels = (train.data.y != -1)
        factor = int((1 - label_perc)/label_perc)-1
        labeled_data = [d for d,i in zip(list_train, indcs_labels) if i]
        list_train += labeled_data * factor
        
    return list_train, list_test

# %%
from skssl.transformers.neuralproc.datasplit import GridCntxtTrgtGetter, RandomMasker, no_masker, half_masker
from utils.data.tsdata import get_timeseries_dataset, SparseMultiTimeSeriesDataset

get_cntxt_trgt_test = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.50),
                                         target_masker=no_masker,
                                         is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

get_cntxt_trgt_feat = GridCntxtTrgtGetter(context_masker=no_masker,
                                     target_masker=no_masker,
                                     is_add_cntxts_to_trgts=False)  # don't context points to tagrtes

get_cntxt_trgt = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.99),
                                 target_masker=RandomMasker(min_nnz=0.50, max_nnz=0.99),
                                 is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

import torch
import skorch
from torch_geometric.data import Batch

def cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=False):
    def mycollate(data_list):
        
        if is_repeat_batch:
            data_list = data_list + data_list
            
        data = Batch.from_data_list(data_list, [])
        edge_attr = torch.ones_like(data.edge_index[0], dtype=torch.float) if data.edge_attr is None else data.edge_attr
        
        X, mask_context, mask_target = get_cntxt_trgt(data.x.t().unsqueeze(0), None, is_grided=True, 
                                                      stratify=data.batch)
        data.x = X.squeeze(0).t()
            
        
        # Can't pass a Dataset directly, since it expects tensors. 
        # Use dict of tensors instead. Also, use torch.sparse for 
        # adjacency matrix to pass skorch's same-dimension check
        return {
            "X":{'x': data.x,
            'adj': torch.sparse.FloatTensor(data.edge_index, 
                                            edge_attr, 
                                            size=[data.num_nodes, data.num_nodes], 
                                            device=data.x.device),
            'batch': data.batch},
            'mask_context':mask_context.squeeze(0),
            'mask_target':mask_target.squeeze(0),
            
        }, data.y
    
    return mycollate
        
class SkorchDataset(skorch.dataset.Dataset):
    def __init__(self, X, y):
        # We need to specify `length` to avoid checks
        super(SkorchDataset, self).__init__(X, y, length=len(X))
    
    def transform(self, X, y):
        return X   # Ignore y, since it is included in X

# %%
X_DIM = 2  # 2D spatial input 
#Y_DIM = data.shape[0]
N_TARGETS = None#data.n_classes

label_percentages = [0.01, 0.05, 0.1, 0.3, 0.5, 1]

# %% [markdown]
# # Model

# %%
from skssl.transformers import GraphConvNeuralProcess, GraphNeuralProcessLoss
from skssl.predefined import GCN, UnetGCN, GAT
from skssl.transformers.neuralproc.datasplit import precomputed_cntxt_trgt_split
from functools import partial
from torch_geometric.nn import GCNConv, GINConv, global_mean_pool
from torch_geometric.nn import GraphConv, TopKPooling
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
import torch.nn as nn
import torch.nn.functional as F
from types import SimpleNamespace

models = {}

class Topk(torch.nn.Module):
    def __init__(self, y_dim, t_dim):
        super().__init__()

        self.conv1 = GraphConv(y_dim, 128)
        self.pool1 = TopKPooling(128, ratio=0.8)
        self.conv2 = GraphConv(128, 128)
        self.pool2 = TopKPooling(128, ratio=0.8)
        self.conv3 = GraphConv(128, 128)
        self.pool3 = TopKPooling(128, ratio=0.8)

        self.lin1 = torch.nn.Linear(256, 128)
        self.lin2 = torch.nn.Linear(128, 64)
        self.lin3 = torch.nn.Linear(64, t_dim)

    def forward(self, x, adj, batch):
        edge_index = adj._indices()

        x = F.relu(self.conv1(x, edge_index))
        x, edge_index, _, batch, _ = self.pool1(x, edge_index, None, batch)
        x1 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv2(x, edge_index))
        x, edge_index, _, batch, _ = self.pool2(x, edge_index, None, batch)
        x2 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = F.relu(self.conv3(x, edge_index))
        x, edge_index, _, batch, _ = self.pool3(x, edge_index, None, batch)
        x3 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)

        x = x1 + x2 + x3

        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)

        return F.relu(self.lin2(x))


class GATSupervised(torch.nn.Module):
    def __init__(self, y_dim, t_dim, dim=8, heads=8, dropout=0.6, n_layers=2):
        super().__init__()
        self.gat = GAT(y_dim, out_channels=32, dim=dim, heads=heads, dropout=dropout, n_layers=n_layers)
        self.lin = nn.Linear(32, t_dim)
        
    def forward(self, x, adj, batch):
        x = self.gat(SimpleNamespace(x=x, edge_index=adj._indices(), batch=batch))
        x = global_mean_pool(x.x, x.batch)
        return self.lin(x) 
    
class GIN0(torch.nn.Module):
    def __init__(self, y_dim, t_dim, num_layers=5, hidden=32):
        super(GIN0, self).__init__()
        self.conv1 = GINConv(
            nn.Sequential(
            nn.Linear(y_dim, hidden),
                nn.ReLU(),
                nn.Linear(hidden, hidden),
                nn.ReLU(),
                nn.BatchNorm1d(hidden),
            ),
            train_eps=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(
                GINConv(
                    nn.Sequential(
                        nn.Linear(hidden, hidden),
                        nn.ReLU(),
                        nn.Linear(hidden, hidden),
                        nn.ReLU(),
                        nn.BatchNorm1d(hidden),
                    ),
                    train_eps=False))
        self.lin1 = torch.nn.Linear(num_layers * hidden, hidden)
        self.lin2 = nn.Linear(hidden, t_dim)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        for conv in self.convs:
            conv.reset_parameters()
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()

    def forward(self, x, adj, batch):
        edge_index = adj._indices()
        x = self.conv1(x, edge_index)
        xs = [x]
        for conv in self.convs:
            x = conv(x, edge_index)
            xs += [x]
        x = global_mean_pool(torch.cat(xs, dim=1), batch)
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        return self.lin2(x)

    def __repr__(self):
        return self.__class__.__name__

# initialize one model for each dataset
models["supervised_gat_large"] = lambda y_dim, t_dim : GATSupervised(y_dim, t_dim, dim=16, n_layers=3)
models["supervised_gin0_large"] = lambda y_dim, t_dim : GIN0(y_dim, t_dim, hidden=64)
models["supervised_topk"] = lambda y_dim, t_dim : Topk(y_dim, t_dim)
#models["supervised_gat_small"] = lambda y_dim, t_dim : GATSupervised(y_dim, t_dim, dim=8, n_layers=2)
#models["supervised_gin0_small"] = lambda y_dim, t_dim : GIN0(y_dim, t_dim, hidden=32)

# %%
from utils.helpers import count_parameters
for k,v in models.items():
    print(k, "- N Param:", count_parameters(v(y_dim=20, t_dim=5)))
# Out:
# supervised_gat_large - N Param: 53189
# supervised_gin0_large - N Param: 60293
# supervised_topk - N Param: 112901

# %%
from skssl.transformers.neuralproc.datasplit import GridCntxtTrgtGetter, RandomMasker, no_masker, half_masker
from utils.data.tsdata import get_timeseries_dataset, SparseMultiTimeSeriesDataset
import torch
import skorch
from torch_geometric.data import Batch
class SkorchDataLoader(torch.utils.data.DataLoader):
    def _collate_fn(self, data_list, follow_batch=[]):
        data = Batch.from_data_list(data_list, follow_batch)
        edge_attr = torch.ones_like(data.edge_index[0], dtype=torch.float) if data.edge_attr is None else data.edge_attr
        
        # Can't pass a Dataset directly, since it expects tensors. 
        # Use dict of tensors instead. Also, use torch.sparse for 
        # adjacency matrix to pass skorch's same-dimension check
        return {
            'x': data.x,
            'adj': torch.sparse.FloatTensor(data.edge_index, 
                                            edge_attr, 
                                            size=[data.num_nodes, data.num_nodes], 
                                            device=data.x.device),
            'batch': data.batch
        }, data.y
    
    def __init__(self,
                 dataset,
                 batch_size=1,
                 shuffle=True,
                 follow_batch=[],
                 **kwargs):
        super(SkorchDataLoader, self).__init__(
            dataset,
            batch_size,
            shuffle,
            collate_fn=lambda data_list: self._collate_fn(data_list, follow_batch),
            **kwargs)
        
class SkorchDataset(skorch.dataset.Dataset):
    def __init__(self, X, y):
        # We need to specify `length` to avoid checks
        super(SkorchDataset, self).__init__(X, y, length=len(X))
    
    def transform(self, X, y):
        return X   # Ignore y, since it is included in X

# %% [markdown]
# # Training

# %%
N_EPOCHS = 100 
BATCH_SIZE = 32
IS_RETRAIN = False # if false load precomputed
chckpnt_dirname="results/notebooks/neural_process_graph/"

from ntbks_helpers import train_models_

# %%
import random

data_trainers = {}
data_keys = datasets.keys()

for label_perc in label_percentages[::-1]:
    for run in range(10):
        for name_mod in models.keys():
            for data_name in data_keys:

                datasets=dict(enzymes = TUDataset(root='data/ENZYMES', name='ENZYMES', use_node_attr=True),
                             proteins = TUDataset(root='data/PROTEINS_full', name='PROTEINS_full', use_node_attr=True),
                         synthie = TUDataset(root='data/Synthie', name='Synthie', use_node_attr=True))

                data_specific_kwargs = {k:dict(y_dim=d.num_node_features,
                                               t_dim=d.num_classes
                                              ) 
                                        for k,d in datasets.items()}
                # should store the split
                datasets = {k:ssl_graph(train_test_split(d), label_perc=label_perc, is_add_test=False, is_augment=False) 
                                for k,d in datasets.items()if k == data_name}

                print("label perc test:", np.array([x.y != -1 for x in datasets[data_name][0]]).mean())

                data_trainers.update(train_models_({k:d for k,d in datasets.items()}, 
                                       {k+ "_lab{}%_run{}".format(label_perc, run):m  for k,m in models.items() if name_mod == k},
                                      criterion=partial(nn.CrossEntropyLoss, ignore_index=-1),
                                        data_specific_kwargs=data_specific_kwargs,
                                     patience=15,
                                     chckpnt_dirname=chckpnt_dirname,
                                      max_epochs=N_EPOCHS,
                                      batch_size=BATCH_SIZE,
                                      is_retrain=IS_RETRAIN,
                                      callbacks=[],
                                                   seed=random.randint(0,10000),
                                      iterator_train=SkorchDataLoader,
                                    iterator_valid=SkorchDataLoader,
                                    dataset=SkorchDataset,
                                                   is_monitor_acc=True,
                                      mode="classifier"))
# Out:
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run0 ---
#
# enzymes/supervised_gat_large_lab1%_run0 best epoch: 27 val_loss: 1.333056089922282
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run0 ---
#
# proteins/supervised_gat_large_lab1%_run0 best epoch: 19 val_loss: 0.4450531373051857
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run0 ---
#
# synthie/supervised_gat_large_lab1%_run0 best epoch: 11 val_loss: 1.2429730469786275
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run0 ---
#
# enzymes/supervised_gin0_large_lab1%_run0 best epoch: 11 val_loss: 1.2847857066293016
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run0 ---
#
# proteins/supervised_gin0_large_lab1%_run0 best epoch: 5 val_loss: 0.48654540174728866
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run0 ---
#
# synthie/supervised_gin0_large_lab1%_run0 best epoch: 4 val_loss: 1.2884178859582218
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run0 ---
#
# enzymes/supervised_topk_lab1%_run0 best epoch: 20 val_loss: 1.27866411121194
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run0 ---
#
# proteins/supervised_topk_lab1%_run0 best epoch: 21 val_loss: 0.5020774744207989
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run0 ---
#
# synthie/supervised_topk_lab1%_run0 best epoch: 16 val_loss: 1.2331990718841552
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run1 ---
#
# enzymes/supervised_gat_large_lab1%_run1 best epoch: 20 val_loss: 1.44608872124009
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run1 ---
#
# proteins/supervised_gat_large_lab1%_run1 best epoch: 18 val_loss: 0.4424575634159505
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run1 ---
#
# synthie/supervised_gat_large_lab1%_run1 best epoch: 17 val_loss: 1.2068536951940319
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run1 ---
#
# enzymes/supervised_gin0_large_lab1%_run1 best epoch: 15 val_loss: 1.0961822557935672
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run1 ---
#
# proteins/supervised_gin0_large_lab1%_run1 best epoch: 14 val_loss: 0.5650824114118168
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run1 ---
#
# synthie/supervised_gin0_large_lab1%_run1 best epoch: 6 val_loss: 1.224953833214567
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run1 ---
#
# enzymes/supervised_topk_lab1%_run1 best epoch: 27 val_loss: 1.1630069216690868
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run1 ---
#
# proteins/supervised_topk_lab1%_run1 best epoch: 4 val_loss: 0.49880857775386145
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run1 ---
#
# synthie/supervised_topk_lab1%_run1 best epoch: 68 val_loss: 0.26481130562330546
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run2 ---
#
# enzymes/supervised_gat_large_lab1%_run2 best epoch: 36 val_loss: 1.2588800919067753
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run2 ---
#
# proteins/supervised_gat_large_lab1%_run2 best epoch: 30 val_loss: 0.3572768750741626
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run2 ---
#
# synthie/supervised_gat_large_lab1%_run2 best epoch: 15 val_loss: 1.0863807750375647
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run2 ---
#
# enzymes/supervised_gin0_large_lab1%_run2 best epoch: 12 val_loss: 1.3551458311057316
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run2 ---
#
# proteins/supervised_gin0_large_lab1%_run2 best epoch: 5 val_loss: 0.5592754351205316
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run2 ---
#
# synthie/supervised_gin0_large_lab1%_run2 best epoch: 16 val_loss: 1.2633693411712248
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run2 ---
#
# enzymes/supervised_topk_lab1%_run2 best epoch: 19 val_loss: 1.5285428796802556
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run2 ---
#
# proteins/supervised_topk_lab1%_run2 best epoch: 17 val_loss: 0.4649067714183687
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run2 ---
#
# synthie/supervised_topk_lab1%_run2 best epoch: 36 val_loss: 0.6326121498668005
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run3 ---
#
# enzymes/supervised_gat_large_lab1%_run3 best epoch: 39 val_loss: 1.1933819646182195
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run3 ---
#
# proteins/supervised_gat_large_lab1%_run3 best epoch: 13 val_loss: 0.48052339496639573
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run3 ---
#
# synthie/supervised_gat_large_lab1%_run3 best epoch: 15 val_loss: 1.1262234155315936
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run3 ---
#
# enzymes/supervised_gin0_large_lab1%_run3 best epoch: 12 val_loss: 1.140825607737557
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run3 ---
#
# proteins/supervised_gin0_large_lab1%_run3 best epoch: 5 val_loss: 0.4586674529648782
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run3 ---
#
# synthie/supervised_gin0_large_lab1%_run3 best epoch: 3 val_loss: 1.3122402093912426
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run3 ---
#
# enzymes/supervised_topk_lab1%_run3 best epoch: 15 val_loss: 1.0863166488481786
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run3 ---
#
# proteins/supervised_topk_lab1%_run3 best epoch: 10 val_loss: 0.5594008487632983
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run3 ---
#
# synthie/supervised_topk_lab1%_run3 best epoch: 7 val_loss: 1.3387047473862177
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run4 ---
#
# enzymes/supervised_gat_large_lab1%_run4 best epoch: 62 val_loss: 1.1425450799066268
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run4 ---
#
# proteins/supervised_gat_large_lab1%_run4 best epoch: 24 val_loss: 0.4664960185861248
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run4 ---
#
# synthie/supervised_gat_large_lab1%_run4 best epoch: 15 val_loss: 1.2298019714555715
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run4 ---
#
# enzymes/supervised_gin0_large_lab1%_run4 best epoch: 10 val_loss: 1.3026072209469772
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run4 ---
#
# proteins/supervised_gin0_large_lab1%_run4 best epoch: 10 val_loss: 0.5720005566386333
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run4 ---
#
# synthie/supervised_gin0_large_lab1%_run4 best epoch: 5 val_loss: 1.3062706538072721
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run4 ---
#
# enzymes/supervised_topk_lab1%_run4 best epoch: 17 val_loss: 1.477212762160874
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run4 ---
#
# proteins/supervised_topk_lab1%_run4 best epoch: 9 val_loss: 0.4713459417729342
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run4 ---
#
# synthie/supervised_topk_lab1%_run4 best epoch: 29 val_loss: 0.4228686381298508
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run5 ---
#
# enzymes/supervised_gat_large_lab1%_run5 best epoch: 11 val_loss: 1.7587204051485719
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run5 ---
#
# proteins/supervised_gat_large_lab1%_run5 best epoch: 8 val_loss: 0.5546846512952488
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run5 ---
#
# synthie/supervised_gat_large_lab1%_run5 best epoch: 18 val_loss: 1.128772445910953
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run5 ---
#
# enzymes/supervised_gin0_large_lab1%_run5 best epoch: 9 val_loss: 1.2407321220808858
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run5 ---
#
# proteins/supervised_gin0_large_lab1%_run5 best epoch: 2 val_loss: 0.5921181300610446
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run5 ---
#
# synthie/supervised_gin0_large_lab1%_run5 best epoch: 14 val_loss: 0.9847901107777968
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run5 ---
#
# enzymes/supervised_topk_lab1%_run5 best epoch: 17 val_loss: 1.277904800459987
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run5 ---
#
# proteins/supervised_topk_lab1%_run5 best epoch: 13 val_loss: 0.4587379825324868
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run5 ---
#
# synthie/supervised_topk_lab1%_run5 best epoch: 38 val_loss: 0.7400394499771238
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run6 ---
#
# enzymes/supervised_gat_large_lab1%_run6 best epoch: 64 val_loss: 0.9403902288475464
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run6 ---
#
# proteins/supervised_gat_large_lab1%_run6 best epoch: 11 val_loss: 0.4229430837154388
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run6 ---
#
# synthie/supervised_gat_large_lab1%_run6 best epoch: 23 val_loss: 1.3124746322631835
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run6 ---
#
# enzymes/supervised_gin0_large_lab1%_run6 best epoch: 10 val_loss: 1.2853448601939794
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run6 ---
#
# proteins/supervised_gin0_large_lab1%_run6 best epoch: 5 val_loss: 0.4991506223088653
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run6 ---
#
# synthie/supervised_gin0_large_lab1%_run6 best epoch: 41 val_loss: 0.8521925477769362
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run6 ---
#
# enzymes/supervised_topk_lab1%_run6 best epoch: 12 val_loss: 1.4305880773858297
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run6 ---
#
# proteins/supervised_topk_lab1%_run6 best epoch: 4 val_loss: 0.5443815558958464
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run6 ---
#
# synthie/supervised_topk_lab1%_run6 best epoch: 13 val_loss: 0.5460121139647469
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run7 ---
#
# enzymes/supervised_gat_large_lab1%_run7 best epoch: 38 val_loss: 1.1890093287559187
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run7 ---
#
# proteins/supervised_gat_large_lab1%_run7 best epoch: 10 val_loss: 0.43253980233027056
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run7 ---
#
# synthie/supervised_gat_large_lab1%_run7 best epoch: 9 val_loss: 1.2923668701604678
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run7 ---
#
# enzymes/supervised_gin0_large_lab1%_run7 best epoch: 12 val_loss: 1.1830626227081025
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run7 ---
#
# proteins/supervised_gin0_large_lab1%_run7 best epoch: 6 val_loss: 0.5105901108824087
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run7 ---
#
# synthie/supervised_gin0_large_lab1%_run7 best epoch: 4 val_loss: 1.363839655719322
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run7 ---
#
# enzymes/supervised_topk_lab1%_run7 best epoch: 18 val_loss: 1.200576353767918
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run7 ---
#
# proteins/supervised_topk_lab1%_run7 best epoch: 10 val_loss: 0.5150860045857848
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run7 ---
#
# synthie/supervised_topk_lab1%_run7 best epoch: 17 val_loss: 0.9038196311642727
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run8 ---
#
# enzymes/supervised_gat_large_lab1%_run8 best epoch: 3 val_loss: 1.7412697748737114
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run8 ---
#
# proteins/supervised_gat_large_lab1%_run8 best epoch: 4 val_loss: 0.46440074745384424
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run8 ---
#
# synthie/supervised_gat_large_lab1%_run8 best epoch: 15 val_loss: 1.1340636059089944
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run8 ---
#
# enzymes/supervised_gin0_large_lab1%_run8 best epoch: 20 val_loss: 1.4814449295703154
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run8 ---
#
# proteins/supervised_gin0_large_lab1%_run8 best epoch: 3 val_loss: 0.5472026667897224
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run8 ---
#
# synthie/supervised_gin0_large_lab1%_run8 best epoch: 5 val_loss: 1.26248126835018
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run8 ---
#
# enzymes/supervised_topk_lab1%_run8 best epoch: 25 val_loss: 1.1640929242143105
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run8 ---
#
# proteins/supervised_topk_lab1%_run8 best epoch: 4 val_loss: 0.47079534623189156
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run8 ---
#
# synthie/supervised_topk_lab1%_run8 best epoch: 25 val_loss: 0.7725519180297852
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gat_large_lab1%_run9 ---
#
# enzymes/supervised_gat_large_lab1%_run9 best epoch: 90 val_loss: 1.029073908053959
# label perc test: 1.0
#
# --- Loading proteins/supervised_gat_large_lab1%_run9 ---
#
# proteins/supervised_gat_large_lab1%_run9 best epoch: 9 val_loss: 0.5310596549129336
# label perc test: 1.0
#
# --- Loading synthie/supervised_gat_large_lab1%_run9 ---
#
# synthie/supervised_gat_large_lab1%_run9 best epoch: 20 val_loss: 1.039165978307848
# label perc test: 1.0
#
# --- Loading enzymes/supervised_gin0_large_lab1%_run9 ---
#
# enzymes/supervised_gin0_large_lab1%_run9 best epoch: 17 val_loss: 1.2734109748925948
# label perc test: 1.0
#
# --- Loading proteins/supervised_gin0_large_lab1%_run9 ---
#
# proteins/supervised_gin0_large_lab1%_run9 best epoch: 7 val_loss: 0.524594067425246
# label perc test: 1.0
#
# --- Loading synthie/supervised_gin0_large_lab1%_run9 ---
#
# synthie/supervised_gin0_large_lab1%_run9 best epoch: 27 val_loss: 1.2400603416397815
# label perc test: 1.0
#
# --- Loading enzymes/supervised_topk_lab1%_run9 ---
#
# enzymes/supervised_topk_lab1%_run9 best epoch: 45 val_loss: 1.1446998360913092
# label perc test: 1.0
#
# --- Loading proteins/supervised_topk_lab1%_run9 ---
#
# proteins/supervised_topk_lab1%_run9 best epoch: 3 val_loss: 0.5412531819878488
# label perc test: 1.0
#
# --- Loading synthie/supervised_topk_lab1%_run9 ---
#
# synthie/supervised_topk_lab1%_run9 best epoch: 14 val_loss: 0.883914137724787
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run0 ---
#
# enzymes/supervised_gat_large_lab0.5%_run0 best epoch: 33 val_loss: 1.4515483354631795
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run0 ---
#
# proteins/supervised_gat_large_lab0.5%_run0 best epoch: 3 val_loss: 0.5747228274393061
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run0 ---
#
# synthie/supervised_gat_large_lab0.5%_run0 best epoch: 15 val_loss: 1.307006150484085
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run0 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run0 best epoch: 7 val_loss: 1.6508292330431495
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run0 ---
#
# proteins/supervised_gin0_large_lab0.5%_run0 best epoch: 10 val_loss: 0.5640446897781694
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run0 ---
#
# synthie/supervised_gin0_large_lab0.5%_run0 best epoch: 1 val_loss: 1.3807585128738646
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run0 ---
#
# enzymes/supervised_topk_lab0.5%_run0 best epoch: 12 val_loss: 1.152609171958015
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run0 ---
#
# proteins/supervised_topk_lab0.5%_run0 best epoch: 17 val_loss: 0.5156495499255535
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run0 ---
#
# synthie/supervised_topk_lab0.5%_run0 best epoch: 21 val_loss: 1.3420811723040036
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run1 ---
#
# enzymes/supervised_gat_large_lab0.5%_run1 best epoch: 17 val_loss: 1.7072968741632857
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run1 ---
#
# proteins/supervised_gat_large_lab0.5%_run1 best epoch: 14 val_loss: 0.5558458767628589
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run1 ---
#
# synthie/supervised_gat_large_lab0.5%_run1 best epoch: 9 val_loss: 1.3505975443219382
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run1 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run1 best epoch: 11 val_loss: 1.5160312238854312
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run1 ---
#
# proteins/supervised_gin0_large_lab0.5%_run1 best epoch: 8 val_loss: 0.548702407853377
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run1 ---
#
# synthie/supervised_gin0_large_lab0.5%_run1 best epoch: 4 val_loss: 1.2137953472764869
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run1 ---
#
# enzymes/supervised_topk_lab0.5%_run1 best epoch: 12 val_loss: 1.5947247220623877
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run1 ---
#
# proteins/supervised_topk_lab0.5%_run1 best epoch: 10 val_loss: 0.5481218252885008
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run1 ---
#
# synthie/supervised_topk_lab0.5%_run1 best epoch: 12 val_loss: 0.7113120557442112
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run2 ---
#
# enzymes/supervised_gat_large_lab0.5%_run2 best epoch: 5 val_loss: 1.6948572309425725
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run2 ---
#
# proteins/supervised_gat_large_lab0.5%_run2 best epoch: 9 val_loss: 0.4758545661160213
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run2 ---
#
# synthie/supervised_gat_large_lab0.5%_run2 best epoch: 11 val_loss: 1.3438840953529982
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run2 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run2 best epoch: 6 val_loss: 1.3392932499506716
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run2 ---
#
# proteins/supervised_gin0_large_lab0.5%_run2 best epoch: 5 val_loss: 0.5743788637095429
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run2 ---
#
# synthie/supervised_gin0_large_lab0.5%_run2 best epoch: 7 val_loss: 1.1787138127521748
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run2 ---
#
# enzymes/supervised_topk_lab0.5%_run2 best epoch: 34 val_loss: 1.2906812442863573
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run2 ---
#
# proteins/supervised_topk_lab0.5%_run2 best epoch: 5 val_loss: 0.8125529059610246
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run2 ---
#
# synthie/supervised_topk_lab0.5%_run2 best epoch: 32 val_loss: 0.8682781653989389
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run3 ---
#
# enzymes/supervised_gat_large_lab0.5%_run3 best epoch: 29 val_loss: 1.5827962819698014
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run3 ---
#
# proteins/supervised_gat_large_lab0.5%_run3 best epoch: 11 val_loss: 0.5029370076971093
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run3 ---
#
# synthie/supervised_gat_large_lab0.5%_run3 best epoch: 33 val_loss: 1.0895908419878313
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run3 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run3 best epoch: 36 val_loss: 1.2839098108931402
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run3 ---
#
# proteins/supervised_gin0_large_lab0.5%_run3 best epoch: 5 val_loss: 0.5658798175475366
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run3 ---
#
# synthie/supervised_gin0_large_lab0.5%_run3 best epoch: 4 val_loss: 1.2946158322136545
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run3 ---
#
# enzymes/supervised_topk_lab0.5%_run3 best epoch: 21 val_loss: 1.4783947041772976
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run3 ---
#
# proteins/supervised_topk_lab0.5%_run3 best epoch: 3 val_loss: 0.5733531745884263
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run3 ---
#
# synthie/supervised_topk_lab0.5%_run3 best epoch: 27 val_loss: 0.6520459329801813
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run4 ---
#
# enzymes/supervised_gat_large_lab0.5%_run4 best epoch: 31 val_loss: 1.5116117965324996
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run4 ---
#
# proteins/supervised_gat_large_lab0.5%_run4 best epoch: 12 val_loss: 0.4115649135380162
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run4 ---
#
# synthie/supervised_gat_large_lab0.5%_run4 best epoch: 19 val_loss: 1.3410714268684387
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run4 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run4 best epoch: 27 val_loss: 1.4121476411819458
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run4 ---
#
# proteins/supervised_gin0_large_lab0.5%_run4 best epoch: 12 val_loss: 0.5574118427717923
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run4 ---
#
# synthie/supervised_gin0_large_lab0.5%_run4 best epoch: 2 val_loss: 1.3157574077869982
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run4 ---
#
# enzymes/supervised_topk_lab0.5%_run4 best epoch: 34 val_loss: 1.323622815064558
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run4 ---
#
# proteins/supervised_topk_lab0.5%_run4 best epoch: 6 val_loss: 0.4789142785637079
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run4 ---
#
# synthie/supervised_topk_lab0.5%_run4 best epoch: 22 val_loss: 0.8295434442574922
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run5 ---
#
# enzymes/supervised_gat_large_lab0.5%_run5 best epoch: 26 val_loss: 1.401635358445957
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run5 ---
#
# proteins/supervised_gat_large_lab0.5%_run5 best epoch: 18 val_loss: 0.44234067812059535
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run5 ---
#
# synthie/supervised_gat_large_lab0.5%_run5 best epoch: 13 val_loss: 1.2352193913121863
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run5 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run5 best epoch: 7 val_loss: 1.534407604025408
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run5 ---
#
# proteins/supervised_gin0_large_lab0.5%_run5 best epoch: 2 val_loss: 0.6853963753362854
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run5 ---
#
# synthie/supervised_gin0_large_lab0.5%_run5 best epoch: 8 val_loss: 1.201576818262367
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run5 ---
#
# enzymes/supervised_topk_lab0.5%_run5 best epoch: 11 val_loss: 1.6265361989753833
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run5 ---
#
# proteins/supervised_topk_lab0.5%_run5 best epoch: 13 val_loss: 0.5073711012059712
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run5 ---
#
# synthie/supervised_topk_lab0.5%_run5 best epoch: 5 val_loss: 1.3639794807929497
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run6 ---
#
# enzymes/supervised_gat_large_lab0.5%_run6 best epoch: 5 val_loss: 1.7184106807699318
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run6 ---
#
# proteins/supervised_gat_large_lab0.5%_run6 best epoch: 14 val_loss: 0.49538643483942824
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run6 ---
#
# synthie/supervised_gat_large_lab0.5%_run6 best epoch: 7 val_loss: 1.339744625268159
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run6 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run6 best epoch: 5 val_loss: 1.6149052445159067
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run6 ---
#
# proteins/supervised_gin0_large_lab0.5%_run6 best epoch: 5 val_loss: 0.49811599779560073
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run6 ---
#
# synthie/supervised_gin0_large_lab0.5%_run6 best epoch: 2 val_loss: 1.3739478160334766
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run6 ---
#
# enzymes/supervised_topk_lab0.5%_run6 best epoch: 15 val_loss: 1.140702968115335
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run6 ---
#
# proteins/supervised_topk_lab0.5%_run6 best epoch: 11 val_loss: 0.4831573669109192
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run6 ---
#
# synthie/supervised_topk_lab0.5%_run6 best epoch: 25 val_loss: 1.1263355480300055
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run7 ---
#
# enzymes/supervised_gat_large_lab0.5%_run7 best epoch: 45 val_loss: 1.4512570258139013
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run7 ---
#
# proteins/supervised_gat_large_lab0.5%_run7 best epoch: 6 val_loss: 0.5688191761947344
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run7 ---
#
# synthie/supervised_gat_large_lab0.5%_run7 best epoch: 28 val_loss: 1.045873854368452
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run7 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run7 best epoch: 9 val_loss: 1.4817104375484038
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run7 ---
#
# proteins/supervised_gin0_large_lab0.5%_run7 best epoch: 3 val_loss: 0.5644944544936803
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run7 ---
#
# synthie/supervised_gin0_large_lab0.5%_run7 best epoch: 4 val_loss: 1.2795611099192972
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run7 ---
#
# enzymes/supervised_topk_lab0.5%_run7 best epoch: 30 val_loss: 1.2343687906792635
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run7 ---
#
# proteins/supervised_topk_lab0.5%_run7 best epoch: 2 val_loss: 0.526936121725501
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run7 ---
#
# synthie/supervised_topk_lab0.5%_run7 best epoch: 15 val_loss: 1.019374756196558
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run8 ---
#
# enzymes/supervised_gat_large_lab0.5%_run8 best epoch: 27 val_loss: 1.383861177907127
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run8 ---
#
# proteins/supervised_gat_large_lab0.5%_run8 best epoch: 10 val_loss: 0.6092634134655895
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run8 ---
#
# synthie/supervised_gat_large_lab0.5%_run8 best epoch: 10 val_loss: 1.3033136628685198
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run8 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run8 best epoch: 9 val_loss: 1.4621420756339034
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run8 ---
#
# proteins/supervised_gin0_large_lab0.5%_run8 best epoch: 5 val_loss: 0.504476533674701
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run8 ---
#
# synthie/supervised_gin0_large_lab0.5%_run8 best epoch: 4 val_loss: 1.267095775046247
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run8 ---
#
# enzymes/supervised_topk_lab0.5%_run8 best epoch: 27 val_loss: 1.0619116608913128
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run8 ---
#
# proteins/supervised_topk_lab0.5%_run8 best epoch: 9 val_loss: 0.49255218965324327
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run8 ---
#
# synthie/supervised_topk_lab0.5%_run8 best epoch: 8 val_loss: 0.9519792553037405
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gat_large_lab0.5%_run9 ---
#
# enzymes/supervised_gat_large_lab0.5%_run9 best epoch: 62 val_loss: 1.2014043390037057
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gat_large_lab0.5%_run9 ---
#
# proteins/supervised_gat_large_lab0.5%_run9 best epoch: 4 val_loss: 0.44653370617772375
# label perc test: 0.5
#
# --- Loading synthie/supervised_gat_large_lab0.5%_run9 ---
#
# synthie/supervised_gat_large_lab0.5%_run9 best epoch: 26 val_loss: 0.9831210649572313
# label perc test: 0.5
#
# --- Loading enzymes/supervised_gin0_large_lab0.5%_run9 ---
#
# enzymes/supervised_gin0_large_lab0.5%_run9 best epoch: 4 val_loss: 1.4484040780560126
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_gin0_large_lab0.5%_run9 ---
#
# proteins/supervised_gin0_large_lab0.5%_run9 best epoch: 9 val_loss: 0.478286271551618
# label perc test: 0.5
#
# --- Loading synthie/supervised_gin0_large_lab0.5%_run9 ---
#
# synthie/supervised_gin0_large_lab0.5%_run9 best epoch: 5 val_loss: 1.2946994017789708
# label perc test: 0.5
#
# --- Loading enzymes/supervised_topk_lab0.5%_run9 ---
#
# enzymes/supervised_topk_lab0.5%_run9 best epoch: 12 val_loss: 1.5589061330270895
# label perc test: 0.5004995004995005
#
# --- Loading proteins/supervised_topk_lab0.5%_run9 ---
#
# proteins/supervised_topk_lab0.5%_run9 best epoch: 8 val_loss: 0.5280788375976238
# label perc test: 0.5
#
# --- Loading synthie/supervised_topk_lab0.5%_run9 ---
#
# synthie/supervised_topk_lab0.5%_run9 best epoch: 12 val_loss: 0.9046898199435003
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run0 ---
#
# enzymes/supervised_gat_large_lab0.3%_run0 best epoch: 29 val_loss: 1.620949004135058
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run0 ---
#
# proteins/supervised_gat_large_lab0.3%_run0 best epoch: 4 val_loss: 0.5557287610102538
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run0 ---
#
# synthie/supervised_gat_large_lab0.3%_run0 best epoch: 14 val_loss: 1.326248166402181
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run0 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run0 best epoch: 10 val_loss: 1.4065983558224127
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run0 ---
#
# proteins/supervised_gin0_large_lab0.3%_run0 best epoch: 7 val_loss: 0.555198014636092
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run0 ---
#
# synthie/supervised_gin0_large_lab0.3%_run0 best epoch: 2 val_loss: 1.3654975569685093
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run0 ---
#
# enzymes/supervised_topk_lab0.3%_run0 best epoch: 12 val_loss: 1.6108049840905412
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run0 ---
#
# proteins/supervised_topk_lab0.3%_run0 best epoch: 4 val_loss: 0.5356870924350116
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run0 ---
#
# synthie/supervised_topk_lab0.3%_run0 best epoch: 11 val_loss: 1.2686918136921335
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run1 ---
#
# enzymes/supervised_gat_large_lab0.3%_run1 best epoch: 36 val_loss: 1.5020246496836345
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run1 ---
#
# proteins/supervised_gat_large_lab0.3%_run1 best epoch: 14 val_loss: 0.4943531536535138
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run1 ---
#
# synthie/supervised_gat_large_lab0.3%_run1 best epoch: 30 val_loss: 1.2253123774578434
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run1 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run1 best epoch: 9 val_loss: 1.4314727837712342
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run1 ---
#
# proteins/supervised_gin0_large_lab0.3%_run1 best epoch: 2 val_loss: 0.6206601472584975
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run1 ---
#
# synthie/supervised_gin0_large_lab0.3%_run1 best epoch: 3 val_loss: 1.3381326314956343
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run1 ---
#
# enzymes/supervised_topk_lab0.3%_run1 best epoch: 15 val_loss: 1.7045543032387893
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run1 ---
#
# proteins/supervised_topk_lab0.3%_run1 best epoch: 6 val_loss: 0.5503227212940905
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run1 ---
#
# synthie/supervised_topk_lab0.3%_run1 best epoch: 19 val_loss: 0.8033830115261177
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run2 ---
#
# enzymes/supervised_gat_large_lab0.3%_run2 best epoch: 57 val_loss: 1.3522506028559624
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run2 ---
#
# proteins/supervised_gat_large_lab0.3%_run2 best epoch: 5 val_loss: 0.5615244866249525
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run2 ---
#
# synthie/supervised_gat_large_lab0.3%_run2 best epoch: 61 val_loss: 1.212681219985448
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run2 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run2 best epoch: 15 val_loss: 1.5044539750201031
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run2 ---
#
# proteins/supervised_gin0_large_lab0.3%_run2 best epoch: 1 val_loss: 0.6535360782675477
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run2 ---
#
# synthie/supervised_gin0_large_lab0.3%_run2 best epoch: 3 val_loss: 1.3481911587526427
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run2 ---
#
# enzymes/supervised_topk_lab0.3%_run2 best epoch: 9 val_loss: 1.7507157139871075
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run2 ---
#
# proteins/supervised_topk_lab0.3%_run2 best epoch: 3 val_loss: 0.5625065614668836
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run2 ---
#
# synthie/supervised_topk_lab0.3%_run2 best epoch: 13 val_loss: 0.7643977398922701
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run3 ---
#
# enzymes/supervised_gat_large_lab0.3%_run3 best epoch: 37 val_loss: 1.3924521032229875
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run3 ---
#
# proteins/supervised_gat_large_lab0.3%_run3 best epoch: 7 val_loss: 0.5311745386799972
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run3 ---
#
# synthie/supervised_gat_large_lab0.3%_run3 best epoch: 13 val_loss: 1.1604762224387621
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run3 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run3 best epoch: 13 val_loss: 1.4732316211612526
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run3 ---
#
# proteins/supervised_gin0_large_lab0.3%_run3 best epoch: 1 val_loss: 0.6164362522142718
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run3 ---
#
# synthie/supervised_gin0_large_lab0.3%_run3 best epoch: 4 val_loss: 1.3818092057481408
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run3 ---
#
# enzymes/supervised_topk_lab0.3%_run3 best epoch: 22 val_loss: 1.670900395740498
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run3 ---
#
# proteins/supervised_topk_lab0.3%_run3 best epoch: 4 val_loss: 0.5983721593101321
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run3 ---
#
# synthie/supervised_topk_lab0.3%_run3 best epoch: 32 val_loss: 0.8674675279124288
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run4 ---
#
# enzymes/supervised_gat_large_lab0.3%_run4 best epoch: 17 val_loss: 1.6576676495035394
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run4 ---
#
# proteins/supervised_gat_large_lab0.3%_run4 best epoch: 7 val_loss: 0.5722295295842346
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run4 ---
#
# synthie/supervised_gat_large_lab0.3%_run4 best epoch: 17 val_loss: 1.1389580787496363
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run4 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run4 best epoch: 5 val_loss: 1.5788135697635322
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run4 ---
#
# proteins/supervised_gin0_large_lab0.3%_run4 best epoch: 2 val_loss: 0.5945767827836524
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run4 ---
#
# synthie/supervised_gin0_large_lab0.3%_run4 best epoch: 2 val_loss: 1.3340973680152184
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run4 ---
#
# enzymes/supervised_topk_lab0.3%_run4 best epoch: 20 val_loss: 1.7902351760054849
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run4 ---
#
# proteins/supervised_topk_lab0.3%_run4 best epoch: 2 val_loss: 0.6197631228595752
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run4 ---
#
# synthie/supervised_topk_lab0.3%_run4 best epoch: 15 val_loss: 1.1968595674785787
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run5 ---
#
# enzymes/supervised_gat_large_lab0.3%_run5 best epoch: 39 val_loss: 1.345746213163182
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run5 ---
#
# proteins/supervised_gat_large_lab0.3%_run5 best epoch: 9 val_loss: 0.580996385297992
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run5 ---
#
# synthie/supervised_gat_large_lab0.3%_run5 best epoch: 12 val_loss: 1.2979903410351465
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run5 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run5 best epoch: 8 val_loss: 1.5990879073026585
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run5 ---
#
# proteins/supervised_gin0_large_lab0.3%_run5 best epoch: 4 val_loss: 0.6389837309580159
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run5 ---
#
# synthie/supervised_gin0_large_lab0.3%_run5 best epoch: 2 val_loss: 1.3422157961552537
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run5 ---
#
# enzymes/supervised_topk_lab0.3%_run5 best epoch: 7 val_loss: 1.8530015718369257
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run5 ---
#
# proteins/supervised_topk_lab0.3%_run5 best epoch: 10 val_loss: 0.5045164696480453
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run5 ---
#
# synthie/supervised_topk_lab0.3%_run5 best epoch: 11 val_loss: 0.9656737309358714
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run6 ---
#
# enzymes/supervised_gat_large_lab0.3%_run6 best epoch: 30 val_loss: 1.6372558448375931
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run6 ---
#
# proteins/supervised_gat_large_lab0.3%_run6 best epoch: 8 val_loss: 0.5657544487914864
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run6 ---
#
# synthie/supervised_gat_large_lab0.3%_run6 best epoch: 27 val_loss: 1.2071708339129308
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run6 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run6 best epoch: 5 val_loss: 1.5753264238761524
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run6 ---
#
# proteins/supervised_gin0_large_lab0.3%_run6 best epoch: 3 val_loss: 0.654331553871746
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run6 ---
#
# synthie/supervised_gin0_large_lab0.3%_run6 best epoch: 5 val_loss: 1.2457401025892876
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run6 ---
#
# enzymes/supervised_topk_lab0.3%_run6 best epoch: 8 val_loss: 1.6598315495997666
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run6 ---
#
# proteins/supervised_topk_lab0.3%_run6 best epoch: 2 val_loss: 0.5469616108625018
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run6 ---
#
# synthie/supervised_topk_lab0.3%_run6 best epoch: 10 val_loss: 1.3558734383723692
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run7 ---
#
# enzymes/supervised_gat_large_lab0.3%_run7 best epoch: 4 val_loss: 1.787778720808986
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run7 ---
#
# proteins/supervised_gat_large_lab0.3%_run7 best epoch: 1 val_loss: 0.6734479610452947
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run7 ---
#
# synthie/supervised_gat_large_lab0.3%_run7 best epoch: 23 val_loss: 1.1638525305943168
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run7 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run7 best epoch: 8 val_loss: 1.2525558471679688
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run7 ---
#
# proteins/supervised_gin0_large_lab0.3%_run7 best epoch: 5 val_loss: 0.5555072066398908
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run7 ---
#
# synthie/supervised_gin0_large_lab0.3%_run7 best epoch: 2 val_loss: 1.347477095064364
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run7 ---
#
# enzymes/supervised_topk_lab0.3%_run7 best epoch: 17 val_loss: 1.8220527492013088
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run7 ---
#
# proteins/supervised_topk_lab0.3%_run7 best epoch: 5 val_loss: 0.5282050612890676
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run7 ---
#
# synthie/supervised_topk_lab0.3%_run7 best epoch: 16 val_loss: 1.3999945369605318
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run8 ---
#
# enzymes/supervised_gat_large_lab0.3%_run8 best epoch: 8 val_loss: 1.7507590977029373
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run8 ---
#
# proteins/supervised_gat_large_lab0.3%_run8 best epoch: 9 val_loss: 0.49581607814706846
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run8 ---
#
# synthie/supervised_gat_large_lab0.3%_run8 best epoch: 3 val_loss: 1.3812758019857483
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run8 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run8 best epoch: 13 val_loss: 1.3834492885476772
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run8 ---
#
# proteins/supervised_gin0_large_lab0.3%_run8 best epoch: 2 val_loss: 0.6449429305581801
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run8 ---
#
# synthie/supervised_gin0_large_lab0.3%_run8 best epoch: 4 val_loss: 1.3637284182743306
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run8 ---
#
# enzymes/supervised_topk_lab0.3%_run8 best epoch: 9 val_loss: 1.719841208980709
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run8 ---
#
# proteins/supervised_topk_lab0.3%_run8 best epoch: 3 val_loss: 0.810798969481134
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run8 ---
#
# synthie/supervised_topk_lab0.3%_run8 best epoch: 9 val_loss: 1.2071935187431913
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gat_large_lab0.3%_run9 ---
#
# enzymes/supervised_gat_large_lab0.3%_run9 best epoch: 10 val_loss: 1.6922145188009745
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gat_large_lab0.3%_run9 ---
#
# proteins/supervised_gat_large_lab0.3%_run9 best epoch: 8 val_loss: 0.5854409234535549
# label perc test: 0.3
#
# --- Loading synthie/supervised_gat_large_lab0.3%_run9 ---
#
# synthie/supervised_gat_large_lab0.3%_run9 best epoch: 33 val_loss: 1.1803588316748828
# label perc test: 0.3
#
# --- Loading enzymes/supervised_gin0_large_lab0.3%_run9 ---
#
# enzymes/supervised_gin0_large_lab0.3%_run9 best epoch: 8 val_loss: 1.5825799338671627
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_gin0_large_lab0.3%_run9 ---
#
# proteins/supervised_gin0_large_lab0.3%_run9 best epoch: 2 val_loss: 0.6146249752525605
# label perc test: 0.3
#
# --- Loading synthie/supervised_gin0_large_lab0.3%_run9 ---
#
# synthie/supervised_gin0_large_lab0.3%_run9 best epoch: 4 val_loss: 1.2422228795024042
# label perc test: 0.3
#
# --- Loading enzymes/supervised_topk_lab0.3%_run9 ---
#
# enzymes/supervised_topk_lab0.3%_run9 best epoch: 8 val_loss: 1.6770923188603282
# label perc test: 0.3006993006993007
#
# --- Loading proteins/supervised_topk_lab0.3%_run9 ---
#
# proteins/supervised_topk_lab0.3%_run9 best epoch: 3 val_loss: 0.667897039219408
# label perc test: 0.3
#
# --- Loading synthie/supervised_topk_lab0.3%_run9 ---
#
# synthie/supervised_topk_lab0.3%_run9 best epoch: 17 val_loss: 1.1609162023733552
# label perc test: 0.1
#
# --- Loading enzymes/supervised_gat_large_lab0.1%_run0 ---
#
# enzymes/supervised_gat_large_lab0.1%_run0 best epoch: 8 val_loss: 1.6965100303943017
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_gat_large_lab0.1%_run0 ---
#
# proteins/supervised_gat_large_lab0.1%_run0 best epoch: 3 val_loss: 0.6540130296152754
# label perc test: 0.1
#
# --- Loading synthie/supervised_gat_large_lab0.1%_run0 ---
#
# synthie/supervised_gat_large_lab0.1%_run0 best epoch: 13 val_loss: 1.3411064629727694
# label perc test: 0.1
#
# --- Loading enzymes/supervised_gin0_large_lab0.1%_run0 ---
#
# enzymes/supervised_gin0_large_lab0.1%_run0 best epoch: 6 val_loss: 1.6869017599861402
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_gin0_large_lab0.1%_run0 ---
#
# proteins/supervised_gin0_large_lab0.1%_run0 best epoch: 3 val_loss: 0.6383244732483206
# label perc test: 0.1
#
# --- Loading synthie/supervised_gin0_large_lab0.1%_run0 ---
#
# synthie/supervised_gin0_large_lab0.1%_run0 best epoch: 1 val_loss: 1.3688951020545148
# label perc test: 0.1
#
# --- Loading enzymes/supervised_topk_lab0.1%_run0 ---
#
# enzymes/supervised_topk_lab0.1%_run0 best epoch: 13 val_loss: 2.382015159561878
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_topk_lab0.1%_run0 ---
#
# proteins/supervised_topk_lab0.1%_run0 best epoch: 4 val_loss: 0.6160341136621468
# label perc test: 0.1
#
# --- Loading synthie/supervised_topk_lab0.1%_run0 ---
#
# synthie/supervised_topk_lab0.1%_run0 best epoch: 17 val_loss: 1.3854999523561244
# label perc test: 0.1
#
# --- Loading enzymes/supervised_gat_large_lab0.1%_run1 ---
#
# enzymes/supervised_gat_large_lab0.1%_run1 best epoch: 5 val_loss: 1.7099516489466682
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_gat_large_lab0.1%_run1 ---
#
# proteins/supervised_gat_large_lab0.1%_run1 best epoch: 4 val_loss: 0.6203491173620853
# label perc test: 0.1
#
# --- Loading synthie/supervised_gat_large_lab0.1%_run1 ---
#
# synthie/supervised_gat_large_lab0.1%_run1 best epoch: 17 val_loss: 1.3551669411771878
# label perc test: 0.1
#
# --- Loading enzymes/supervised_gin0_large_lab0.1%_run1 ---
#
# enzymes/supervised_gin0_large_lab0.1%_run1 best epoch: 4 val_loss: 1.6807944744918206
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_gin0_large_lab0.1%_run1 ---
#
# proteins/supervised_gin0_large_lab0.1%_run1 best epoch: 1 val_loss: 0.6869369181610419
# label perc test: 0.1
#
# --- Loading synthie/supervised_gin0_large_lab0.1%_run1 ---
#
# synthie/supervised_gin0_large_lab0.1%_run1 best epoch: 4 val_loss: 1.391614873365236
# label perc test: 0.1
#
# --- Loading enzymes/supervised_topk_lab0.1%_run1 ---
#
# enzymes/supervised_topk_lab0.1%_run1 best epoch: 11 val_loss: 1.8836238823075226
# label perc test: 0.1008991008991009
#
# --- Loading proteins/supervised_topk_lab0.1%_run1 ---
#
# proteins/supervised_topk_lab0.1%_run1 best epoch: 2 val_loss: 0.5671494899700765
# label perc test: 0.1
#
# --- Loading synthie/supervised_topk_lab0.1%_run1 ---
#
# synthie/supervised_topk_lab0.1%_run1 best epoch: 9 val_loss: 1.9103678319361304
# ...
#
# synthie/supervised_gat_large_lab0.01%_run0 best epoch: 1 val_loss: 1.3687495299034718
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run0 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run0 best epoch: 5 val_loss: 1.6731205940494676
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run0 ---
#
# proteins/supervised_gin0_large_lab0.01%_run0 best epoch: 2 val_loss: 0.6280018400371544
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run0 ---
#
# synthie/supervised_gin0_large_lab0.01%_run0 best epoch: 14 val_loss: 1.3425013175670137
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run0 ---
#
# enzymes/supervised_topk_lab0.01%_run0 best epoch: 3 val_loss: 3.7698224287492947
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run0 ---
#
# proteins/supervised_topk_lab0.01%_run0 best epoch: 5 val_loss: 2.1096928151288825
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run0 ---
#
# synthie/supervised_topk_lab0.01%_run0 best epoch: 12 val_loss: 1.7092674349745114
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run1 ---
#
# enzymes/supervised_gat_large_lab0.01%_run1 best epoch: 1 val_loss: 1.7863543252507132
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run1 ---
#
# proteins/supervised_gat_large_lab0.01%_run1 best epoch: 1 val_loss: 0.7837334459016579
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run1 ---
#
# synthie/supervised_gat_large_lab0.01%_run1 best epoch: 25 val_loss: 1.2980347778648138
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run1 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run1 best epoch: 1 val_loss: 1.7998105179031816
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run1 ---
#
# proteins/supervised_gin0_large_lab0.01%_run1 best epoch: 2 val_loss: 0.6919233918619085
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run1 ---
#
# synthie/supervised_gin0_large_lab0.01%_run1 best epoch: 2 val_loss: 1.381759844043038
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run1 ---
#
# enzymes/supervised_topk_lab0.01%_run1 best epoch: 3 val_loss: 4.120491315476657
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run1 ---
#
# proteins/supervised_topk_lab0.01%_run1 best epoch: 5 val_loss: 1.6920891398530071
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run1 ---
#
# synthie/supervised_topk_lab0.01%_run1 best epoch: 8 val_loss: 2.338221629045651
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run2 ---
#
# enzymes/supervised_gat_large_lab0.01%_run2 best epoch: 2 val_loss: 1.7832407554182552
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run2 ---
#
# proteins/supervised_gat_large_lab0.01%_run2 best epoch: 1 val_loss: 0.7026594299200473
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run2 ---
#
# synthie/supervised_gat_large_lab0.01%_run2 best epoch: 13 val_loss: 1.3779014673233032
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run2 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run2 best epoch: 1 val_loss: 1.7872422263863381
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run2 ---
#
# proteins/supervised_gin0_large_lab0.01%_run2 best epoch: 1 val_loss: 0.6583329419423921
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run2 ---
#
# synthie/supervised_gin0_large_lab0.01%_run2 best epoch: 4 val_loss: 1.3845033252426466
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run2 ---
#
# enzymes/supervised_topk_lab0.01%_run2 best epoch: 2 val_loss: 3.5975209317834254
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run2 ---
#
# proteins/supervised_topk_lab0.01%_run2 best epoch: 3 val_loss: 1.3362751963056452
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run2 ---
#
# synthie/supervised_topk_lab0.01%_run2 best epoch: 6 val_loss: 2.411360654425114
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run3 ---
#
# enzymes/supervised_gat_large_lab0.01%_run3 best epoch: 6 val_loss: 1.790752241452535
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run3 ---
#
# proteins/supervised_gat_large_lab0.01%_run3 best epoch: 1 val_loss: 0.6892483946111454
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run3 ---
#
# synthie/supervised_gat_large_lab0.01%_run3 best epoch: 16 val_loss: 1.3982256728941234
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run3 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run3 best epoch: 4 val_loss: 1.7658668858393523
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run3 ---
#
# proteins/supervised_gin0_large_lab0.01%_run3 best epoch: 1 val_loss: 0.6968312422600094
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run3 ---
#
# synthie/supervised_gin0_large_lab0.01%_run3 best epoch: 6 val_loss: 1.294490545280376
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run3 ---
#
# enzymes/supervised_topk_lab0.01%_run3 best epoch: 9 val_loss: 3.3802625693026043
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run3 ---
#
# proteins/supervised_topk_lab0.01%_run3 best epoch: 3 val_loss: 1.8109153933713664
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run3 ---
#
# synthie/supervised_topk_lab0.01%_run3 best epoch: 17 val_loss: 2.5532858669757843
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run4 ---
#
# enzymes/supervised_gat_large_lab0.01%_run4 best epoch: 1 val_loss: 1.7963918492870528
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run4 ---
#
# proteins/supervised_gat_large_lab0.01%_run4 best epoch: 1 val_loss: 0.6843625867578584
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run4 ---
#
# synthie/supervised_gat_large_lab0.01%_run4 best epoch: 22 val_loss: 1.2595632428332313
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run4 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run4 best epoch: 5 val_loss: 1.67457466656661
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run4 ---
#
# proteins/supervised_gin0_large_lab0.01%_run4 best epoch: 1 val_loss: 0.6917377477730173
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run4 ---
#
# synthie/supervised_gin0_large_lab0.01%_run4 best epoch: 5 val_loss: 1.3510913333037284
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run4 ---
#
# enzymes/supervised_topk_lab0.01%_run4 best epoch: 12 val_loss: 3.814911645391713
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run4 ---
#
# proteins/supervised_topk_lab0.01%_run4 best epoch: 2 val_loss: 1.0982486040369102
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run4 ---
#
# synthie/supervised_topk_lab0.01%_run4 best epoch: 8 val_loss: 2.2323575353244993
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run5 ---
#
# enzymes/supervised_gat_large_lab0.01%_run5 best epoch: 1 val_loss: 1.780623247087464
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run5 ---
#
# proteins/supervised_gat_large_lab0.01%_run5 best epoch: 2 val_loss: 0.6836774850645071
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run5 ---
#
# synthie/supervised_gat_large_lab0.01%_run5 best epoch: 1 val_loss: 1.3767756020303161
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run5 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run5 best epoch: 4 val_loss: 1.7924936650272363
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run5 ---
#
# proteins/supervised_gin0_large_lab0.01%_run5 best epoch: 3 val_loss: 0.6598343690824475
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run5 ---
#
# synthie/supervised_gin0_large_lab0.01%_run5 best epoch: 3 val_loss: 1.3626628387719393
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run5 ---
#
# enzymes/supervised_topk_lab0.01%_run5 best epoch: 4 val_loss: 3.7995307264346465
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run5 ---
#
# proteins/supervised_topk_lab0.01%_run5 best epoch: 3 val_loss: 1.4236607879346812
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run5 ---
#
# synthie/supervised_topk_lab0.01%_run5 best epoch: 14 val_loss: 2.1040077408673556
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run6 ---
#
# enzymes/supervised_gat_large_lab0.01%_run6 best epoch: 3 val_loss: 1.7897353732785064
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run6 ---
#
# proteins/supervised_gat_large_lab0.01%_run6 best epoch: 1 val_loss: 0.6875019807040557
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run6 ---
#
# synthie/supervised_gat_large_lab0.01%_run6 best epoch: 13 val_loss: 1.3653341988299756
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run6 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run6 best epoch: 1 val_loss: 1.785380597297962
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run6 ---
#
# proteins/supervised_gin0_large_lab0.01%_run6 best epoch: 1 val_loss: 0.6933360729033861
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run6 ---
#
# synthie/supervised_gin0_large_lab0.01%_run6 best epoch: 3 val_loss: 1.3716967991239513
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run6 ---
#
# enzymes/supervised_topk_lab0.01%_run6 best epoch: 3 val_loss: 3.7037982799027245
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run6 ---
#
# proteins/supervised_topk_lab0.01%_run6 best epoch: 9 val_loss: 1.7779107182984453
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run6 ---
#
# synthie/supervised_topk_lab0.01%_run6 best epoch: 35 val_loss: 2.4133933389474493
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run7 ---
#
# enzymes/supervised_gat_large_lab0.01%_run7 best epoch: 5 val_loss: 1.7392214003709068
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run7 ---
#
# proteins/supervised_gat_large_lab0.01%_run7 best epoch: 1 val_loss: 0.7000444792481986
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run7 ---
#
# synthie/supervised_gat_large_lab0.01%_run7 best epoch: 16 val_loss: 1.3423417516486356
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run7 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run7 best epoch: 1 val_loss: 1.7886794472031773
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run7 ---
#
# proteins/supervised_gin0_large_lab0.01%_run7 best epoch: 1 val_loss: 0.6732862339389545
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run7 ---
#
# synthie/supervised_gin0_large_lab0.01%_run7 best epoch: 8 val_loss: 1.292338447307977
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run7 ---
#
# enzymes/supervised_topk_lab0.01%_run7 best epoch: 6 val_loss: 3.9101391038283926
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run7 ---
#
# proteins/supervised_topk_lab0.01%_run7 best epoch: 3 val_loss: 1.2947847226408045
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run7 ---
#
# synthie/supervised_topk_lab0.01%_run7 best epoch: 15 val_loss: 2.1203558253219237
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run8 ---
#
# enzymes/supervised_gat_large_lab0.01%_run8 best epoch: 2 val_loss: 1.7956735643635982
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run8 ---
#
# proteins/supervised_gat_large_lab0.01%_run8 best epoch: 1 val_loss: 0.6754631700496344
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run8 ---
#
# synthie/supervised_gat_large_lab0.01%_run8 best epoch: 21 val_loss: 1.377343029014824
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run8 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run8 best epoch: 4 val_loss: 1.6979079649119282
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run8 ---
#
# proteins/supervised_gin0_large_lab0.01%_run8 best epoch: 1 val_loss: 0.7137818980796135
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run8 ---
#
# synthie/supervised_gin0_large_lab0.01%_run8 best epoch: 4 val_loss: 1.3773840986644372
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run8 ---
#
# enzymes/supervised_topk_lab0.01%_run8 best epoch: 5 val_loss: 3.26300485432148
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run8 ---
#
# proteins/supervised_topk_lab0.01%_run8 best epoch: 8 val_loss: 2.0286997724361364
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run8 ---
#
# synthie/supervised_topk_lab0.01%_run8 best epoch: 5 val_loss: 2.870918903529804
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gat_large_lab0.01%_run9 ---
#
# enzymes/supervised_gat_large_lab0.01%_run9 best epoch: 1 val_loss: 1.7966820258043994
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gat_large_lab0.01%_run9 ---
#
# proteins/supervised_gat_large_lab0.01%_run9 best epoch: 1 val_loss: 0.673102273847765
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gat_large_lab0.01%_run9 ---
#
# synthie/supervised_gat_large_lab0.01%_run9 best epoch: 2 val_loss: 1.367339796661713
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_gin0_large_lab0.01%_run9 ---
#
# enzymes/supervised_gin0_large_lab0.01%_run9 best epoch: 7 val_loss: 1.5914015849431355
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_gin0_large_lab0.01%_run9 ---
#
# proteins/supervised_gin0_large_lab0.01%_run9 best epoch: 1 val_loss: 0.7598013119435171
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_gin0_large_lab0.01%_run9 ---
#
# synthie/supervised_gin0_large_lab0.01%_run9 best epoch: 3 val_loss: 1.365352287417964
# label perc test: 0.011111111111111112
#
# --- Loading enzymes/supervised_topk_lab0.01%_run9 ---
#
# enzymes/supervised_topk_lab0.01%_run9 best epoch: 6 val_loss: 3.9314929436528407
# label perc test: 0.01098901098901099
#
# --- Loading proteins/supervised_topk_lab0.01%_run9 ---
#
# proteins/supervised_topk_lab0.01%_run9 best epoch: 5 val_loss: 1.8696230036746473
# label perc test: 0.011111111111111112
#
# --- Loading synthie/supervised_topk_lab0.01%_run9 ---
#
# synthie/supervised_topk_lab0.01%_run9 best epoch: 1 val_loss: 3.7207018215199468

# %%
for k,t in data_trainers.items(): 
    for e, h in enumerate(t.history[::-1]):
        if h["valid_acc_best"]:
            print(k, "epoch:", len(t.history)-e, 
                  "val_loss:", h["valid_loss"], 
                 "valid_acc", h["valid_acc"])
            break
# Out:
# enzymes/supervised_gat_large_lab1%_run0 epoch: 27 val_loss: 1.333056089922282 valid_acc 0.5
# proteins/supervised_gat_large_lab1%_run0 epoch: 19 val_loss: 0.4450531373051857 valid_acc 0.7410714285714286
# synthie/supervised_gat_large_lab1%_run0 epoch: 11 val_loss: 1.2429730469786275 valid_acc 0.5
# enzymes/supervised_gin0_large_lab1%_run0 epoch: 11 val_loss: 1.2847857066293016 valid_acc 0.55
# proteins/supervised_gin0_large_lab1%_run0 epoch: 5 val_loss: 0.48654540174728866 valid_acc 0.7767857142857143
# synthie/supervised_gin0_large_lab1%_run0 epoch: 4 val_loss: 1.2884178859582218 valid_acc 0.425
# enzymes/supervised_topk_lab1%_run0 epoch: 20 val_loss: 1.27866411121194 valid_acc 0.5166666666666667
# proteins/supervised_topk_lab1%_run0 epoch: 21 val_loss: 0.5020774744207989 valid_acc 0.7589285714285714
# synthie/supervised_topk_lab1%_run0 epoch: 16 val_loss: 1.2331990718841552 valid_acc 0.5
# enzymes/supervised_gat_large_lab1%_run1 epoch: 20 val_loss: 1.44608872124009 valid_acc 0.45
# proteins/supervised_gat_large_lab1%_run1 epoch: 18 val_loss: 0.4424575634159505 valid_acc 0.7946428571428571
# synthie/supervised_gat_large_lab1%_run1 epoch: 17 val_loss: 1.2068536951940319 valid_acc 0.475
# enzymes/supervised_gin0_large_lab1%_run1 epoch: 15 val_loss: 1.0961822557935672 valid_acc 0.6
# proteins/supervised_gin0_large_lab1%_run1 epoch: 14 val_loss: 0.5650824114118168 valid_acc 0.7589285714285714
# synthie/supervised_gin0_large_lab1%_run1 epoch: 6 val_loss: 1.224953833214567 valid_acc 0.575
# enzymes/supervised_topk_lab1%_run1 epoch: 27 val_loss: 1.1630069216690868 valid_acc 0.6666666666666666
# proteins/supervised_topk_lab1%_run1 epoch: 4 val_loss: 0.49880857775386145 valid_acc 0.7678571428571429
# synthie/supervised_topk_lab1%_run1 epoch: 68 val_loss: 0.26481130562330546 valid_acc 0.9
# enzymes/supervised_gat_large_lab1%_run2 epoch: 36 val_loss: 1.2588800919067753 valid_acc 0.55
# proteins/supervised_gat_large_lab1%_run2 epoch: 30 val_loss: 0.3572768750741626 valid_acc 0.8303571428571429
# synthie/supervised_gat_large_lab1%_run2 epoch: 15 val_loss: 1.0863807750375647 valid_acc 0.5
# enzymes/supervised_gin0_large_lab1%_run2 epoch: 12 val_loss: 1.3551458311057316 valid_acc 0.55
# proteins/supervised_gin0_large_lab1%_run2 epoch: 5 val_loss: 0.5592754351205316 valid_acc 0.7053571428571429
# synthie/supervised_gin0_large_lab1%_run2 epoch: 16 val_loss: 1.2633693411712248 valid_acc 0.625
# enzymes/supervised_topk_lab1%_run2 epoch: 19 val_loss: 1.5285428796802556 valid_acc 0.5833333333333334
# proteins/supervised_topk_lab1%_run2 epoch: 17 val_loss: 0.4649067714183687 valid_acc 0.8125
# synthie/supervised_topk_lab1%_run2 epoch: 36 val_loss: 0.6326121498668005 valid_acc 0.8
# enzymes/supervised_gat_large_lab1%_run3 epoch: 39 val_loss: 1.1933819646182195 valid_acc 0.6
# proteins/supervised_gat_large_lab1%_run3 epoch: 13 val_loss: 0.48052339496639573 valid_acc 0.7410714285714286
# synthie/supervised_gat_large_lab1%_run3 epoch: 15 val_loss: 1.1262234155315936 valid_acc 0.5
# enzymes/supervised_gin0_large_lab1%_run3 epoch: 12 val_loss: 1.140825607737557 valid_acc 0.5833333333333334
# proteins/supervised_gin0_large_lab1%_run3 epoch: 5 val_loss: 0.4586674529648782 valid_acc 0.7410714285714286
# synthie/supervised_gin0_large_lab1%_run3 epoch: 3 val_loss: 1.3122402093912426 valid_acc 0.425
# enzymes/supervised_topk_lab1%_run3 epoch: 15 val_loss: 1.0863166488481786 valid_acc 0.6333333333333333
# proteins/supervised_topk_lab1%_run3 epoch: 10 val_loss: 0.5594008487632983 valid_acc 0.7410714285714286
# synthie/supervised_topk_lab1%_run3 epoch: 7 val_loss: 1.3387047473862177 valid_acc 0.45
# enzymes/supervised_gat_large_lab1%_run4 epoch: 62 val_loss: 1.1425450799066268 valid_acc 0.65
# proteins/supervised_gat_large_lab1%_run4 epoch: 24 val_loss: 0.4664960185861248 valid_acc 0.7589285714285714
# synthie/supervised_gat_large_lab1%_run4 epoch: 15 val_loss: 1.2298019714555715 valid_acc 0.45
# enzymes/supervised_gin0_large_lab1%_run4 epoch: 10 val_loss: 1.3026072209469772 valid_acc 0.5666666666666667
# proteins/supervised_gin0_large_lab1%_run4 epoch: 10 val_loss: 0.5720005566386333 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab1%_run4 epoch: 5 val_loss: 1.3062706538072721 valid_acc 0.35
# enzymes/supervised_topk_lab1%_run4 epoch: 17 val_loss: 1.477212762160874 valid_acc 0.43333333333333335
# proteins/supervised_topk_lab1%_run4 epoch: 9 val_loss: 0.4713459417729342 valid_acc 0.75
# synthie/supervised_topk_lab1%_run4 epoch: 29 val_loss: 0.4228686381298508 valid_acc 0.85
# enzymes/supervised_gat_large_lab1%_run5 epoch: 11 val_loss: 1.7587204051485719 valid_acc 0.35
# proteins/supervised_gat_large_lab1%_run5 epoch: 8 val_loss: 0.5546846512952488 valid_acc 0.7321428571428571
# synthie/supervised_gat_large_lab1%_run5 epoch: 18 val_loss: 1.128772445910953 valid_acc 0.525
# enzymes/supervised_gin0_large_lab1%_run5 epoch: 9 val_loss: 1.2407321220808858 valid_acc 0.5166666666666667
# proteins/supervised_gin0_large_lab1%_run5 epoch: 2 val_loss: 0.5921181300610446 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab1%_run5 epoch: 14 val_loss: 0.9847901107777968 valid_acc 0.65
# enzymes/supervised_topk_lab1%_run5 epoch: 17 val_loss: 1.277904800459987 valid_acc 0.65
# proteins/supervised_topk_lab1%_run5 epoch: 13 val_loss: 0.4587379825324868 valid_acc 0.7589285714285714
# synthie/supervised_topk_lab1%_run5 epoch: 38 val_loss: 0.7400394499771238 valid_acc 0.775
# enzymes/supervised_gat_large_lab1%_run6 epoch: 64 val_loss: 0.9403902288475464 valid_acc 0.7
# proteins/supervised_gat_large_lab1%_run6 epoch: 11 val_loss: 0.4229430837154388 valid_acc 0.8125
# synthie/supervised_gat_large_lab1%_run6 epoch: 23 val_loss: 1.3124746322631835 valid_acc 0.425
# enzymes/supervised_gin0_large_lab1%_run6 epoch: 10 val_loss: 1.2853448601939794 valid_acc 0.4666666666666667
# proteins/supervised_gin0_large_lab1%_run6 epoch: 5 val_loss: 0.4991506223088653 valid_acc 0.7857142857142857
# synthie/supervised_gin0_large_lab1%_run6 epoch: 41 val_loss: 0.8521925477769362 valid_acc 0.75
# enzymes/supervised_topk_lab1%_run6 epoch: 12 val_loss: 1.4305880773858297 valid_acc 0.5
# proteins/supervised_topk_lab1%_run6 epoch: 4 val_loss: 0.5443815558958464 valid_acc 0.7232142857142857
# synthie/supervised_topk_lab1%_run6 epoch: 13 val_loss: 0.5460121139647469 valid_acc 0.85
# enzymes/supervised_gat_large_lab1%_run7 epoch: 38 val_loss: 1.1890093287559187 valid_acc 0.65
# proteins/supervised_gat_large_lab1%_run7 epoch: 10 val_loss: 0.43253980233027056 valid_acc 0.8035714285714286
# synthie/supervised_gat_large_lab1%_run7 epoch: 9 val_loss: 1.2923668701604678 valid_acc 0.5
# enzymes/supervised_gin0_large_lab1%_run7 epoch: 12 val_loss: 1.1830626227081025 valid_acc 0.5833333333333334
# proteins/supervised_gin0_large_lab1%_run7 epoch: 6 val_loss: 0.5105901108824087 valid_acc 0.8035714285714286
# synthie/supervised_gin0_large_lab1%_run7 epoch: 4 val_loss: 1.363839655719322 valid_acc 0.45
# enzymes/supervised_topk_lab1%_run7 epoch: 18 val_loss: 1.200576353767918 valid_acc 0.5666666666666667
# proteins/supervised_topk_lab1%_run7 epoch: 10 val_loss: 0.5150860045857848 valid_acc 0.7946428571428571
# synthie/supervised_topk_lab1%_run7 epoch: 17 val_loss: 0.9038196311642727 valid_acc 0.6
# enzymes/supervised_gat_large_lab1%_run8 epoch: 3 val_loss: 1.7412697748737114 valid_acc 0.23333333333333334
# proteins/supervised_gat_large_lab1%_run8 epoch: 4 val_loss: 0.46440074745384424 valid_acc 0.7857142857142857
# synthie/supervised_gat_large_lab1%_run8 epoch: 15 val_loss: 1.1340636059089944 valid_acc 0.5
# enzymes/supervised_gin0_large_lab1%_run8 epoch: 20 val_loss: 1.4814449295703154 valid_acc 0.5333333333333333
# proteins/supervised_gin0_large_lab1%_run8 epoch: 3 val_loss: 0.5472026667897224 valid_acc 0.7142857142857143
# synthie/supervised_gin0_large_lab1%_run8 epoch: 5 val_loss: 1.26248126835018 valid_acc 0.5
# enzymes/supervised_topk_lab1%_run8 epoch: 25 val_loss: 1.1640929242143105 valid_acc 0.65
# proteins/supervised_topk_lab1%_run8 epoch: 4 val_loss: 0.47079534623189156 valid_acc 0.7410714285714286
# synthie/supervised_topk_lab1%_run8 epoch: 25 val_loss: 0.7725519180297852 valid_acc 0.75
# enzymes/supervised_gat_large_lab1%_run9 epoch: 90 val_loss: 1.029073908053959 valid_acc 0.7
# proteins/supervised_gat_large_lab1%_run9 epoch: 9 val_loss: 0.5310596549129336 valid_acc 0.7232142857142857
# synthie/supervised_gat_large_lab1%_run9 epoch: 20 val_loss: 1.039165978307848 valid_acc 0.625
# enzymes/supervised_gin0_large_lab1%_run9 epoch: 17 val_loss: 1.2734109748925948 valid_acc 0.55
# proteins/supervised_gin0_large_lab1%_run9 epoch: 7 val_loss: 0.524594067425246 valid_acc 0.7321428571428571
# synthie/supervised_gin0_large_lab1%_run9 epoch: 27 val_loss: 1.2400603416397815 valid_acc 0.625
# enzymes/supervised_topk_lab1%_run9 epoch: 45 val_loss: 1.1446998360913092 valid_acc 0.7
# proteins/supervised_topk_lab1%_run9 epoch: 3 val_loss: 0.5412531819878488 valid_acc 0.6964285714285714
# synthie/supervised_topk_lab1%_run9 epoch: 14 val_loss: 0.883914137724787 valid_acc 0.725
# enzymes/supervised_gat_large_lab0.5%_run0 epoch: 33 val_loss: 1.4515483354631795 valid_acc 0.48333333333333334
# proteins/supervised_gat_large_lab0.5%_run0 epoch: 3 val_loss: 0.5747228274393061 valid_acc 0.7410714285714286
# synthie/supervised_gat_large_lab0.5%_run0 epoch: 15 val_loss: 1.307006150484085 valid_acc 0.5
# enzymes/supervised_gin0_large_lab0.5%_run0 epoch: 7 val_loss: 1.6508292330431495 valid_acc 0.35
# proteins/supervised_gin0_large_lab0.5%_run0 epoch: 10 val_loss: 0.5640446897781694 valid_acc 0.7589285714285714
# synthie/supervised_gin0_large_lab0.5%_run0 epoch: 1 val_loss: 1.3807585128738646 valid_acc 0.425
# enzymes/supervised_topk_lab0.5%_run0 epoch: 12 val_loss: 1.152609171958015 valid_acc 0.65
# proteins/supervised_topk_lab0.5%_run0 epoch: 17 val_loss: 0.5156495499255535 valid_acc 0.75
# synthie/supervised_topk_lab0.5%_run0 epoch: 21 val_loss: 1.3420811723040036 valid_acc 0.475
# enzymes/supervised_gat_large_lab0.5%_run1 epoch: 17 val_loss: 1.7072968741632857 valid_acc 0.36666666666666664
# proteins/supervised_gat_large_lab0.5%_run1 epoch: 14 val_loss: 0.5558458767628589 valid_acc 0.7142857142857143
# synthie/supervised_gat_large_lab0.5%_run1 epoch: 9 val_loss: 1.3505975443219382 valid_acc 0.55
# enzymes/supervised_gin0_large_lab0.5%_run1 epoch: 11 val_loss: 1.5160312238854312 valid_acc 0.45
# proteins/supervised_gin0_large_lab0.5%_run1 epoch: 8 val_loss: 0.548702407853377 valid_acc 0.6964285714285714
# synthie/supervised_gin0_large_lab0.5%_run1 epoch: 4 val_loss: 1.2137953472764869 valid_acc 0.5
# enzymes/supervised_topk_lab0.5%_run1 epoch: 12 val_loss: 1.5947247220623877 valid_acc 0.43333333333333335
# proteins/supervised_topk_lab0.5%_run1 epoch: 10 val_loss: 0.5481218252885008 valid_acc 0.7142857142857143
# synthie/supervised_topk_lab0.5%_run1 epoch: 12 val_loss: 0.7113120557442112 valid_acc 0.725
# enzymes/supervised_gat_large_lab0.5%_run2 epoch: 5 val_loss: 1.6948572309425725 valid_acc 0.31666666666666665
# proteins/supervised_gat_large_lab0.5%_run2 epoch: 9 val_loss: 0.4758545661160213 valid_acc 0.8035714285714286
# synthie/supervised_gat_large_lab0.5%_run2 epoch: 11 val_loss: 1.3438840953529982 valid_acc 0.4
# enzymes/supervised_gin0_large_lab0.5%_run2 epoch: 6 val_loss: 1.3392932499506716 valid_acc 0.5
# proteins/supervised_gin0_large_lab0.5%_run2 epoch: 5 val_loss: 0.5743788637095429 valid_acc 0.6785714285714286
# synthie/supervised_gin0_large_lab0.5%_run2 epoch: 7 val_loss: 1.1787138127521748 valid_acc 0.525
# enzymes/supervised_topk_lab0.5%_run2 epoch: 34 val_loss: 1.2906812442863573 valid_acc 0.6
# proteins/supervised_topk_lab0.5%_run2 epoch: 5 val_loss: 0.8125529059610246 valid_acc 0.6428571428571429
# synthie/supervised_topk_lab0.5%_run2 epoch: 32 val_loss: 0.8682781653989389 valid_acc 0.75
# enzymes/supervised_gat_large_lab0.5%_run3 epoch: 29 val_loss: 1.5827962819698014 valid_acc 0.48333333333333334
# proteins/supervised_gat_large_lab0.5%_run3 epoch: 11 val_loss: 0.5029370076971093 valid_acc 0.6964285714285714
# synthie/supervised_gat_large_lab0.5%_run3 epoch: 33 val_loss: 1.0895908419878313 valid_acc 0.575
# enzymes/supervised_gin0_large_lab0.5%_run3 epoch: 36 val_loss: 1.2839098108931402 valid_acc 0.6333333333333333
# proteins/supervised_gin0_large_lab0.5%_run3 epoch: 5 val_loss: 0.5658798175475366 valid_acc 0.6696428571428571
# synthie/supervised_gin0_large_lab0.5%_run3 epoch: 4 val_loss: 1.2946158322136545 valid_acc 0.3
# enzymes/supervised_topk_lab0.5%_run3 epoch: 21 val_loss: 1.4783947041772976 valid_acc 0.45
# proteins/supervised_topk_lab0.5%_run3 epoch: 3 val_loss: 0.5733531745884263 valid_acc 0.7142857142857143
# synthie/supervised_topk_lab0.5%_run3 epoch: 27 val_loss: 0.6520459329801813 valid_acc 0.85
# enzymes/supervised_gat_large_lab0.5%_run4 epoch: 31 val_loss: 1.5116117965324996 valid_acc 0.45
# proteins/supervised_gat_large_lab0.5%_run4 epoch: 12 val_loss: 0.4115649135380162 valid_acc 0.7946428571428571
# synthie/supervised_gat_large_lab0.5%_run4 epoch: 19 val_loss: 1.3410714268684387 valid_acc 0.4
# enzymes/supervised_gin0_large_lab0.5%_run4 epoch: 27 val_loss: 1.4121476411819458 valid_acc 0.5666666666666667
# proteins/supervised_gin0_large_lab0.5%_run4 epoch: 12 val_loss: 0.5574118427717923 valid_acc 0.7053571428571429
# synthie/supervised_gin0_large_lab0.5%_run4 epoch: 2 val_loss: 1.3157574077869982 valid_acc 0.575
# enzymes/supervised_topk_lab0.5%_run4 epoch: 34 val_loss: 1.323622815064558 valid_acc 0.6166666666666667
# proteins/supervised_topk_lab0.5%_run4 epoch: 6 val_loss: 0.4789142785637079 valid_acc 0.7857142857142857
# synthie/supervised_topk_lab0.5%_run4 epoch: 22 val_loss: 0.8295434442574922 valid_acc 0.675
# enzymes/supervised_gat_large_lab0.5%_run5 epoch: 26 val_loss: 1.401635358445957 valid_acc 0.43333333333333335
# proteins/supervised_gat_large_lab0.5%_run5 epoch: 18 val_loss: 0.44234067812059535 valid_acc 0.8035714285714286
# synthie/supervised_gat_large_lab0.5%_run5 epoch: 13 val_loss: 1.2352193913121863 valid_acc 0.35
# enzymes/supervised_gin0_large_lab0.5%_run5 epoch: 7 val_loss: 1.534407604025408 valid_acc 0.45
# proteins/supervised_gin0_large_lab0.5%_run5 epoch: 2 val_loss: 0.6853963753362854 valid_acc 0.625
# synthie/supervised_gin0_large_lab0.5%_run5 epoch: 8 val_loss: 1.201576818262367 valid_acc 0.6
# enzymes/supervised_topk_lab0.5%_run5 epoch: 11 val_loss: 1.6265361989753833 valid_acc 0.4166666666666667
# proteins/supervised_topk_lab0.5%_run5 epoch: 13 val_loss: 0.5073711012059712 valid_acc 0.7946428571428571
# synthie/supervised_topk_lab0.5%_run5 epoch: 5 val_loss: 1.3639794807929497 valid_acc 0.525
# enzymes/supervised_gat_large_lab0.5%_run6 epoch: 5 val_loss: 1.7184106807699318 valid_acc 0.31666666666666665
# proteins/supervised_gat_large_lab0.5%_run6 epoch: 14 val_loss: 0.49538643483942824 valid_acc 0.7678571428571429
# synthie/supervised_gat_large_lab0.5%_run6 epoch: 7 val_loss: 1.339744625268159 valid_acc 0.5
# enzymes/supervised_gin0_large_lab0.5%_run6 epoch: 5 val_loss: 1.6149052445159067 valid_acc 0.36666666666666664
# proteins/supervised_gin0_large_lab0.5%_run6 epoch: 5 val_loss: 0.49811599779560073 valid_acc 0.7589285714285714
# synthie/supervised_gin0_large_lab0.5%_run6 epoch: 2 val_loss: 1.3739478160334766 valid_acc 0.375
# enzymes/supervised_topk_lab0.5%_run6 epoch: 15 val_loss: 1.140702968115335 valid_acc 0.5833333333333334
# proteins/supervised_topk_lab0.5%_run6 epoch: 11 val_loss: 0.4831573669109192 valid_acc 0.7321428571428571
# synthie/supervised_topk_lab0.5%_run6 epoch: 25 val_loss: 1.1263355480300055 valid_acc 0.5
# enzymes/supervised_gat_large_lab0.5%_run7 epoch: 45 val_loss: 1.4512570258139013 valid_acc 0.48333333333333334
# proteins/supervised_gat_large_lab0.5%_run7 epoch: 6 val_loss: 0.5688191761947344 valid_acc 0.75
# synthie/supervised_gat_large_lab0.5%_run7 epoch: 28 val_loss: 1.045873854368452 valid_acc 0.6
# enzymes/supervised_gin0_large_lab0.5%_run7 epoch: 9 val_loss: 1.4817104375484038 valid_acc 0.48333333333333334
# proteins/supervised_gin0_large_lab0.5%_run7 epoch: 3 val_loss: 0.5644944544936803 valid_acc 0.7053571428571429
# synthie/supervised_gin0_large_lab0.5%_run7 epoch: 4 val_loss: 1.2795611099192972 valid_acc 0.425
# enzymes/supervised_topk_lab0.5%_run7 epoch: 30 val_loss: 1.2343687906792635 valid_acc 0.5833333333333334
# proteins/supervised_topk_lab0.5%_run7 epoch: 2 val_loss: 0.526936121725501 valid_acc 0.7410714285714286
# synthie/supervised_topk_lab0.5%_run7 epoch: 15 val_loss: 1.019374756196558 valid_acc 0.525
# enzymes/supervised_gat_large_lab0.5%_run8 epoch: 27 val_loss: 1.383861177907127 valid_acc 0.5
# proteins/supervised_gat_large_lab0.5%_run8 epoch: 10 val_loss: 0.6092634134655895 valid_acc 0.6607142857142857
# synthie/supervised_gat_large_lab0.5%_run8 epoch: 10 val_loss: 1.3033136628685198 valid_acc 0.425
# enzymes/supervised_gin0_large_lab0.5%_run8 epoch: 9 val_loss: 1.4621420756339034 valid_acc 0.5
# proteins/supervised_gin0_large_lab0.5%_run8 epoch: 5 val_loss: 0.504476533674701 valid_acc 0.7321428571428571
# synthie/supervised_gin0_large_lab0.5%_run8 epoch: 4 val_loss: 1.267095775046247 valid_acc 0.375
# enzymes/supervised_topk_lab0.5%_run8 epoch: 27 val_loss: 1.0619116608913128 valid_acc 0.5833333333333334
# proteins/supervised_topk_lab0.5%_run8 epoch: 9 val_loss: 0.49255218965324327 valid_acc 0.7321428571428571
# synthie/supervised_topk_lab0.5%_run8 epoch: 8 val_loss: 0.9519792553037405 valid_acc 0.775
# enzymes/supervised_gat_large_lab0.5%_run9 epoch: 62 val_loss: 1.2014043390037057 valid_acc 0.6166666666666667
# proteins/supervised_gat_large_lab0.5%_run9 epoch: 4 val_loss: 0.44653370617772375 valid_acc 0.8571428571428571
# synthie/supervised_gat_large_lab0.5%_run9 epoch: 26 val_loss: 0.9831210649572313 valid_acc 0.6
# enzymes/supervised_gin0_large_lab0.5%_run9 epoch: 4 val_loss: 1.4484040780560126 valid_acc 0.4
# proteins/supervised_gin0_large_lab0.5%_run9 epoch: 9 val_loss: 0.478286271551618 valid_acc 0.7946428571428571
# synthie/supervised_gin0_large_lab0.5%_run9 epoch: 5 val_loss: 1.2946994017789708 valid_acc 0.35
# enzymes/supervised_topk_lab0.5%_run9 epoch: 12 val_loss: 1.5589061330270895 valid_acc 0.45
# proteins/supervised_topk_lab0.5%_run9 epoch: 8 val_loss: 0.5280788375976238 valid_acc 0.7410714285714286
# synthie/supervised_topk_lab0.5%_run9 epoch: 12 val_loss: 0.9046898199435003 valid_acc 0.65
# enzymes/supervised_gat_large_lab0.3%_run0 epoch: 29 val_loss: 1.620949004135058 valid_acc 0.4
# proteins/supervised_gat_large_lab0.3%_run0 epoch: 4 val_loss: 0.5557287610102538 valid_acc 0.6964285714285714
# synthie/supervised_gat_large_lab0.3%_run0 epoch: 14 val_loss: 1.326248166402181 valid_acc 0.375
# enzymes/supervised_gin0_large_lab0.3%_run0 epoch: 10 val_loss: 1.4065983558224127 valid_acc 0.5333333333333333
# proteins/supervised_gin0_large_lab0.3%_run0 epoch: 7 val_loss: 0.555198014636092 valid_acc 0.6785714285714286
# synthie/supervised_gin0_large_lab0.3%_run0 epoch: 2 val_loss: 1.3654975569685093 valid_acc 0.325
# enzymes/supervised_topk_lab0.3%_run0 epoch: 12 val_loss: 1.6108049840905412 valid_acc 0.38333333333333336
# proteins/supervised_topk_lab0.3%_run0 epoch: 4 val_loss: 0.5356870924350116 valid_acc 0.7410714285714286
# synthie/supervised_topk_lab0.3%_run0 epoch: 11 val_loss: 1.2686918136921335 valid_acc 0.475
# enzymes/supervised_gat_large_lab0.3%_run1 epoch: 36 val_loss: 1.5020246496836345 valid_acc 0.43333333333333335
# proteins/supervised_gat_large_lab0.3%_run1 epoch: 14 val_loss: 0.4943531536535138 valid_acc 0.8125
# synthie/supervised_gat_large_lab0.3%_run1 epoch: 30 val_loss: 1.2253123774578434 valid_acc 0.5
# enzymes/supervised_gin0_large_lab0.3%_run1 epoch: 9 val_loss: 1.4314727837712342 valid_acc 0.55
# proteins/supervised_gin0_large_lab0.3%_run1 epoch: 2 val_loss: 0.6206601472584975 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.3%_run1 epoch: 3 val_loss: 1.3381326314956343 valid_acc 0.3
# enzymes/supervised_topk_lab0.3%_run1 epoch: 15 val_loss: 1.7045543032387893 valid_acc 0.35
# proteins/supervised_topk_lab0.3%_run1 epoch: 6 val_loss: 0.5503227212940905 valid_acc 0.6964285714285714
# synthie/supervised_topk_lab0.3%_run1 epoch: 19 val_loss: 0.8033830115261177 valid_acc 0.575
# enzymes/supervised_gat_large_lab0.3%_run2 epoch: 57 val_loss: 1.3522506028559624 valid_acc 0.55
# proteins/supervised_gat_large_lab0.3%_run2 epoch: 5 val_loss: 0.5615244866249525 valid_acc 0.6964285714285714
# synthie/supervised_gat_large_lab0.3%_run2 epoch: 61 val_loss: 1.212681219985448 valid_acc 0.525
# enzymes/supervised_gin0_large_lab0.3%_run2 epoch: 15 val_loss: 1.5044539750201031 valid_acc 0.48333333333333334
# proteins/supervised_gin0_large_lab0.3%_run2 epoch: 1 val_loss: 0.6535360782675477 valid_acc 0.6875
# synthie/supervised_gin0_large_lab0.3%_run2 epoch: 3 val_loss: 1.3481911587526427 valid_acc 0.475
# enzymes/supervised_topk_lab0.3%_run2 epoch: 9 val_loss: 1.7507157139871075 valid_acc 0.4166666666666667
# proteins/supervised_topk_lab0.3%_run2 epoch: 3 val_loss: 0.5625065614668836 valid_acc 0.7321428571428571
# synthie/supervised_topk_lab0.3%_run2 epoch: 13 val_loss: 0.7643977398922701 valid_acc 0.625
# enzymes/supervised_gat_large_lab0.3%_run3 epoch: 37 val_loss: 1.3924521032229875 valid_acc 0.45
# proteins/supervised_gat_large_lab0.3%_run3 epoch: 7 val_loss: 0.5311745386799972 valid_acc 0.7321428571428571
# synthie/supervised_gat_large_lab0.3%_run3 epoch: 13 val_loss: 1.1604762224387621 valid_acc 0.6
# enzymes/supervised_gin0_large_lab0.3%_run3 epoch: 13 val_loss: 1.4732316211612526 valid_acc 0.5166666666666667
# proteins/supervised_gin0_large_lab0.3%_run3 epoch: 1 val_loss: 0.6164362522142718 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab0.3%_run3 epoch: 4 val_loss: 1.3818092057481408 valid_acc 0.25
# enzymes/supervised_topk_lab0.3%_run3 epoch: 22 val_loss: 1.670900395740498 valid_acc 0.43333333333333335
# proteins/supervised_topk_lab0.3%_run3 epoch: 4 val_loss: 0.5983721593101321 valid_acc 0.6785714285714286
# synthie/supervised_topk_lab0.3%_run3 epoch: 32 val_loss: 0.8674675279124288 valid_acc 0.575
# enzymes/supervised_gat_large_lab0.3%_run4 epoch: 17 val_loss: 1.6576676495035394 valid_acc 0.38333333333333336
# proteins/supervised_gat_large_lab0.3%_run4 epoch: 7 val_loss: 0.5722295295842346 valid_acc 0.6696428571428571
# synthie/supervised_gat_large_lab0.3%_run4 epoch: 17 val_loss: 1.1389580787496363 valid_acc 0.575
# enzymes/supervised_gin0_large_lab0.3%_run4 epoch: 5 val_loss: 1.5788135697635322 valid_acc 0.36666666666666664
# proteins/supervised_gin0_large_lab0.3%_run4 epoch: 2 val_loss: 0.5945767827836524 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.3%_run4 epoch: 2 val_loss: 1.3340973680152184 valid_acc 0.475
# enzymes/supervised_topk_lab0.3%_run4 epoch: 20 val_loss: 1.7902351760054849 valid_acc 0.45
# proteins/supervised_topk_lab0.3%_run4 epoch: 2 val_loss: 0.6197631228595752 valid_acc 0.6696428571428571
# synthie/supervised_topk_lab0.3%_run4 epoch: 15 val_loss: 1.1968595674785787 valid_acc 0.55
# enzymes/supervised_gat_large_lab0.3%_run5 epoch: 39 val_loss: 1.345746213163182 valid_acc 0.5
# proteins/supervised_gat_large_lab0.3%_run5 epoch: 9 val_loss: 0.580996385297992 valid_acc 0.75
# synthie/supervised_gat_large_lab0.3%_run5 epoch: 12 val_loss: 1.2979903410351465 valid_acc 0.575
# enzymes/supervised_gin0_large_lab0.3%_run5 epoch: 8 val_loss: 1.5990879073026585 valid_acc 0.45
# proteins/supervised_gin0_large_lab0.3%_run5 epoch: 4 val_loss: 0.6389837309580159 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.3%_run5 epoch: 2 val_loss: 1.3422157961552537 valid_acc 0.55
# enzymes/supervised_topk_lab0.3%_run5 epoch: 7 val_loss: 1.8530015718369257 valid_acc 0.4166666666666667
# proteins/supervised_topk_lab0.3%_run5 epoch: 10 val_loss: 0.5045164696480453 valid_acc 0.7589285714285714
# synthie/supervised_topk_lab0.3%_run5 epoch: 11 val_loss: 0.9656737309358714 valid_acc 0.65
# enzymes/supervised_gat_large_lab0.3%_run6 epoch: 30 val_loss: 1.6372558448375931 valid_acc 0.5
# proteins/supervised_gat_large_lab0.3%_run6 epoch: 8 val_loss: 0.5657544487914864 valid_acc 0.7232142857142857
# synthie/supervised_gat_large_lab0.3%_run6 epoch: 27 val_loss: 1.2071708339129308 valid_acc 0.525
# enzymes/supervised_gin0_large_lab0.3%_run6 epoch: 5 val_loss: 1.5753264238761524 valid_acc 0.4
# proteins/supervised_gin0_large_lab0.3%_run6 epoch: 3 val_loss: 0.654331553871746 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab0.3%_run6 epoch: 5 val_loss: 1.2457401025892876 valid_acc 0.425
# enzymes/supervised_topk_lab0.3%_run6 epoch: 8 val_loss: 1.6598315495997666 valid_acc 0.35
# proteins/supervised_topk_lab0.3%_run6 epoch: 2 val_loss: 0.5469616108625018 valid_acc 0.7857142857142857
# synthie/supervised_topk_lab0.3%_run6 epoch: 10 val_loss: 1.3558734383723692 valid_acc 0.5
# enzymes/supervised_gat_large_lab0.3%_run7 epoch: 4 val_loss: 1.787778720808986 valid_acc 0.18333333333333332
# proteins/supervised_gat_large_lab0.3%_run7 epoch: 1 val_loss: 0.6734479610452947 valid_acc 0.6428571428571429
# synthie/supervised_gat_large_lab0.3%_run7 epoch: 23 val_loss: 1.1638525305943168 valid_acc 0.55
# enzymes/supervised_gin0_large_lab0.3%_run7 epoch: 8 val_loss: 1.2525558471679688 valid_acc 0.6
# proteins/supervised_gin0_large_lab0.3%_run7 epoch: 5 val_loss: 0.5555072066398908 valid_acc 0.7857142857142857
# synthie/supervised_gin0_large_lab0.3%_run7 epoch: 2 val_loss: 1.347477095064364 valid_acc 0.5
# enzymes/supervised_topk_lab0.3%_run7 epoch: 17 val_loss: 1.8220527492013088 valid_acc 0.36666666666666664
# proteins/supervised_topk_lab0.3%_run7 epoch: 5 val_loss: 0.5282050612890676 valid_acc 0.7857142857142857
# synthie/supervised_topk_lab0.3%_run7 epoch: 16 val_loss: 1.3999945369605318 valid_acc 0.525
# enzymes/supervised_gat_large_lab0.3%_run8 epoch: 8 val_loss: 1.7507590977029373 valid_acc 0.16666666666666666
# proteins/supervised_gat_large_lab0.3%_run8 epoch: 9 val_loss: 0.49581607814706846 valid_acc 0.7678571428571429
# synthie/supervised_gat_large_lab0.3%_run8 epoch: 3 val_loss: 1.3812758019857483 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.3%_run8 epoch: 13 val_loss: 1.3834492885476772 valid_acc 0.5166666666666667
# proteins/supervised_gin0_large_lab0.3%_run8 epoch: 2 val_loss: 0.6449429305581801 valid_acc 0.625
# synthie/supervised_gin0_large_lab0.3%_run8 epoch: 4 val_loss: 1.3637284182743306 valid_acc 0.275
# enzymes/supervised_topk_lab0.3%_run8 epoch: 9 val_loss: 1.719841208980709 valid_acc 0.3333333333333333
# proteins/supervised_topk_lab0.3%_run8 epoch: 3 val_loss: 0.810798969481134 valid_acc 0.6428571428571429
# synthie/supervised_topk_lab0.3%_run8 epoch: 9 val_loss: 1.2071935187431913 valid_acc 0.45
# enzymes/supervised_gat_large_lab0.3%_run9 epoch: 10 val_loss: 1.6922145188009745 valid_acc 0.36666666666666664
# proteins/supervised_gat_large_lab0.3%_run9 epoch: 8 val_loss: 0.5854409234535549 valid_acc 0.6875
# synthie/supervised_gat_large_lab0.3%_run9 epoch: 33 val_loss: 1.1803588316748828 valid_acc 0.525
# enzymes/supervised_gin0_large_lab0.3%_run9 epoch: 8 val_loss: 1.5825799338671627 valid_acc 0.35
# proteins/supervised_gin0_large_lab0.3%_run9 epoch: 2 val_loss: 0.6146249752525605 valid_acc 0.6428571428571429
# synthie/supervised_gin0_large_lab0.3%_run9 epoch: 4 val_loss: 1.2422228795024042 valid_acc 0.475
# enzymes/supervised_topk_lab0.3%_run9 epoch: 8 val_loss: 1.6770923188603282 valid_acc 0.31666666666666665
# proteins/supervised_topk_lab0.3%_run9 epoch: 3 val_loss: 0.667897039219408 valid_acc 0.625
# synthie/supervised_topk_lab0.3%_run9 epoch: 17 val_loss: 1.1609162023733552 valid_acc 0.675
# enzymes/supervised_gat_large_lab0.1%_run0 epoch: 8 val_loss: 1.6965100303943017 valid_acc 0.3333333333333333
# proteins/supervised_gat_large_lab0.1%_run0 epoch: 3 val_loss: 0.6540130296152754 valid_acc 0.7232142857142857
# synthie/supervised_gat_large_lab0.1%_run0 epoch: 13 val_loss: 1.3411064629727694 valid_acc 0.375
# enzymes/supervised_gin0_large_lab0.1%_run0 epoch: 6 val_loss: 1.6869017599861402 valid_acc 0.2833333333333333
# proteins/supervised_gin0_large_lab0.1%_run0 epoch: 3 val_loss: 0.6383244732483206 valid_acc 0.625
# synthie/supervised_gin0_large_lab0.1%_run0 epoch: 1 val_loss: 1.3688951020545148 valid_acc 0.475
# enzymes/supervised_topk_lab0.1%_run0 epoch: 13 val_loss: 2.382015159561878 valid_acc 0.3333333333333333
# proteins/supervised_topk_lab0.1%_run0 epoch: 4 val_loss: 0.6160341136621468 valid_acc 0.7053571428571429
# synthie/supervised_topk_lab0.1%_run0 epoch: 17 val_loss: 1.3854999523561244 valid_acc 0.3
# enzymes/supervised_gat_large_lab0.1%_run1 epoch: 5 val_loss: 1.7099516489466682 valid_acc 0.23333333333333334
# proteins/supervised_gat_large_lab0.1%_run1 epoch: 4 val_loss: 0.6203491173620853 valid_acc 0.6607142857142857
# synthie/supervised_gat_large_lab0.1%_run1 epoch: 17 val_loss: 1.3551669411771878 valid_acc 0.35
# enzymes/supervised_gin0_large_lab0.1%_run1 epoch: 4 val_loss: 1.6807944744918206 valid_acc 0.3333333333333333
# proteins/supervised_gin0_large_lab0.1%_run1 epoch: 1 val_loss: 0.6869369181610419 valid_acc 0.6160714285714286
# synthie/supervised_gin0_large_lab0.1%_run1 epoch: 4 val_loss: 1.391614873365236 valid_acc 0.25
# enzymes/supervised_topk_lab0.1%_run1 epoch: 11 val_loss: 1.8836238823075226 valid_acc 0.26666666666666666
# proteins/supervised_topk_lab0.1%_run1 epoch: 2 val_loss: 0.5671494899700765 valid_acc 0.7767857142857143
# synthie/supervised_topk_lab0.1%_run1 epoch: 9 val_loss: 1.9103678319361304 valid_acc 0.575
# enzymes/supervised_gat_large_lab0.1%_run2 epoch: 7 val_loss: 1.7649605787789868 valid_acc 0.15
# proteins/supervised_gat_large_lab0.1%_run2 epoch: 1 val_loss: 0.6701907363092621 valid_acc 0.6339285714285714
# synthie/supervised_gat_large_lab0.1%_run2 epoch: 7 val_loss: 1.3238019640483554 valid_acc 0.45
# enzymes/supervised_gin0_large_lab0.1%_run2 epoch: 6 val_loss: 1.6550424363334075 valid_acc 0.2833333333333333
# proteins/supervised_gin0_large_lab0.1%_run2 epoch: 5 val_loss: 0.5975477037980652 valid_acc 0.6696428571428571
# synthie/supervised_gin0_large_lab0.1%_run2 epoch: 6 val_loss: 1.3276553198026793 valid_acc 0.475
# enzymes/supervised_topk_lab0.1%_run2 epoch: 16 val_loss: 1.9929209259244707 valid_acc 0.2
# proteins/supervised_topk_lab0.1%_run2 epoch: 1 val_loss: 0.631363836707772 valid_acc 0.6071428571428571
# synthie/supervised_topk_lab0.1%_run2 epoch: 6 val_loss: 1.5417768627247483 valid_acc 0.4
# enzymes/supervised_gat_large_lab0.1%_run3 epoch: 7 val_loss: 1.7562152043154753 valid_acc 0.2
# proteins/supervised_gat_large_lab0.1%_run3 epoch: 1 val_loss: 0.6799853738139351 valid_acc 0.625
# synthie/supervised_gat_large_lab0.1%_run3 epoch: 37 val_loss: 0.9688375625345442 valid_acc 0.625
# enzymes/supervised_gin0_large_lab0.1%_run3 epoch: 3 val_loss: 1.7035221311510826 valid_acc 0.2833333333333333
# proteins/supervised_gin0_large_lab0.1%_run3 epoch: 3 val_loss: 0.6283579249746307 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab0.1%_run3 epoch: 5 val_loss: 1.3025683792013871 valid_acc 0.4
# enzymes/supervised_topk_lab0.1%_run3 epoch: 4 val_loss: 2.264928987635995 valid_acc 0.26666666666666666
# proteins/supervised_topk_lab0.1%_run3 epoch: 5 val_loss: 0.6492432832563546 valid_acc 0.7142857142857143
# synthie/supervised_topk_lab0.1%_run3 epoch: 12 val_loss: 1.376490754313708 valid_acc 0.425
# enzymes/supervised_gat_large_lab0.1%_run4 epoch: 3 val_loss: 1.7893978578546137 valid_acc 0.06666666666666667
# proteins/supervised_gat_large_lab0.1%_run4 epoch: 3 val_loss: 0.6187881833349367 valid_acc 0.6517857142857143
# synthie/supervised_gat_large_lab0.1%_run4 epoch: 10 val_loss: 1.3581999290676017 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.1%_run4 epoch: 9 val_loss: 1.7349706501171815 valid_acc 0.38333333333333336
# proteins/supervised_gin0_large_lab0.1%_run4 epoch: 5 val_loss: 0.6493855600105966 valid_acc 0.6428571428571429
# synthie/supervised_gin0_large_lab0.1%_run4 epoch: 3 val_loss: 1.33679509701881 valid_acc 0.425
# enzymes/supervised_topk_lab0.1%_run4 epoch: 9 val_loss: 2.1607294721116155 valid_acc 0.38333333333333336
# proteins/supervised_topk_lab0.1%_run4 epoch: 4 val_loss: 0.5944037521604317 valid_acc 0.6964285714285714
# synthie/supervised_topk_lab0.1%_run4 epoch: 6 val_loss: 1.4170519256343443 valid_acc 0.35
# enzymes/supervised_gat_large_lab0.1%_run5 epoch: 7 val_loss: 1.6658037739718508 valid_acc 0.3333333333333333
# proteins/supervised_gat_large_lab0.1%_run5 epoch: 7 val_loss: 0.5065434543109032 valid_acc 0.7767857142857143
# synthie/supervised_gat_large_lab0.1%_run5 epoch: 21 val_loss: 1.2746460977941751 valid_acc 0.475
# enzymes/supervised_gin0_large_lab0.1%_run5 epoch: 9 val_loss: 1.5910612583485961 valid_acc 0.36666666666666664
# proteins/supervised_gin0_large_lab0.1%_run5 epoch: 4 val_loss: 0.6100940870552176 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab0.1%_run5 epoch: 6 val_loss: 1.2480466391313523 valid_acc 0.475
# enzymes/supervised_topk_lab0.1%_run5 epoch: 13 val_loss: 1.985015098746575 valid_acc 0.36666666666666664
# proteins/supervised_topk_lab0.1%_run5 epoch: 9 val_loss: 0.7021164122080693 valid_acc 0.6517857142857143
# synthie/supervised_topk_lab0.1%_run5 epoch: 10 val_loss: 1.4195011138293512 valid_acc 0.325
# enzymes/supervised_gat_large_lab0.1%_run6 epoch: 16 val_loss: 1.6993390338424321 valid_acc 0.3
# proteins/supervised_gat_large_lab0.1%_run6 epoch: 9 val_loss: 0.6289750216148312 valid_acc 0.6785714285714286
# synthie/supervised_gat_large_lab0.1%_run6 epoch: 12 val_loss: 1.379364756266276 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.1%_run6 epoch: 2 val_loss: 1.766611920186324 valid_acc 0.23333333333333334
# proteins/supervised_gin0_large_lab0.1%_run6 epoch: 3 val_loss: 0.6500158118145342 valid_acc 0.6160714285714286
# synthie/supervised_gin0_large_lab0.1%_run6 epoch: 3 val_loss: 1.368702509328333 valid_acc 0.375
# enzymes/supervised_topk_lab0.1%_run6 epoch: 17 val_loss: 1.8160891407378776 valid_acc 0.4166666666666667
# proteins/supervised_topk_lab0.1%_run6 epoch: 17 val_loss: 0.6238693581244642 valid_acc 0.7232142857142857
# synthie/supervised_topk_lab0.1%_run6 epoch: 43 val_loss: 0.7868033818742062 valid_acc 0.725
# enzymes/supervised_gat_large_lab0.1%_run7 epoch: 4 val_loss: 1.7838349020640056 valid_acc 0.13333333333333333
# proteins/supervised_gat_large_lab0.1%_run7 epoch: 7 val_loss: 0.6052131313855165 valid_acc 0.6517857142857143
# synthie/supervised_gat_large_lab0.1%_run7 epoch: 7 val_loss: 1.3780194820533873 valid_acc 0.4
# enzymes/supervised_gin0_large_lab0.1%_run7 epoch: 13 val_loss: 1.5085334325168527 valid_acc 0.4
# proteins/supervised_gin0_large_lab0.1%_run7 epoch: 3 val_loss: 0.6693975107532292 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.1%_run7 epoch: 2 val_loss: 1.3524602425129872 valid_acc 0.425
# enzymes/supervised_topk_lab0.1%_run7 epoch: 12 val_loss: 2.2264609464577267 valid_acc 0.23333333333333334
# proteins/supervised_topk_lab0.1%_run7 epoch: 6 val_loss: 0.6692454762243282 valid_acc 0.625
# synthie/supervised_topk_lab0.1%_run7 epoch: 20 val_loss: 1.265878587340315 valid_acc 0.425
# enzymes/supervised_gat_large_lab0.1%_run8 epoch: 8 val_loss: 1.763719280820103 valid_acc 0.18333333333333332
# proteins/supervised_gat_large_lab0.1%_run8 epoch: 5 val_loss: 0.6082339021155072 valid_acc 0.7053571428571429
# synthie/supervised_gat_large_lab0.1%_run8 epoch: 22 val_loss: 1.3097179930444827 valid_acc 0.475
# enzymes/supervised_gin0_large_lab0.1%_run8 epoch: 6 val_loss: 1.66622103271767 valid_acc 0.4166666666666667
# proteins/supervised_gin0_large_lab0.1%_run8 epoch: 4 val_loss: 0.6070018847831196 valid_acc 0.7053571428571429
# synthie/supervised_gin0_large_lab0.1%_run8 epoch: 2 val_loss: 1.3855510987832866 valid_acc 0.4
# enzymes/supervised_topk_lab0.1%_run8 epoch: 9 val_loss: 2.126192873802738 valid_acc 0.23333333333333334
# proteins/supervised_topk_lab0.1%_run8 epoch: 9 val_loss: 0.6466932037859585 valid_acc 0.6785714285714286
# synthie/supervised_topk_lab0.1%_run8 epoch: 14 val_loss: 1.3168847752749762 valid_acc 0.475
# enzymes/supervised_gat_large_lab0.1%_run9 epoch: 7 val_loss: 1.7318331646364789 valid_acc 0.3
# proteins/supervised_gat_large_lab0.1%_run9 epoch: 10 val_loss: 0.6644698342877496 valid_acc 0.6696428571428571
# synthie/supervised_gat_large_lab0.1%_run9 epoch: 1 val_loss: 1.37472842027509 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.1%_run9 epoch: 4 val_loss: 1.7270156949579358 valid_acc 0.21666666666666667
# proteins/supervised_gin0_large_lab0.1%_run9 epoch: 1 val_loss: 0.6536057611460525 valid_acc 0.6964285714285714
# synthie/supervised_gin0_large_lab0.1%_run9 epoch: 4 val_loss: 1.3720436400423448 valid_acc 0.25
# enzymes/supervised_topk_lab0.1%_run9 epoch: 12 val_loss: 2.197379635702837 valid_acc 0.3
# proteins/supervised_topk_lab0.1%_run9 epoch: 2 val_loss: 0.8181132225549466 valid_acc 0.6160714285714286
# synthie/supervised_topk_lab0.1%_run9 epoch: 7 val_loss: 1.5836171870443279 valid_acc 0.45
# enzymes/supervised_gat_large_lab0.05%_run0 epoch: 3 val_loss: 1.7989643880461736 valid_acc 0.25
# proteins/supervised_gat_large_lab0.05%_run0 epoch: 1 val_loss: 0.6722426195580588 valid_acc 0.5982142857142857
# synthie/supervised_gat_large_lab0.05%_run0 epoch: 2 val_loss: 1.3772105955063028 valid_acc 0.425
# enzymes/supervised_gin0_large_lab0.05%_run0 epoch: 5 val_loss: 1.7220087790718446 valid_acc 0.25
# proteins/supervised_gin0_large_lab0.05%_run0 epoch: 1 val_loss: 0.6940035584718135 valid_acc 0.5892857142857143
# synthie/supervised_gin0_large_lab0.05%_run0 epoch: 2 val_loss: 1.3347617650221766 valid_acc 0.425
# enzymes/supervised_topk_lab0.05%_run0 epoch: 8 val_loss: 2.6696060288267853 valid_acc 0.25
# proteins/supervised_topk_lab0.05%_run0 epoch: 1 val_loss: 0.691029964631936 valid_acc 0.7321428571428571
# synthie/supervised_topk_lab0.05%_run0 epoch: 16 val_loss: 1.2980522585298677 valid_acc 0.55
# enzymes/supervised_gat_large_lab0.05%_run1 epoch: 4 val_loss: 1.758238315142852 valid_acc 0.25
# proteins/supervised_gat_large_lab0.05%_run1 epoch: 3 val_loss: 0.6482736570726741 valid_acc 0.6339285714285714
# synthie/supervised_gat_large_lab0.05%_run1 epoch: 5 val_loss: 1.3817344616960596 valid_acc 0.45
# enzymes/supervised_gin0_large_lab0.05%_run1 epoch: 2 val_loss: 1.7775031348817345 valid_acc 0.15
# proteins/supervised_gin0_large_lab0.05%_run1 epoch: 2 val_loss: 0.6300008264404756 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.05%_run1 epoch: 4 val_loss: 1.310069002504424 valid_acc 0.3
# enzymes/supervised_topk_lab0.05%_run1 epoch: 2 val_loss: 3.4358796936342086 valid_acc 0.3
# proteins/supervised_topk_lab0.05%_run1 epoch: 2 val_loss: 0.5762396724383897 valid_acc 0.8035714285714286
# synthie/supervised_topk_lab0.05%_run1 epoch: 22 val_loss: 0.8588413278155288 valid_acc 0.575
# enzymes/supervised_gat_large_lab0.05%_run2 epoch: 4 val_loss: 1.7835881222494154 valid_acc 0.2833333333333333
# proteins/supervised_gat_large_lab0.05%_run2 epoch: 4 val_loss: 0.6441648436708344 valid_acc 0.6607142857142857
# synthie/supervised_gat_large_lab0.05%_run2 epoch: 9 val_loss: 1.373448975326479 valid_acc 0.2
# enzymes/supervised_gin0_large_lab0.05%_run2 epoch: 2 val_loss: 1.7446797439873658 valid_acc 0.35
# proteins/supervised_gin0_large_lab0.05%_run2 epoch: 1 val_loss: 0.690460009004469 valid_acc 0.5089285714285714
# synthie/supervised_gin0_large_lab0.05%_run2 epoch: 8 val_loss: 1.2938297788826332 valid_acc 0.375
# enzymes/supervised_topk_lab0.05%_run2 epoch: 10 val_loss: 2.6823535033812127 valid_acc 0.45
# proteins/supervised_topk_lab0.05%_run2 epoch: 4 val_loss: 0.940917294848839 valid_acc 0.7589285714285714
# synthie/supervised_topk_lab0.05%_run2 epoch: 24 val_loss: 1.4961875983920878 valid_acc 0.4
# enzymes/supervised_gat_large_lab0.05%_run3 epoch: 1 val_loss: 1.7864506427116946 valid_acc 0.26666666666666666
# proteins/supervised_gat_large_lab0.05%_run3 epoch: 3 val_loss: 0.687445410543291 valid_acc 0.5982142857142857
# synthie/supervised_gat_large_lab0.05%_run3 epoch: 1 val_loss: 1.3735598473968902 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.05%_run3 epoch: 4 val_loss: 1.669754402577376 valid_acc 0.31666666666666665
# proteins/supervised_gin0_large_lab0.05%_run3 epoch: 1 val_loss: 0.7730039598090077 valid_acc 0.5089285714285714
# synthie/supervised_gin0_large_lab0.05%_run3 epoch: 2 val_loss: 1.3691478810812299 valid_acc 0.4
# enzymes/supervised_topk_lab0.05%_run3 epoch: 4 val_loss: 3.1061865536002227 valid_acc 0.16666666666666666
# proteins/supervised_topk_lab0.05%_run3 epoch: 1 val_loss: 0.840848375826887 valid_acc 0.5982142857142857
# synthie/supervised_topk_lab0.05%_run3 epoch: 9 val_loss: 1.5092219830810867 valid_acc 0.275
# enzymes/supervised_gat_large_lab0.05%_run4 epoch: 3 val_loss: 1.8135219760639771 valid_acc 0.21666666666666667
# proteins/supervised_gat_large_lab0.05%_run4 epoch: 1 val_loss: 0.6979277401224464 valid_acc 0.5446428571428571
# synthie/supervised_gat_large_lab0.05%_run4 epoch: 10 val_loss: 1.3748575323175314 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.05%_run4 epoch: 3 val_loss: 1.724150002944962 valid_acc 0.26666666666666666
# proteins/supervised_gin0_large_lab0.05%_run4 epoch: 1 val_loss: 0.7775081868391112 valid_acc 0.5357142857142857
# synthie/supervised_gin0_large_lab0.05%_run4 epoch: 1 val_loss: 1.3905136016066575 valid_acc 0.275
# enzymes/supervised_topk_lab0.05%_run4 epoch: 7 val_loss: 2.1771833449602127 valid_acc 0.2833333333333333
# proteins/supervised_topk_lab0.05%_run4 epoch: 5 val_loss: 0.9642843487126098 valid_acc 0.6875
# synthie/supervised_topk_lab0.05%_run4 epoch: 7 val_loss: 1.475972015303669 valid_acc 0.425
# enzymes/supervised_gat_large_lab0.05%_run5 epoch: 1 val_loss: 1.8108148365918386 valid_acc 0.15
# proteins/supervised_gat_large_lab0.05%_run5 epoch: 4 val_loss: 0.6634520229117775 valid_acc 0.7053571428571429
# synthie/supervised_gat_large_lab0.05%_run5 epoch: 2 val_loss: 1.3924326758271472 valid_acc 0.2
# enzymes/supervised_gin0_large_lab0.05%_run5 epoch: 6 val_loss: 1.7492303908775764 valid_acc 0.3
# proteins/supervised_gin0_large_lab0.05%_run5 epoch: 1 val_loss: 0.6728415841680705 valid_acc 0.625
# synthie/supervised_gin0_large_lab0.05%_run5 epoch: 6 val_loss: 1.3618796187748747 valid_acc 0.325
# enzymes/supervised_topk_lab0.05%_run5 epoch: 16 val_loss: 2.0458550498170673 valid_acc 0.3
# proteins/supervised_topk_lab0.05%_run5 epoch: 4 val_loss: 0.9028001277662544 valid_acc 0.5803571428571429
# synthie/supervised_topk_lab0.05%_run5 epoch: 1 val_loss: 3.172220584929145 valid_acc 0.35
# enzymes/supervised_gat_large_lab0.05%_run6 epoch: 4 val_loss: 1.7863982536965408 valid_acc 0.13333333333333333
# proteins/supervised_gat_large_lab0.05%_run6 epoch: 2 val_loss: 0.6878699727411817 valid_acc 0.7053571428571429
# synthie/supervised_gat_large_lab0.05%_run6 epoch: 5 val_loss: 1.373635554869558 valid_acc 0.425
# enzymes/supervised_gin0_large_lab0.05%_run6 epoch: 1 val_loss: 1.7864423431636054 valid_acc 0.2833333333333333
# proteins/supervised_gin0_large_lab0.05%_run6 epoch: 4 val_loss: 0.6673749299110345 valid_acc 0.6160714285714286
# synthie/supervised_gin0_large_lab0.05%_run6 epoch: 2 val_loss: 1.3575040089323165 valid_acc 0.45
# enzymes/supervised_topk_lab0.05%_run6 epoch: 9 val_loss: 3.3196460802724044 valid_acc 0.31666666666666665
# proteins/supervised_topk_lab0.05%_run6 epoch: 4 val_loss: 1.137091770480695 valid_acc 0.625
# synthie/supervised_topk_lab0.05%_run6 epoch: 10 val_loss: 1.5501394399463664 valid_acc 0.375
# enzymes/supervised_gat_large_lab0.05%_run7 epoch: 5 val_loss: 1.7867894333894137 valid_acc 0.25
# proteins/supervised_gat_large_lab0.05%_run7 epoch: 4 val_loss: 0.6261235194165441 valid_acc 0.6428571428571429
# synthie/supervised_gat_large_lab0.05%_run7 epoch: 5 val_loss: 1.3759260916021552 valid_acc 0.3
# enzymes/supervised_gin0_large_lab0.05%_run7 epoch: 6 val_loss: 1.6951117211041793 valid_acc 0.3333333333333333
# proteins/supervised_gin0_large_lab0.05%_run7 epoch: 1 val_loss: 0.6902941572514609 valid_acc 0.5267857142857143
# synthie/supervised_gin0_large_lab0.05%_run7 epoch: 3 val_loss: 1.3848332610168055 valid_acc 0.25
# enzymes/supervised_topk_lab0.05%_run7 epoch: 12 val_loss: 2.446351104312473 valid_acc 0.3333333333333333
# proteins/supervised_topk_lab0.05%_run7 epoch: 3 val_loss: 0.7355438535938555 valid_acc 0.7321428571428571
# synthie/supervised_topk_lab0.05%_run7 epoch: 1 val_loss: 3.3954107761383057 valid_acc 0.4
# enzymes/supervised_gat_large_lab0.05%_run8 epoch: 9 val_loss: 1.695539458408186 valid_acc 0.3
# proteins/supervised_gat_large_lab0.05%_run8 epoch: 1 val_loss: 0.6678997712535106 valid_acc 0.6696428571428571
# synthie/supervised_gat_large_lab0.05%_run8 epoch: 8 val_loss: 1.3368530648726005 valid_acc 0.45
# enzymes/supervised_gin0_large_lab0.05%_run8 epoch: 3 val_loss: 1.8043240291626792 valid_acc 0.2
# proteins/supervised_gin0_large_lab0.05%_run8 epoch: 3 val_loss: 0.6295260596398485 valid_acc 0.6517857142857143
# synthie/supervised_gin0_large_lab0.05%_run8 epoch: 5 val_loss: 1.3209817183049184 valid_acc 0.325
# enzymes/supervised_topk_lab0.05%_run8 epoch: 1 val_loss: 3.2343195789939276 valid_acc 0.2
# proteins/supervised_topk_lab0.05%_run8 epoch: 4 val_loss: 0.7375543581128438 valid_acc 0.6428571428571429
# synthie/supervised_topk_lab0.05%_run8 epoch: 10 val_loss: 1.5795095685928586 valid_acc 0.45
# enzymes/supervised_gat_large_lab0.05%_run9 epoch: 2 val_loss: 1.8005680799225525 valid_acc 0.13333333333333333
# proteins/supervised_gat_large_lab0.05%_run9 epoch: 1 val_loss: 0.6863501252699303 valid_acc 0.6696428571428571
# synthie/supervised_gat_large_lab0.05%_run9 epoch: 26 val_loss: 1.1864600503255451 valid_acc 0.475
# enzymes/supervised_gin0_large_lab0.05%_run9 epoch: 3 val_loss: 1.774329066033266 valid_acc 0.16666666666666666
# proteins/supervised_gin0_large_lab0.05%_run9 epoch: 1 val_loss: 0.6866635380340411 valid_acc 0.6160714285714286
# synthie/supervised_gin0_large_lab0.05%_run9 epoch: 1 val_loss: 1.3878484619291205 valid_acc 0.225
# enzymes/supervised_topk_lab0.05%_run9 epoch: 7 val_loss: 3.265656755541876 valid_acc 0.18333333333333332
# proteins/supervised_topk_lab0.05%_run9 epoch: 4 val_loss: 0.916452561337525 valid_acc 0.6964285714285714
# synthie/supervised_topk_lab0.05%_run9 epoch: 36 val_loss: 2.092158110286441 valid_acc 0.475
# enzymes/supervised_gat_large_lab0.01%_run0 epoch: 1 val_loss: 1.8083174534675497 valid_acc 0.06666666666666667
# proteins/supervised_gat_large_lab0.01%_run0 epoch: 1 val_loss: 0.724998096649989 valid_acc 0.5714285714285714
# synthie/supervised_gat_large_lab0.01%_run0 epoch: 1 val_loss: 1.3687495299034718 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.01%_run0 epoch: 5 val_loss: 1.6731205940494676 valid_acc 0.26666666666666666
# proteins/supervised_gin0_large_lab0.01%_run0 epoch: 2 val_loss: 0.6280018400371544 valid_acc 0.6696428571428571
# synthie/supervised_gin0_large_lab0.01%_run0 epoch: 14 val_loss: 1.3425013175670137 valid_acc 0.325
# enzymes/supervised_topk_lab0.01%_run0 epoch: 3 val_loss: 3.7698224287492947 valid_acc 0.2833333333333333
# proteins/supervised_topk_lab0.01%_run0 epoch: 5 val_loss: 2.1096928151288825 valid_acc 0.6071428571428571
# synthie/supervised_topk_lab0.01%_run0 epoch: 12 val_loss: 1.7092674349745114 valid_acc 0.3
# enzymes/supervised_gat_large_lab0.01%_run1 epoch: 1 val_loss: 1.7863543252507132 valid_acc 0.26666666666666666
# proteins/supervised_gat_large_lab0.01%_run1 epoch: 1 val_loss: 0.7837334459016579 valid_acc 0.5535714285714286
# synthie/supervised_gat_large_lab0.01%_run1 epoch: 25 val_loss: 1.2980347778648138 valid_acc 0.45
# enzymes/supervised_gin0_large_lab0.01%_run1 epoch: 1 val_loss: 1.7998105179031816 valid_acc 0.2
# proteins/supervised_gin0_large_lab0.01%_run1 epoch: 2 val_loss: 0.6919233918619085 valid_acc 0.5178571428571429
# synthie/supervised_gin0_large_lab0.01%_run1 epoch: 2 val_loss: 1.381759844043038 valid_acc 0.4
# enzymes/supervised_topk_lab0.01%_run1 epoch: 3 val_loss: 4.120491315476657 valid_acc 0.15
# proteins/supervised_topk_lab0.01%_run1 epoch: 5 val_loss: 1.6920891398530071 valid_acc 0.5535714285714286
# synthie/supervised_topk_lab0.01%_run1 epoch: 8 val_loss: 2.338221629045651 valid_acc 0.225
# enzymes/supervised_gat_large_lab0.01%_run2 epoch: 2 val_loss: 1.7832407554182552 valid_acc 0.23333333333333334
# proteins/supervised_gat_large_lab0.01%_run2 epoch: 1 val_loss: 0.7026594299200473 valid_acc 0.44642857142857145
# synthie/supervised_gat_large_lab0.01%_run2 epoch: 13 val_loss: 1.3779014673233032 valid_acc 0.375
# enzymes/supervised_gin0_large_lab0.01%_run2 epoch: 1 val_loss: 1.7872422263863381 valid_acc 0.18333333333333332
# proteins/supervised_gin0_large_lab0.01%_run2 epoch: 1 val_loss: 0.6583329419423921 valid_acc 0.6607142857142857
# synthie/supervised_gin0_large_lab0.01%_run2 epoch: 4 val_loss: 1.3845033252426466 valid_acc 0.35
# enzymes/supervised_topk_lab0.01%_run2 epoch: 2 val_loss: 3.5975209317834254 valid_acc 0.2
# proteins/supervised_topk_lab0.01%_run2 epoch: 3 val_loss: 1.3362751963056452 valid_acc 0.7053571428571429
# synthie/supervised_topk_lab0.01%_run2 epoch: 6 val_loss: 2.411360654425114 valid_acc 0.15
# enzymes/supervised_gat_large_lab0.01%_run3 epoch: 6 val_loss: 1.790752241452535 valid_acc 0.2
# proteins/supervised_gat_large_lab0.01%_run3 epoch: 1 val_loss: 0.6892483946111454 valid_acc 0.5982142857142857
# synthie/supervised_gat_large_lab0.01%_run3 epoch: 16 val_loss: 1.3982256728941234 valid_acc 0.225
# enzymes/supervised_gin0_large_lab0.01%_run3 epoch: 4 val_loss: 1.7658668858393523 valid_acc 0.26666666666666666
# proteins/supervised_gin0_large_lab0.01%_run3 epoch: 1 val_loss: 0.6968312422600094 valid_acc 0.5357142857142857
# synthie/supervised_gin0_large_lab0.01%_run3 epoch: 6 val_loss: 1.294490545280376 valid_acc 0.45
# enzymes/supervised_topk_lab0.01%_run3 epoch: 9 val_loss: 3.3802625693026043 valid_acc 0.18333333333333332
# proteins/supervised_topk_lab0.01%_run3 epoch: 3 val_loss: 1.8109153933713664 valid_acc 0.6160714285714286
# synthie/supervised_topk_lab0.01%_run3 epoch: 17 val_loss: 2.5532858669757843 valid_acc 0.375
# enzymes/supervised_gat_large_lab0.01%_run4 epoch: 1 val_loss: 1.7963918492870528 valid_acc 0.23333333333333334
# proteins/supervised_gat_large_lab0.01%_run4 epoch: 1 val_loss: 0.6843625867578584 valid_acc 0.6428571428571429
# synthie/supervised_gat_large_lab0.01%_run4 epoch: 22 val_loss: 1.2595632428332313 valid_acc 0.4
# enzymes/supervised_gin0_large_lab0.01%_run4 epoch: 5 val_loss: 1.67457466656661 valid_acc 0.3
# proteins/supervised_gin0_large_lab0.01%_run4 epoch: 1 val_loss: 0.6917377477730173 valid_acc 0.5446428571428571
# synthie/supervised_gin0_large_lab0.01%_run4 epoch: 5 val_loss: 1.3510913333037284 valid_acc 0.3
# enzymes/supervised_topk_lab0.01%_run4 epoch: 12 val_loss: 3.814911645391713 valid_acc 0.21666666666666667
# proteins/supervised_topk_lab0.01%_run4 epoch: 2 val_loss: 1.0982486040369102 valid_acc 0.6071428571428571
# synthie/supervised_topk_lab0.01%_run4 epoch: 8 val_loss: 2.2323575353244993 valid_acc 0.3
# enzymes/supervised_gat_large_lab0.01%_run5 epoch: 1 val_loss: 1.780623247087464 valid_acc 0.2
# proteins/supervised_gat_large_lab0.01%_run5 epoch: 2 val_loss: 0.6836774850645071 valid_acc 0.6517857142857143
# synthie/supervised_gat_large_lab0.01%_run5 epoch: 1 val_loss: 1.3767756020303161 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.01%_run5 epoch: 4 val_loss: 1.7924936650272363 valid_acc 0.18333333333333332
# proteins/supervised_gin0_large_lab0.01%_run5 epoch: 3 val_loss: 0.6598343690824475 valid_acc 0.5892857142857143
# synthie/supervised_gin0_large_lab0.01%_run5 epoch: 3 val_loss: 1.3626628387719393 valid_acc 0.4
# enzymes/supervised_topk_lab0.01%_run5 epoch: 4 val_loss: 3.7995307264346465 valid_acc 0.18333333333333332
# proteins/supervised_topk_lab0.01%_run5 epoch: 3 val_loss: 1.4236607879346812 valid_acc 0.6785714285714286
# synthie/supervised_topk_lab0.01%_run5 epoch: 14 val_loss: 2.1040077408673556 valid_acc 0.375
# enzymes/supervised_gat_large_lab0.01%_run6 epoch: 3 val_loss: 1.7897353732785064 valid_acc 0.2
# proteins/supervised_gat_large_lab0.01%_run6 epoch: 1 val_loss: 0.6875019807040557 valid_acc 0.5357142857142857
# synthie/supervised_gat_large_lab0.01%_run6 epoch: 13 val_loss: 1.3653341988299756 valid_acc 0.45
# enzymes/supervised_gin0_large_lab0.01%_run6 epoch: 1 val_loss: 1.785380597297962 valid_acc 0.2
# proteins/supervised_gin0_large_lab0.01%_run6 epoch: 1 val_loss: 0.6933360729033861 valid_acc 0.5178571428571429
# synthie/supervised_gin0_large_lab0.01%_run6 epoch: 3 val_loss: 1.3716967991239513 valid_acc 0.425
# enzymes/supervised_topk_lab0.01%_run6 epoch: 3 val_loss: 3.7037982799027245 valid_acc 0.25
# proteins/supervised_topk_lab0.01%_run6 epoch: 9 val_loss: 1.7779107182984453 valid_acc 0.5982142857142857
# synthie/supervised_topk_lab0.01%_run6 epoch: 35 val_loss: 2.4133933389474493 valid_acc 0.4
# enzymes/supervised_gat_large_lab0.01%_run7 epoch: 5 val_loss: 1.7392214003709068 valid_acc 0.16666666666666666
# proteins/supervised_gat_large_lab0.01%_run7 epoch: 1 val_loss: 0.7000444792481986 valid_acc 0.5357142857142857
# synthie/supervised_gat_large_lab0.01%_run7 epoch: 16 val_loss: 1.3423417516486356 valid_acc 0.475
# enzymes/supervised_gin0_large_lab0.01%_run7 epoch: 1 val_loss: 1.7886794472031773 valid_acc 0.21666666666666667
# proteins/supervised_gin0_large_lab0.01%_run7 epoch: 1 val_loss: 0.6732862339389545 valid_acc 0.6339285714285714
# synthie/supervised_gin0_large_lab0.01%_run7 epoch: 8 val_loss: 1.292338447307977 valid_acc 0.525
# enzymes/supervised_topk_lab0.01%_run7 epoch: 6 val_loss: 3.9101391038283926 valid_acc 0.16666666666666666
# proteins/supervised_topk_lab0.01%_run7 epoch: 3 val_loss: 1.2947847226408045 valid_acc 0.7232142857142857
# synthie/supervised_topk_lab0.01%_run7 epoch: 15 val_loss: 2.1203558253219237 valid_acc 0.3
# enzymes/supervised_gat_large_lab0.01%_run8 epoch: 2 val_loss: 1.7956735643635982 valid_acc 0.06666666666666667
# proteins/supervised_gat_large_lab0.01%_run8 epoch: 1 val_loss: 0.6754631700496344 valid_acc 0.6428571428571429
# synthie/supervised_gat_large_lab0.01%_run8 epoch: 21 val_loss: 1.377343029014824 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.01%_run8 epoch: 4 val_loss: 1.6979079649119282 valid_acc 0.3
# proteins/supervised_gin0_large_lab0.01%_run8 epoch: 1 val_loss: 0.7137818980796135 valid_acc 0.4732142857142857
# synthie/supervised_gin0_large_lab0.01%_run8 epoch: 4 val_loss: 1.3773840986644372 valid_acc 0.35
# enzymes/supervised_topk_lab0.01%_run8 epoch: 5 val_loss: 3.26300485432148 valid_acc 0.2
# proteins/supervised_topk_lab0.01%_run8 epoch: 8 val_loss: 2.0286997724361364 valid_acc 0.7232142857142857
# synthie/supervised_topk_lab0.01%_run8 epoch: 5 val_loss: 2.870918903529804 valid_acc 0.325
# enzymes/supervised_gat_large_lab0.01%_run9 epoch: 1 val_loss: 1.7966820258043994 valid_acc 0.26666666666666666
# proteins/supervised_gat_large_lab0.01%_run9 epoch: 1 val_loss: 0.673102273847765 valid_acc 0.6339285714285714
# synthie/supervised_gat_large_lab0.01%_run9 epoch: 2 val_loss: 1.367339796661713 valid_acc 0.325
# enzymes/supervised_gin0_large_lab0.01%_run9 epoch: 7 val_loss: 1.5914015849431355 valid_acc 0.3333333333333333
# proteins/supervised_gin0_large_lab0.01%_run9 epoch: 1 val_loss: 0.7598013119435171 valid_acc 0.41964285714285715
# synthie/supervised_gin0_large_lab0.01%_run9 epoch: 3 val_loss: 1.365352287417964 valid_acc 0.275
# enzymes/supervised_topk_lab0.01%_run9 epoch: 6 val_loss: 3.9314929436528407 valid_acc 0.18333333333333332
# proteins/supervised_topk_lab0.01%_run9 epoch: 5 val_loss: 1.8696230036746473 valid_acc 0.6696428571428571
# synthie/supervised_topk_lab0.01%_run9 epoch: 1 val_loss: 3.7207018215199468 valid_acc 0.4

# %%
import pandas as pd

out = pd.Series({k:v.history[-1]["valid_acc"] for k,v in data_trainers.items()}).reset_index(name="accuracy")
splitted = out["index"].str.split("/", expand = True)
out["data"] = splitted[0]
out["models"] = splitted[1]

splitted2 = out["models"].str.split("_run", expand = True)
out["models"] = splitted2[0]
out["run"] = splitted2[1]

splitted3 = out["models"].str.split("_lab", expand = True)
out["models"] = splitted3[0]
out["lab"] = splitted3[1]


out.drop(columns =["index"], inplace = True) 

out.groupby(["data", "models", "lab"]).describe()
# Out:
#                                      accuracy                                \
#                                         count      mean       std       min
# data     models                lab
# enzymes  supervised_gat_large  0.01%     10.0  0.258333  0.032632  0.200000
#                                0.05%     10.0  0.311667  0.055583  0.233333
#                                0.1%      10.0  0.363333  0.042889  0.283333
#                                0.3%      10.0  0.496667  0.090880  0.350000
#                                0.5%      10.0  0.505000  0.081669  0.316667
#                                1%        10.0  0.615000  0.089045  0.450000
#          supervised_gin0_large 0.01%     10.0  0.291667  0.059447  0.200000
#                                0.05%     10.0  0.318333  0.060067  0.183333
#                                0.1%      10.0  0.400000  0.047140  0.333333
#                                0.3%      10.0  0.546667  0.054320  0.433333
#                                0.5%      10.0  0.543333  0.063925  0.466667
#                                1%        10.0  0.648333  0.048718  0.566667
#          supervised_topk       0.01%     10.0  0.260000  0.045270  0.183333
#                                0.05%     10.0  0.330000  0.067036  0.200000
#                                0.1%      10.0  0.400000  0.056108  0.333333
#                                0.3%      10.0  0.481667  0.046779  0.400000
#                                0.5%      10.0  0.601667  0.074722  0.450000
#                                1%        10.0  0.655000  0.043069  0.600000
# proteins supervised_gat_large  0.01%     10.0  0.617857  0.037125  0.571429
#                                0.05%     10.0  0.680357  0.024105  0.642857
#                                0.1%      10.0  0.720536  0.036946  0.651786
#                                0.3%      10.0  0.749107  0.029896  0.705357
#                                0.5%      10.0  0.776786  0.055360  0.696429
#                                1%        10.0  0.799107  0.037232  0.732143
#          supervised_gin0_large 0.01%     10.0  0.600893  0.054400  0.491071
#                                0.05%     10.0  0.658929  0.048504  0.589286
#                                0.1%      10.0  0.698214  0.032819  0.660714
#                                0.3%      10.0  0.718750  0.032940  0.678571
#                                0.5%      10.0  0.754464  0.030132  0.696429
#                                1%        10.0  0.766071  0.036886  0.723214
#          supervised_topk       0.01%     10.0  0.675000  0.043781  0.607143
#                                0.05%     10.0  0.723214  0.043334  0.660714
#                                0.1%      10.0  0.720536  0.039941  0.642857
#                                0.3%      10.0  0.753571  0.031553  0.705357
#                                0.5%      10.0  0.772321  0.021150  0.723214
#                                1%        10.0  0.783036  0.026967  0.732143
# synthie  supervised_gat_large  0.01%     10.0  0.387500  0.061520  0.325000
#                                0.05%     10.0  0.387500  0.081862  0.250000
#                                0.1%      10.0  0.440000  0.100830  0.325000
#                                0.3%      10.0  0.517500  0.069771  0.375000
#                                0.5%      10.0  0.507500  0.084204  0.400000
#                                1%        10.0  0.517500  0.063519  0.425000
#          supervised_gin0_large 0.01%     10.0  0.405000  0.062138  0.350000
#                                0.05%     10.0  0.395000  0.053748  0.300000
#                                0.1%      10.0  0.437500  0.053033  0.375000
#                                0.3%      10.0  0.470000  0.051099  0.375000
#                                0.5%      10.0  0.522500  0.047799  0.425000
#                                1%        10.0  0.635000  0.067905  0.550000
#          supervised_topk       0.01%     10.0  0.397500  0.051975  0.325000
#                                0.05%     10.0  0.475000  0.083333  0.350000
#                                0.1%      10.0  0.497500  0.094612  0.400000
#                                0.3%      10.0  0.610000  0.072839  0.475000
#                                0.5%      10.0  0.677500  0.112083  0.475000
#                                1%        10.0  0.747500  0.123856  0.525000
#
#
#                                            25%       50%       75%       max
# data     models                lab
# enzymes  supervised_gat_large  0.01%  0.237500  0.266667  0.283333  0.300000
#                                0.05%  0.283333  0.300000  0.341667  0.433333
#                                0.1%   0.366667  0.366667  0.383333  0.433333
#                                0.3%   0.441667  0.500000  0.550000  0.616667
#                                0.5%   0.483333  0.500000  0.545833  0.633333
#                                1%     0.554167  0.633333  0.687500  0.733333
#          supervised_gin0_large 0.01%  0.241667  0.308333  0.341667  0.366667
#                                0.05%  0.300000  0.325000  0.345833  0.400000
#                                0.1%   0.362500  0.408333  0.429167  0.466667
#                                0.3%   0.533333  0.541667  0.591667  0.616667
#                                0.5%   0.487500  0.541667  0.595833  0.633333
#                                1%     0.620833  0.658333  0.679167  0.716667
#          supervised_topk       0.01%  0.237500  0.258333  0.283333  0.350000
#                                0.05%  0.300000  0.316667  0.375000  0.450000
#                                0.1%   0.345833  0.408333  0.416667  0.483333
#                                0.3%   0.458333  0.483333  0.516667  0.533333
#                                0.5%   0.554167  0.616667  0.645833  0.700000
#                                1%     0.637500  0.650000  0.666667  0.750000
# proteins supervised_gat_large  0.01%  0.575893  0.638393  0.642857  0.660714
#                                0.05%  0.662946  0.678571  0.694196  0.723214
#                                0.1%   0.698661  0.723214  0.745536  0.776786
#                                0.3%   0.732143  0.741071  0.763393  0.812500
#                                0.5%   0.743304  0.763393  0.803571  0.866071
#                                1%     0.785714  0.799107  0.812500  0.875000
#          supervised_gin0_large 0.01%  0.580357  0.611607  0.636161  0.669643
#                                0.05%  0.622768  0.647321  0.700893  0.723214
#                                0.1%   0.680804  0.687500  0.703125  0.767857
#                                0.3%   0.694196  0.714286  0.723214  0.785714
#                                0.5%   0.745536  0.758929  0.767857  0.794643
#                                1%     0.734375  0.758929  0.792411  0.830357
#          supervised_topk       0.01%  0.642857  0.691964  0.705357  0.723214
#                                0.05%  0.698661  0.705357  0.754464  0.803571
#                                0.1%   0.707589  0.723214  0.743304  0.776786
#                                0.3%   0.741071  0.750000  0.779018  0.803571
#                                0.5%   0.761161  0.781250  0.785714  0.794643
#                                1%     0.767857  0.781250  0.801339  0.830357
# synthie  supervised_gat_large  0.01%  0.331250  0.362500  0.450000  0.475000
#                                0.05%  0.325000  0.400000  0.443750  0.525000
#                                0.1%   0.381250  0.437500  0.475000  0.675000
#                                0.3%   0.506250  0.525000  0.568750  0.600000
#                                0.5%   0.431250  0.500000  0.568750  0.650000
#                                1%     0.500000  0.500000  0.556250  0.625000
#          supervised_gin0_large 0.01%  0.356250  0.387500  0.418750  0.525000
#                                0.05%  0.375000  0.400000  0.425000  0.475000
#                                0.1%   0.381250  0.450000  0.475000  0.500000
#                                0.3%   0.437500  0.475000  0.493750  0.550000
#                                0.5%   0.500000  0.525000  0.543750  0.600000
#                                1%     0.575000  0.637500  0.668750  0.750000
#          supervised_topk       0.01%  0.356250  0.400000  0.418750  0.500000
#                                0.05%  0.431250  0.450000  0.531250  0.600000
#                                0.1%   0.456250  0.475000  0.500000  0.725000
#                                0.3%   0.581250  0.637500  0.668750  0.675000
#                                0.5%   0.650000  0.687500  0.743750  0.850000
#                                1%     0.668750  0.775000  0.837500  0.925000

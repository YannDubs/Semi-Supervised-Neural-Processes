# %% [markdown]
# # Tutorial 7 : Neural Process Graphs
#
# Last Update : 28 July 2019
#
# **Aim**:

# %%
N_THREADS = 8
# Nota Bene : notebooks don't deallocate GPU memory
IS_FORCE_CPU = True # can also be set in the trainer

# %% [markdown]
# ## Environment

# %%
cd ..
# Out:
# /conv

# %%
# %autosave 600
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# CENTER PLOTS
from IPython.core.display import HTML
display(HTML(""" <style> .output_png {display: table-cell; text-align: center; margin:auto; }
.prompt display:none;}  </style>"""))

import os
if IS_FORCE_CPU:
    os.environ['CUDA_VISIBLE_DEVICES'] = ""
    
import sys
sys.path.append("notebooks")

import numpy as np
import matplotlib.pyplot as plt
import torch
torch.set_num_threads(N_THREADS)
# Out:
# Autosaving every 600 seconds
#  <style> .output_png {display: table-cell; text-align: center; margin:auto; }
# .prompt display:none;}  </style>

# %% [markdown]
# # Dataset
#
# Cora, Citeseer, Pubmed
# PROTEINS, enzymes

# %%
from torch_geometric.datasets import TUDataset, Planetoid, PPI, QM7b, ModelNet
from sklearn.preprocessing import StandardScaler
from utils.data.helpers import make_ssl_dataset_
from copy import deepcopy

# %%
from random import shuffle

datasets=dict(enzymes = TUDataset(root='data/ENZYMES', name='ENZYMES', use_node_attr=True, ),
             proteins = TUDataset(root='data/PROTEINS_full', name='PROTEINS_full', use_node_attr=True),
             synthie = TUDataset(root='data/Synthie', name='Synthie', use_node_attr=True))

data_specific_kwargs = {k:dict(y_dim=d.num_node_features,
                               t_dim=d.num_classes
                              ) 
                        for k,d in datasets.items()}

def train_test_split(d, transform=lambda x : StandardScaler().fit_transform(x)):
    if transform is not None:
        d.data.x = torch.from_numpy(transform(d.data.x.numpy()))
    d = d.shuffle()
    return d[:-len(d) // 10], d[-len(d) // 10:]

from skssl.utils.helpers import cont_tuple_to_tuple_cont

def ssl_graph(train_test, label_perc=0.1, is_add_test=True, is_augment=True):
    train, test = train_test
    make_ssl_dataset_(train, label_perc, is_graph=True)
    list_train, list_test = list(train), list(test)
    
    if is_add_test:
        test = deepcopy(test)
        test.data.y = torch.ones_like(test.data.y) * -1
        list_train += list(test)
        
    if is_augment:
        indcs_labels = (train.data.y != -1)
        factor = int((1 - label_perc)/label_perc)-1
        labeled_data = [d for d,i in zip(list_train, indcs_labels) if i]
        list_train += labeled_data * factor
        
    return list_train, list_test

# %%
X_DIM = 2  # 2D spatial input 
#Y_DIM = data.shape[0]
N_TARGETS = None#data.n_classes

label_percentages = [0.01, 0.05, 0.1, 0.3, 0.5, 1]

# %% [markdown]
# # Model

# %%
from skssl.transformers import GraphConvNeuralProcess, GraphNeuralProcessSSLLoss
from skssl.predefined import GCN, UnetGCN, GraphUNet, MLP
from skssl.transformers.neuralproc.datasplit import precomputed_cntxt_trgt_split
from functools import partial
from torch_geometric.nn import GCNConv
import torch.nn as nn

models = {}


m_clf = lambda y_dim, t_dim : partial(GraphConvNeuralProcess,y_dim=y_dim,
                         r_dim=32,
                                Classifier=partial(MLP, input_size=128+y_dim*3, output_size=t_dim, 
                                        dropout=0., hidden_size=64, n_hidden_layers=3, is_res=True),
                                      is_clf_features=True,
                          TmpSelfAttn=partial(UnetGCN, 
                                              is_sum_res=True,
                                              Conv=partial(GCNConv, improved=True), 
                                              max_nchannels=128, n_layers=5,
                                             _is_summary=True))

models["ssl_classifier_gcnp_unetgcn"] = m_clf

m_trnsf = lambda y_dim, t_dim : partial(GraphConvNeuralProcess,y_dim=y_dim,
                         r_dim=32,
                                Classifier=None,
                          TmpSelfAttn=partial(UnetGCN, 
                                              is_sum_res=True,
                                              Conv=partial(GCNConv, improved=True), 
                                              max_nchannels=128, n_layers=5,_is_summary=True))

models["transformer_gcnp_unetgcn"] = m_trnsf

# %%
from utils.helpers import count_parameters
for k,v in models.items():
    print(k, "- N Param:", count_parameters(v(y_dim=3, t_dim=6)()))
# Out:
# ssl_classifier_gcnp_unetgcn - N Param: 59599
# transformer_gcnp_unetgcn - N Param: 42057

# %%
from skssl.transformers.neuralproc.datasplit import GridCntxtTrgtGetter, RandomMasker, no_masker, half_masker
from utils.data.tsdata import get_timeseries_dataset, SparseMultiTimeSeriesDataset

get_cntxt_trgt_test = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.50),
                                         target_masker=no_masker,
                                         is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

get_cntxt_trgt_feat = GridCntxtTrgtGetter(context_masker=no_masker,
                                     target_masker=no_masker,
                                     is_add_cntxts_to_trgts=False)  # don't context points to tagrtes

get_cntxt_trgt = GridCntxtTrgtGetter(context_masker=RandomMasker(min_nnz=0.01, max_nnz=0.99),
                                 target_masker=RandomMasker(min_nnz=0.50, max_nnz=0.99),
                                 is_add_cntxts_to_trgts=False, is_stratify=True)  # don't context points to tagrtes

import torch
import skorch
from torch_geometric.data import Batch

def cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=False):
    def mycollate(data_list):
        
        if is_repeat_batch:
            data_list = data_list + data_list
            
        data = Batch.from_data_list(data_list, [])
        edge_attr = torch.ones_like(data.edge_index[0], dtype=torch.float) if data.edge_attr is None else data.edge_attr
        
        X, mask_context, mask_target = get_cntxt_trgt(data.x.t().unsqueeze(0), None, is_grided=True, 
                                                      stratify=data.batch)
        data.x = X.squeeze(0).t()
            
        
        # Can't pass a Dataset directly, since it expects tensors. 
        # Use dict of tensors instead. Also, use torch.sparse for 
        # adjacency matrix to pass skorch's same-dimension check
        return {
            "X":{'x': data.x,
            'adj': torch.sparse.FloatTensor(data.edge_index, 
                                            edge_attr, 
                                            size=[data.num_nodes, data.num_nodes], 
                                            device=data.x.device),
            'batch': data.batch},
            'mask_context':mask_context.squeeze(0),
            'mask_target':mask_target.squeeze(0),
            
        }, data.y
    
    return mycollate
        
class SkorchDataset(skorch.dataset.Dataset):
    def __init__(self, X, y):
        # We need to specify `length` to avoid checks
        super(SkorchDataset, self).__init__(X, y, length=len(X))
    
    def transform(self, X, y):
        return X   # Ignore y, since it is included in X

# %%
def load_pretrained_(models, data_name, datasets, data_specific_kwargs):

    # ALREADY INITALIZE TO BE ABLE TO LOAD
    models["ssl_classifier_gcnp_unetgcn"] = m_clf(**data_specific_kwargs[data_name])()
    models["transformer_gcnp_unetgcn"] = m_trnsf(**data_specific_kwargs[data_name])()

    # load all transformers
    loaded_models = {}
    for k, m in models.items():
        if "transformer" not in k:
            continue

        out = train_models_({data_name:datasets[data_name]}, {k :m },
                            chckpnt_dirname=chckpnt_dirname,
                            is_retrain=False)

        pretrained_model = out[list(out.keys())[0]].module_
        model_dict = models[k.replace("transformer", "ssl_classifier")].state_dict()
        model_dict.update(pretrained_model.state_dict())
        models[k.replace("transformer", "ssl_classifier")].load_state_dict(model_dict)

# %% [markdown]
# # Training

# %%
import random

N_EPOCHS = 200 
BATCH_SIZE = 16
IS_RETRAIN = False # if false load precomputed
chckpnt_dirname="results/notebooks/neural_process_graph/"

from ntbks_helpers import train_models_
from skorch.callbacks import EarlyStopping

# %%
data_trainers = {}
data_keys = datasets.keys()

for label_perc in label_percentages[::-1]:
    for run in range(10):
        for name_mod in models.keys():
            if "transformer" in name_mod:
                continue
                
            for data_name in data_keys:

                datasets_new = {k:ssl_graph(train_test_split(d), label_perc=label_perc, is_add_test=True, is_augment=True) 
                                for k,d in datasets.items()}

                (data_train, data_test) = datasets_new[data_name]

                data_train = SkorchDataset(data_train, None)
                data_test = SkorchDataset(data_test, None)
                data_test.y = torch.cat([x.y for x in data_test.X])
                data_train.y = torch.cat([x.y for x in data_train.X])

                load_pretrained_(models, data_name, datasets, data_specific_kwargs)

                from skssl.utils.helpers import HyperparameterInterpolator
                n_steps_per_epoch = len(data_train) // BATCH_SIZE
                get_lambda_clf = HyperparameterInterpolator(1, 50, N_EPOCHS * n_steps_per_epoch, mode="linear")

                data_trainers.update(train_models_({data_name: (data_train, data_test)}, 
                                      {k+"_finetune_lab{}%_run{}".format(label_perc, run) :m for k,m in models.items() if "ssl_classifier" in k}, 
                                      criterion=partial(GraphNeuralProcessSSLLoss, 
                                                        n_max_elements=-1, # auto
                                                        label_perc=(data_train.y!=-1).float().mean() ,
                                                        get_lambda_sup=lambda: get_lambda_clf(True),
                                                        is_ssl_only=False,
                                                        ),
                                        patience=15,
                                      chckpnt_dirname=chckpnt_dirname,
                                      max_epochs=N_EPOCHS,
                                                   seed=random.randint(0,10000),
                                      batch_size=BATCH_SIZE,
                                      is_retrain=IS_RETRAIN,
                                                   dataset=SkorchDataset,
                                                   is_monitor_acc=True,
                                      callbacks=[],
                                      #callbacks=[Freezer(lambda x: not x.startswith('classifier'))],
                                      iterator_train__collate_fn=cntxt_trgt_collate(get_cntxt_trgt, is_repeat_batch=True),  
                                      iterator_valid__collate_fn=cntxt_trgt_collate(get_cntxt_trgt_feat),
                                                   mode="classifier",
                                                  ))
# Out:
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 45 val_loss: 1.2858003377914429
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 7 val_loss: 0.5431659817695618
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 27 val_loss: 0.8947901725769043
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 45 val_loss: 1.2858003377914429
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 7 val_loss: 0.5431659817695618
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 best epoch: 27 val_loss: 0.8947901725769043
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 35 val_loss: 1.3219211101531982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 4 val_loss: 0.548983633518219
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 16 val_loss: 0.9077684283256531
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 35 val_loss: 1.3219211101531982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 4 val_loss: 0.548983633518219
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 best epoch: 16 val_loss: 0.9077684283256531
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 45 val_loss: 1.3730242252349854
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 8 val_loss: 0.5437370538711548
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 27 val_loss: 0.9021309018135071
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 45 val_loss: 1.3730242252349854
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 8 val_loss: 0.5437370538711548
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 best epoch: 27 val_loss: 0.9021309018135071
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 35 val_loss: 1.302344799041748
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 8 val_loss: 0.5479198098182678
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 27 val_loss: 0.8938373327255249
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 35 val_loss: 1.302344799041748
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 8 val_loss: 0.5479198098182678
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 best epoch: 27 val_loss: 0.8938373327255249
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 35 val_loss: 1.3134015798568726
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 1 val_loss: 0.6016703248023987
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 27 val_loss: 0.8845755457878113
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 35 val_loss: 1.3134015798568726
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 1 val_loss: 0.6016703248023987
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 best epoch: 27 val_loss: 0.8845755457878113
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 45 val_loss: 1.3031649589538574
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 7 val_loss: 0.5434341430664062
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 27 val_loss: 0.8981335759162903
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 45 val_loss: 1.3031649589538574
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 7 val_loss: 0.5434341430664062
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 best epoch: 27 val_loss: 0.8981335759162903
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 45 val_loss: 1.2180068492889404
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 1 val_loss: 0.6003772616386414
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 27 val_loss: 0.8906818628311157
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 45 val_loss: 1.2180068492889404
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 1 val_loss: 0.6003772616386414
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 best epoch: 27 val_loss: 0.8906818628311157
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 65 val_loss: 1.276801347732544
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 8 val_loss: 0.539327085018158
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 27 val_loss: 0.8912492990493774
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 65 val_loss: 1.276801347732544
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 8 val_loss: 0.539327085018158
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 best epoch: 27 val_loss: 0.8912492990493774
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 30 val_loss: 1.3993544578552246
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 7 val_loss: 0.5523544549942017
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 53 val_loss: 0.7389787435531616
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 30 val_loss: 1.3993544578552246
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 7 val_loss: 0.5523544549942017
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 best epoch: 53 val_loss: 0.7389787435531616
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 35 val_loss: 1.308423638343811
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 7 val_loss: 0.5469298958778381
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 22 val_loss: 0.9014230966567993
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 35 val_loss: 1.308423638343811
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 7 val_loss: 0.5469298958778381
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 best epoch: 22 val_loss: 0.9014230966567993
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 35 val_loss: 1.6084825992584229
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 7 val_loss: 0.5368859171867371
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 16 val_loss: 0.977568507194519
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 35 val_loss: 1.6084825992584229
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 7 val_loss: 0.5368859171867371
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 best epoch: 16 val_loss: 0.977568507194519
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 24 val_loss: 1.6144300699234009
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 4 val_loss: 0.5364064574241638
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 16 val_loss: 0.9867525100708008
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 24 val_loss: 1.6144300699234009
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 4 val_loss: 0.5364064574241638
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 best epoch: 16 val_loss: 0.9867525100708008
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 11 val_loss: 1.565070390701294
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 2 val_loss: 0.5400756001472473
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 12 val_loss: 1.0308434963226318
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 11 val_loss: 1.565070390701294
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 2 val_loss: 0.5400756001472473
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 best epoch: 12 val_loss: 1.0308434963226318
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 11 val_loss: 1.6694332361221313
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 5 val_loss: 0.5372689962387085
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 16 val_loss: 0.9789174199104309
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 11 val_loss: 1.6694332361221313
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 5 val_loss: 0.5372689962387085
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 best epoch: 16 val_loss: 0.9789174199104309
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 24 val_loss: 1.6322911977767944
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 2 val_loss: 0.5405126810073853
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 16 val_loss: 0.9704945683479309
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 24 val_loss: 1.6322911977767944
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 2 val_loss: 0.5405126810073853
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 best epoch: 16 val_loss: 0.9704945683479309
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 22 val_loss: 1.62800931930542
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 2 val_loss: 0.5393995642662048
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 16 val_loss: 0.9710229635238647
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 22 val_loss: 1.62800931930542
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 2 val_loss: 0.5393995642662048
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 best epoch: 16 val_loss: 0.9710229635238647
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 42 val_loss: 1.5398651361465454
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 4 val_loss: 0.5265993475914001
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 12 val_loss: 1.035929560661316
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 42 val_loss: 1.5398651361465454
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 4 val_loss: 0.5265993475914001
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 best epoch: 12 val_loss: 1.035929560661316
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 21 val_loss: 1.6602433919906616
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 5 val_loss: 0.5288232564926147
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 16 val_loss: 0.9686108827590942
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 21 val_loss: 1.6602433919906616
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 5 val_loss: 0.5288232564926147
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 best epoch: 16 val_loss: 0.9686108827590942
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 11 val_loss: 1.6536604166030884
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 7 val_loss: 0.5235149264335632
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 20 val_loss: 0.9710159301757812
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 11 val_loss: 1.6536604166030884
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 7 val_loss: 0.5235149264335632
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 best epoch: 20 val_loss: 0.9710159301757812
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 24 val_loss: 1.5892568826675415
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 2 val_loss: 0.5323352217674255
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 16 val_loss: 0.9801570177078247
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 24 val_loss: 1.5892568826675415
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 2 val_loss: 0.5323352217674255
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 best epoch: 16 val_loss: 0.9801570177078247
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 5 val_loss: 1.8553229570388794
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 2 val_loss: 0.4943455755710602
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 13 val_loss: 0.9891241788864136
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 5 val_loss: 1.8553229570388794
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 2 val_loss: 0.4943455755710602
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 best epoch: 13 val_loss: 0.9891241788864136
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 9 val_loss: 1.8083574771881104
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 3 val_loss: 0.48920780420303345
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 12 val_loss: 0.9735854268074036
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 9 val_loss: 1.8083574771881104
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 3 val_loss: 0.48920780420303345
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 best epoch: 12 val_loss: 0.9735854268074036
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 6 val_loss: 1.8204602003097534
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 3 val_loss: 0.49663904309272766
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 47 val_loss: 0.8154346346855164
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 6 val_loss: 1.8204602003097534
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 3 val_loss: 0.49663904309272766
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 best epoch: 47 val_loss: 0.8154346346855164
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 11 val_loss: 1.7522765398025513
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 2 val_loss: 0.4951602518558502
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 27 val_loss: 0.9452120661735535
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 11 val_loss: 1.7522765398025513
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 2 val_loss: 0.4951602518558502
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 best epoch: 27 val_loss: 0.9452120661735535
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 7 val_loss: 1.8469455242156982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 3 val_loss: 0.5039848685264587
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 12 val_loss: 0.9815541505813599
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 7 val_loss: 1.8469455242156982
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 3 val_loss: 0.5039848685264587
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 best epoch: 12 val_loss: 0.9815541505813599
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 11 val_loss: 1.7652459144592285
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 2 val_loss: 0.5005922913551331
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 27 val_loss: 0.9377015829086304
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 11 val_loss: 1.7652459144592285
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 2 val_loss: 0.5005922913551331
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 best epoch: 27 val_loss: 0.9377015829086304
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# ...
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 1.3872177600860596
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 5.956545829772949
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 6.521864891052246
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 best epoch: 1 val_loss: 1.3872177600860596
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 5.952715873718262
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 6.476783275604248
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 1.3872379064559937
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 5.952715873718262
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 6.476783275604248
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 best epoch: 1 val_loss: 1.3872379064559937
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 5.973859786987305
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 6.626062870025635
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 1.3880759477615356
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 5.973859786987305
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 6.626062870025635
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 best epoch: 1 val_loss: 1.3880759477615356
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 5.95278787612915
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 6.636899471282959
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 1.387303113937378
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 5.95278787612915
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 6.636899471282959
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 best epoch: 1 val_loss: 1.387303113937378
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 5.966891288757324
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 6.324332237243652
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 1.3872627019882202
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 5.966891288757324
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 6.324332237243652
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 best epoch: 1 val_loss: 1.3872627019882202
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 5.954939365386963
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 10.4124174118042
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 1.387237310409546
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 5.954939365386963
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 10.4124174118042
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 best epoch: 1 val_loss: 1.387237310409546
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 5.959175109863281
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 6.769335746765137
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 1.3880339860916138
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 5.959175109863281
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 6.769335746765137
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 best epoch: 1 val_loss: 1.3880339860916138
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 5.9524760246276855
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 6.628399848937988
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 1.3881711959838867
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 5.9524760246276855
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 6.628399848937988
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 best epoch: 1 val_loss: 1.3881711959838867
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 5.956018924713135
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 4 val_loss: 7.18483829498291
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 1.3872971534729004
#
# --- Loading enzymes/transformer_gcnp_unetgcn ---
#
# enzymes/transformer_gcnp_unetgcn best epoch: 156 val_loss: 0.7818504571914673
#
# --- Loading enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 5.956018924713135
#
# --- Loading proteins/transformer_gcnp_unetgcn ---
#
# proteins/transformer_gcnp_unetgcn best epoch: 163 val_loss: 0.26717182993888855
#
# --- Loading proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 4 val_loss: 7.18483829498291
#
# --- Loading synthie/transformer_gcnp_unetgcn ---
#
# synthie/transformer_gcnp_unetgcn best epoch: 198 val_loss: 0.9303861260414124
#
# --- Loading synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 ---
#
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 best epoch: 1 val_loss: 1.3872971534729004

# %%
for k,t in data_trainers.items(): 
    for e, h in enumerate(t.history[::-1]):
        if h["valid_acc_best"]:
            print(k, "epoch:", len(t.history)-e, 
                  "val_loss:", h["valid_loss"], 
                 "valid_acc", h["valid_acc"])
            break
# Out:
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 epoch: 76 val_loss: 1.4458937644958496 valid_acc 0.7333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 epoch: 9 val_loss: 0.5690308213233948 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run0 epoch: 27 val_loss: 0.8947901725769043 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 epoch: 35 val_loss: 1.3219211101531982 valid_acc 0.6
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 epoch: 9 val_loss: 0.5792898535728455 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run1 epoch: 20 val_loss: 0.9295721054077148 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 epoch: 69 val_loss: 1.447595238685608 valid_acc 0.7333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 epoch: 9 val_loss: 0.5953370928764343 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run2 epoch: 37 val_loss: 0.9575174450874329 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 epoch: 35 val_loss: 1.302344799041748 valid_acc 0.65
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 epoch: 8 val_loss: 0.5479198098182678 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run3 epoch: 27 val_loss: 0.8938373327255249 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 epoch: 35 val_loss: 1.3134015798568726 valid_acc 0.6166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 epoch: 3 val_loss: 0.6278713345527649 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run4 epoch: 27 val_loss: 0.8845755457878113 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 epoch: 52 val_loss: 1.4607943296432495 valid_acc 0.7
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 epoch: 8 val_loss: 0.5546796917915344 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run5 epoch: 28 val_loss: 0.9233821630477905 valid_acc 0.65
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 epoch: 45 val_loss: 1.2180068492889404 valid_acc 0.6833333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 epoch: 1 val_loss: 0.6003772616386414 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run6 epoch: 37 val_loss: 0.9595597386360168 valid_acc 0.65
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 epoch: 74 val_loss: 1.3698185682296753 valid_acc 0.7166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 epoch: 8 val_loss: 0.539327085018158 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run7 epoch: 27 val_loss: 0.8912492990493774 valid_acc 0.65
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 epoch: 33 val_loss: 1.4916794300079346 valid_acc 0.6166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 epoch: 8 val_loss: 0.5529860258102417 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run8 epoch: 55 val_loss: 0.7456265091896057 valid_acc 0.75
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 epoch: 41 val_loss: 1.4125617742538452 valid_acc 0.6333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 epoch: 9 val_loss: 0.5877180695533752 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab1%_run9 epoch: 30 val_loss: 0.9441299438476562 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 epoch: 39 val_loss: 1.7966759204864502 valid_acc 0.5333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 epoch: 9 val_loss: 0.5506907105445862 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run0 epoch: 20 val_loss: 0.9864892959594727 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 epoch: 25 val_loss: 1.6414666175842285 valid_acc 0.5
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 epoch: 4 val_loss: 0.5364064574241638 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run1 epoch: 20 val_loss: 0.9964703321456909 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 epoch: 46 val_loss: 1.6800682544708252 valid_acc 0.55
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 epoch: 3 val_loss: 0.5735737681388855 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run2 epoch: 12 val_loss: 1.0308434963226318 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 epoch: 17 val_loss: 1.8159300088882446 valid_acc 0.48333333333333334
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 epoch: 5 val_loss: 0.5372689962387085 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run3 epoch: 25 val_loss: 0.9923108220100403 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 epoch: 42 val_loss: 1.6384884119033813 valid_acc 0.55
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 epoch: 3 val_loss: 0.5772849917411804 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run4 epoch: 16 val_loss: 0.9704945683479309 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 epoch: 22 val_loss: 1.62800931930542 valid_acc 0.5166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 epoch: 5 val_loss: 0.5514842867851257 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run5 epoch: 16 val_loss: 0.9710229635238647 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 epoch: 42 val_loss: 1.5398651361465454 valid_acc 0.5333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 epoch: 5 val_loss: 0.5385522246360779 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run6 epoch: 12 val_loss: 1.035929560661316 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 epoch: 36 val_loss: 1.908096432685852 valid_acc 0.5833333333333334
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 epoch: 5 val_loss: 0.5288232564926147 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run7 epoch: 16 val_loss: 0.9686108827590942 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 epoch: 22 val_loss: 1.68401300907135 valid_acc 0.48333333333333334
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 epoch: 7 val_loss: 0.5235149264335632 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run8 epoch: 25 val_loss: 0.971774697303772 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 epoch: 35 val_loss: 1.7509534358978271 valid_acc 0.5333333333333333
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 epoch: 7 val_loss: 0.5356309413909912 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.5%_run9 epoch: 25 val_loss: 0.9854224920272827 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 epoch: 40 val_loss: 2.5602400302886963 valid_acc 0.48333333333333334
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 epoch: 8 val_loss: 0.62606281042099 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run0 epoch: 13 val_loss: 0.9891241788864136 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 epoch: 16 val_loss: 1.9679075479507446 valid_acc 0.45
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 epoch: 3 val_loss: 0.48920780420303345 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run1 epoch: 13 val_loss: 0.9949425458908081 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 epoch: 41 val_loss: 2.4641852378845215 valid_acc 0.48333333333333334
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 epoch: 3 val_loss: 0.49663904309272766 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run2 epoch: 47 val_loss: 0.8154346346855164 valid_acc 0.7
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 epoch: 31 val_loss: 1.9716219902038574 valid_acc 0.4666666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 epoch: 3 val_loss: 0.5142098665237427 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run3 epoch: 27 val_loss: 0.9452120661735535 valid_acc 0.65
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 epoch: 40 val_loss: 2.3409464359283447 valid_acc 0.5166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 epoch: 3 val_loss: 0.5039848685264587 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run4 epoch: 13 val_loss: 1.0039236545562744 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 epoch: 40 val_loss: 2.3599212169647217 valid_acc 0.5
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 epoch: 3 val_loss: 0.5140669941902161 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run5 epoch: 45 val_loss: 1.1207177639007568 valid_acc 0.675
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 epoch: 12 val_loss: 1.9338651895523071 valid_acc 0.43333333333333335
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 epoch: 11 val_loss: 0.5524719953536987 valid_acc 0.7767857142857143
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run6 epoch: 36 val_loss: 1.199415922164917 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 epoch: 16 val_loss: 1.9770411252975464 valid_acc 0.43333333333333335
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 epoch: 3 val_loss: 0.5073078274726868 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run7 epoch: 41 val_loss: 0.9330065846443176 valid_acc 0.7
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 epoch: 16 val_loss: 1.927306890487671 valid_acc 0.4166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 epoch: 3 val_loss: 0.500394880771637 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run8 epoch: 27 val_loss: 0.9451090693473816 valid_acc 0.625
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 epoch: 41 val_loss: 2.6759464740753174 valid_acc 0.4666666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 epoch: 3 val_loss: 0.5012754201889038 valid_acc 0.7410714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.3%_run9 epoch: 13 val_loss: 0.9982069730758667 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 epoch: 8 val_loss: 4.031473159790039 valid_acc 0.4
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 epoch: 9 val_loss: 1.9459837675094604 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run0 epoch: 14 val_loss: 1.654679298400879 valid_acc 0.525
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 epoch: 31 val_loss: 5.203117847442627 valid_acc 0.43333333333333335
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 epoch: 10 val_loss: 2.2066309452056885 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run1 epoch: 5 val_loss: 1.1754133701324463 valid_acc 0.525
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 epoch: 7 val_loss: 3.357534885406494 valid_acc 0.36666666666666664
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 epoch: 1 val_loss: 1.1962950229644775 valid_acc 0.7232142857142857
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run2 epoch: 18 val_loss: 1.5677759647369385 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 epoch: 31 val_loss: 5.168033123016357 valid_acc 0.4666666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 epoch: 19 val_loss: 2.0332541465759277 valid_acc 0.7767857142857143
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run3 epoch: 19 val_loss: 1.655226707458496 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 epoch: 9 val_loss: 3.68428897857666 valid_acc 0.4
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 epoch: 10 val_loss: 1.3139680624008179 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run4 epoch: 6 val_loss: 1.115639328956604 valid_acc 0.525
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 epoch: 25 val_loss: 4.680883407592773 valid_acc 0.4166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 epoch: 16 val_loss: 2.596561908721924 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run5 epoch: 21 val_loss: 1.3600624799728394 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 epoch: 8 val_loss: 3.874210834503174 valid_acc 0.4
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 epoch: 4 val_loss: 1.3902703523635864 valid_acc 0.7410714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run6 epoch: 12 val_loss: 1.4471479654312134 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 epoch: 8 val_loss: 3.6469242572784424 valid_acc 0.4166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 epoch: 2 val_loss: 1.3096948862075806 valid_acc 0.7410714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run7 epoch: 24 val_loss: 1.6720430850982666 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 epoch: 4 val_loss: 2.8818142414093018 valid_acc 0.35
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 epoch: 12 val_loss: 2.4981327056884766 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run8 epoch: 12 val_loss: 1.4254677295684814 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 epoch: 36 val_loss: 4.224605083465576 valid_acc 0.4166666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 epoch: 12 val_loss: 1.9865721464157104 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.1%_run9 epoch: 5 val_loss: 1.1772054433822632 valid_acc 0.5
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 epoch: 17 val_loss: 6.797180652618408 valid_acc 0.31666666666666665
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 epoch: 7 val_loss: 2.960963010787964 valid_acc 0.7767857142857143
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run0 epoch: 7 val_loss: 1.266619324684143 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 epoch: 15 val_loss: 5.92999792098999 valid_acc 0.35
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 epoch: 10 val_loss: 2.6738650798797607 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run1 epoch: 5 val_loss: 1.086868405342102 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 epoch: 7 val_loss: 5.322213649749756 valid_acc 0.35
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 epoch: 1 val_loss: 1.277952790260315 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run2 epoch: 7 val_loss: 1.2330098152160645 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 epoch: 34 val_loss: 7.597785949707031 valid_acc 0.4
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 epoch: 12 val_loss: 2.4463086128234863 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run3 epoch: 11 val_loss: 1.3342316150665283 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 epoch: 15 val_loss: 6.297462463378906 valid_acc 0.36666666666666664
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 epoch: 4 val_loss: 1.9368162155151367 valid_acc 0.75
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run4 epoch: 7 val_loss: 1.225999116897583 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 epoch: 10 val_loss: 6.309290409088135 valid_acc 0.36666666666666664
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 epoch: 8 val_loss: 1.958464503288269 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run5 epoch: 20 val_loss: 2.5654098987579346 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 epoch: 10 val_loss: 6.287646770477295 valid_acc 0.35
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 epoch: 1 val_loss: 1.2469661235809326 valid_acc 0.7410714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run6 epoch: 22 val_loss: 1.8661218881607056 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 epoch: 28 val_loss: 6.979788303375244 valid_acc 0.38333333333333336
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 epoch: 12 val_loss: 3.6643006801605225 valid_acc 0.7589285714285714
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run7 epoch: 7 val_loss: 1.2271983623504639 valid_acc 0.575
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 epoch: 21 val_loss: 6.223791122436523 valid_acc 0.35
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 epoch: 19 val_loss: 3.9422719478607178 valid_acc 0.7678571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run8 epoch: 7 val_loss: 1.270084023475647 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 epoch: 21 val_loss: 5.489485263824463 valid_acc 0.36666666666666664
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 epoch: 2 val_loss: 1.3796164989471436 valid_acc 0.7410714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.05%_run9 epoch: 7 val_loss: 1.2043406963348389 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 epoch: 7 val_loss: 12.794855117797852 valid_acc 0.18333333333333332
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 epoch: 1 val_loss: 6.519623279571533 valid_acc 0.5982142857142857
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run0 epoch: 36 val_loss: 7.256773471832275 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 epoch: 4 val_loss: 9.9508638381958 valid_acc 0.16666666666666666
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 epoch: 44 val_loss: 36.590492248535156 valid_acc 0.6696428571428571
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run1 epoch: 12 val_loss: 2.8586268424987793 valid_acc 0.525
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 epoch: 36 val_loss: 19.466346740722656 valid_acc 0.2
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 epoch: 1 val_loss: 6.476783275604248 valid_acc 0.5803571428571429
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run2 epoch: 15 val_loss: 3.14631724357605 valid_acc 0.525
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 epoch: 2 val_loss: 7.875617980957031 valid_acc 0.16666666666666666
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 epoch: 4 val_loss: 9.269633293151855 valid_acc 0.6071428571428571
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run3 epoch: 34 val_loss: 5.404017925262451 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 epoch: 7 val_loss: 13.017468452453613 valid_acc 0.25
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 epoch: 1 val_loss: 6.636899471282959 valid_acc 0.6071428571428571
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run4 epoch: 4 val_loss: 1.8657867908477783 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 epoch: 2 val_loss: 7.892390251159668 valid_acc 0.16666666666666666
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 epoch: 3 val_loss: 11.16454029083252 valid_acc 0.6160714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run5 epoch: 5 val_loss: 1.9930229187011719 valid_acc 0.475
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 epoch: 2 val_loss: 7.989588260650635 valid_acc 0.16666666666666666
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 epoch: 14 val_loss: 45.5308837890625 valid_acc 0.6160714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run6 epoch: 5 val_loss: 2.4235808849334717 valid_acc 0.5
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 epoch: 4 val_loss: 10.153407096862793 valid_acc 0.16666666666666666
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 epoch: 2 val_loss: 7.787795066833496 valid_acc 0.6160714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run7 epoch: 19 val_loss: 3.1982789039611816 valid_acc 0.6
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 epoch: 10 val_loss: 15.101330757141113 valid_acc 0.21666666666666667
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 epoch: 8 val_loss: 13.487936973571777 valid_acc 0.6875
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run8 epoch: 22 val_loss: 5.119255065917969 valid_acc 0.55
# enzymes/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 epoch: 10 val_loss: 17.69307518005371 valid_acc 0.18333333333333332
# proteins/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 epoch: 12 val_loss: 13.925361633300781 valid_acc 0.6160714285714286
# synthie/ssl_classifier_gcnp_unetgcn_finetune_lab0.01%_run9 epoch: 18 val_loss: 4.3074049949646 valid_acc 0.525

# %%
import pandas as pd

out = pd.Series({k:v.history[-1]["valid_acc"] for k,v in data_trainers.items()}).reset_index(name="accuracy")
splitted = out["index"].str.split("/", expand = True)
out["data"] = splitted[0]
out["models"] = splitted[1]

splitted2 = out["models"].str.split("_run", expand = True)
out["models"] = splitted2[0]
out["run"] = splitted2[1]

splitted3 = out["models"].str.split("_lab", expand = True)
out["models"] = splitted3[0]
out["lab"] = splitted3[1]


out.drop(columns =["index"], inplace = True) 

out.groupby(["data", "models", "lab"]).describe()
# Out:
#                                                     accuracy            \
#                                                        count      mean
# data     models                               lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune 0.01%     10.0  0.186667
#                                               0.05%     10.0  0.360000
#                                               0.1%      10.0  0.406667
#                                               0.3%      10.0  0.465000
#                                               0.5%      10.0  0.526667
#                                               1%        10.0  0.668333
# proteins ssl_classifier_gcnp_unetgcn_finetune 0.01%     10.0  0.621429
#                                               0.05%     10.0  0.756250
#                                               0.1%      10.0  0.750000
#                                               0.3%      10.0  0.759821
#                                               0.5%      10.0  0.758036
#                                               1%        10.0  0.756250
# synthie  ssl_classifier_gcnp_unetgcn_finetune 0.01%     10.0  0.535000
#                                               0.05%     10.0  0.595000
#                                               0.1%      10.0  0.555000
#                                               0.3%      10.0  0.640000
#                                               0.5%      10.0  0.587500
#                                               1%        10.0  0.642500
#
#                                                                          \
#                                                           std       min
# data     models                               lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.028109  0.166667
#                                               0.05%  0.022498  0.316667
#                                               0.1%   0.032584  0.350000
#                                               0.3%   0.031866  0.416667
#                                               0.5%   0.031623  0.483333
#                                               1%     0.051190  0.600000
# proteins ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.032384  0.580357
#                                               0.05%  0.011942  0.741071
#                                               0.1%   0.014580  0.723214
#                                               0.3%   0.010689  0.741071
#                                               0.5%   0.006588  0.750000
#                                               1%     0.004313  0.750000
# synthie  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.033747  0.475000
#                                               0.05%  0.010541  0.575000
#                                               0.1%   0.034960  0.500000
#                                               0.3%   0.039441  0.600000
#                                               0.5%   0.029463  0.550000
#                                               1%     0.040910  0.600000
#
#                                                                          \
#                                                           25%       50%
# data     models                               lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.166667  0.175000
#                                               0.05%  0.350000  0.358333
#                                               0.1%   0.400000  0.408333
#                                               0.3%   0.437500  0.466667
#                                               0.5%   0.504167  0.533333
#                                               1%     0.620833  0.666667
# proteins ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.607143  0.616071
#                                               0.05%  0.750000  0.754464
#                                               0.1%   0.743304  0.750000
#                                               0.3%   0.752232  0.758929
#                                               0.5%   0.752232  0.758929
#                                               1%     0.752232  0.758929
# synthie  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.525000  0.537500
#                                               0.05%  0.600000  0.600000
#                                               0.1%   0.525000  0.562500
#                                               0.3%   0.606250  0.625000
#                                               0.5%   0.575000  0.575000
#                                               1%     0.625000  0.625000
#
#
#                                                           75%       max
# data     models                               lab
# enzymes  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.195833  0.250000
#                                               0.05%  0.366667  0.400000
#                                               0.1%   0.416667  0.466667
#                                               0.3%   0.483333  0.516667
#                                               0.5%   0.545833  0.583333
#                                               1%     0.712500  0.733333
# proteins ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.616071  0.687500
#                                               0.05%  0.765625  0.776786
#                                               0.1%   0.750000  0.776786
#                                               0.3%   0.767857  0.776786
#                                               0.5%   0.758929  0.767857
#                                               1%     0.758929  0.758929
# synthie  ssl_classifier_gcnp_unetgcn_finetune 0.01%  0.550000  0.600000
#                                               0.05%  0.600000  0.600000
#                                               0.1%   0.575000  0.600000
#                                               0.3%   0.668750  0.700000
#                                               0.5%   0.618750  0.625000
#                                               1%     0.650000  0.750000
